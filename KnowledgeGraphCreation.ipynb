# %%
# requirements
# !pip install -q rdflib sparqlwrapper owlrl gdown pandas wikipedia-api

# %%
import gdown
import os
import pandas as pd
import rdflib
import urllib
from SPARQLWrapper import SPARQLWrapper
from urllib.parse import quote
from datetime import datetime
from dateutil import parser
import wikipediaapi
import owlrl

# %%
from rdflib import Graph, URIRef, BNode, Literal, FOAF, RDF, RDFS, XSD, Namespace
from SPARQLWrapper import JSON
sparql = SPARQLWrapper("http://dbpedia.org/sparql")

# %%
# !pip freeze > requirements.txt

# %%
# create directory for data
if not os.path.exists("./data/"):
    os.mkdir("./data/")

# %%
# Download data
gdown.download(id="1UILSMenvqzFMsIhV6l4ZV1opJpRQZnwC", output="./data/rym_top_5000_all_time.csv", quiet=True)
gdown.download(id="1UNJ2iDX-xoWIekSA0ZwoqNOk3eAZjqrp", output="./data/albumlist.csv", quiet=True)
# Out:
# './data/albumlist.csv'

# %% [markdown]
# # **KRR Module 2 2022/23 Project**
#
# The project consists in the creation of an RDF knowledge graph starting from tabular data (two CSV files loaded below).
#
# You should cover all of the following steps.

# %% [markdown]
# ### **`1. Create an RDFLib Graph from data contained in CSV files`**
#
# In steps:
# 1) Load the CSV files in two pandas DataFrames and join them
# 2) Create an RDFLib `Graph` and add triples from the data of the dataframes

# %% [markdown]
# Useful links:
#
# - [Pandas user guide](https://pandas.pydata.org/docs/user_guide/index.html) and [documentation](https://pandas.pydata.org/docs/reference/), e.g.:
#     - [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html)
#     - [Join dataframes](https://pandas.pydata.org/docs/user_guide/10min.html#join)
#     - [Splitting and replacing strings](https://pandas.pydata.org/docs/user_guide/text.html#splitting-and-replacing-strings)
#     - [Apply a function over an axis of a DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html?highlight=apply#pandas.DataFrame.apply)

# %%
df1 = pd.read_csv('data/albumlist.csv', encoding='mac_roman')
df1.head()
# Out:
#    Number  Year                                  Album          Artist
# 0       1  1967  Sgt. Pepper's Lonely Hearts Club Band     The Beatles  \
# 1       2  1966                             Pet Sounds  The Beach Boys
# 2       3  1966                               Revolver     The Beatles
# 3       4  1965                   Highway 61 Revisited       Bob Dylan
# 4       5  1965                            Rubber Soul     The Beatles
#
#        Genre                       Subgenre
# 0       Rock  Rock & Roll, Psychedelic Rock
# 1       Rock     Pop Rock, Psychedelic Rock
# 2       Rock     Psychedelic Rock, Pop Rock
# 3       Rock          Folk Rock, Blues Rock
# 4  Rock, Pop                       Pop Rock

# %%
df2 = pd.read_csv('data/rym_top_5000_all_time.csv')
df2.head()
# Out:
#    Ranking                             Album     Artist Name
# 0      1.0                       OK Computer       Radiohead  \
# 1      2.0                Wish You Were Here      Pink Floyd
# 2      3.0  In the Court of the Crimson King    King Crimson
# 3      4.0                             Kid A       Radiohead
# 4      5.0               To Pimp a Butterfly  Kendrick Lamar
#
#         Release Date                                           Genres
# 0       16 June 1997                       Alternative Rock, Art Rock  \
# 1  12 September 1975                       Progressive Rock, Art Rock
# 2    10 October 1969                       Progressive Rock, Art Rock
# 3     3 October 2000          Art Rock, Experimental Rock, Electronic
# 4      15 March 2015  Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
#
#                                          Descriptors  Average Rating
# 0  melancholic, anxious, futuristic, alienation, ...            4.23  \
# 1  melancholic, atmospheric, progressive, male vo...            4.29
# 2  fantasy, epic, progressive, philosophical, com...            4.30
# 3  cold, melancholic, futuristic, atmospheric, an...            4.21
# 4  political, conscious, poetic, protest, concept...            4.27
#
#   Number of Ratings  Number of Reviews
# 0            70,382               1531
# 1            48,662                983
# 2            44,943                870
# 3            58,590                734
# 4            44,206                379

# %%
df1 = df1.drop('Number', axis=1)
df1.head()
# Out:
#    Year                                  Album          Artist      Genre
# 0  1967  Sgt. Pepper's Lonely Hearts Club Band     The Beatles       Rock  \
# 1  1966                             Pet Sounds  The Beach Boys       Rock
# 2  1966                               Revolver     The Beatles       Rock
# 3  1965                   Highway 61 Revisited       Bob Dylan       Rock
# 4  1965                            Rubber Soul     The Beatles  Rock, Pop
#
#                         Subgenre
# 0  Rock & Roll, Psychedelic Rock
# 1     Pop Rock, Psychedelic Rock
# 2     Psychedelic Rock, Pop Rock
# 3          Folk Rock, Blues Rock
# 4                       Pop Rock

# %%
df2 = df2.drop('Ranking', axis=1)

# %%
df2 = df2.rename(columns={'Artist Name':'Artist'})

# %%
dfo = pd.merge(df1, df2, on=['Album', 'Artist'], how='outer')
print(dfo.shape)
dfo.head()
# Out:
# (5205, 11)
#      Year                                  Album          Artist      Genre
# 0  1967.0  Sgt. Pepper's Lonely Hearts Club Band     The Beatles       Rock  \
# 1  1966.0                             Pet Sounds  The Beach Boys       Rock
# 2  1966.0                               Revolver     The Beatles       Rock
# 3  1965.0                   Highway 61 Revisited       Bob Dylan       Rock
# 4  1965.0                            Rubber Soul     The Beatles  Rock, Pop
#
#                         Subgenre     Release Date
# 0  Rock & Roll, Psychedelic Rock      1 June 1967  \
# 1     Pop Rock, Psychedelic Rock      16 May 1966
# 2     Psychedelic Rock, Pop Rock    5 August 1966
# 3          Folk Rock, Blues Rock   30 August 1965
# 4                       Pop Rock  3 December 1965
#
#                          Genres
# 0     Psychedelic Pop, Pop Rock  \
# 1                   Baroque Pop
# 2     Pop Rock, Psychedelic Pop
# 3  Folk Rock, Singer/Songwriter
# 4                      Pop Rock
#
#                                          Descriptors  Average Rating
# 0  psychedelic, playful, melodic, male vocals, wa...            4.13  \
# 1  Wall of Sound, warm, bittersweet, love, romant...            4.18
# 2  psychedelic, melodic, male vocals, drugs, ecle...            4.23
# 3  poetic, cryptic, surreal, sarcastic, male voca...            4.17
# 4  melodic, love, male vocals, bittersweet, roman...            4.03
#
#   Number of Ratings  Number of Reviews
# 0            43,576              863.0
# 1            36,305              727.0
# 2            43,178             1160.0
# 3            26,338              604.0
# 4            33,508              721.0

# %%
g = Graph()
DBP = Namespace("http://dbpedia.org/property/")
EX = Namespace("http://www.example.org/")
g.bind("dbp", DBP)
g.bind("ex", EX)

# %%
DBO = Namespace("http://dbpedia.org/ontology/")

# %%
def encode_uri(uri):
    return URIRef(uri.replace(" ", "_").replace('"', ""))

# %% [markdown]
# Create an RDFLib `Graph` and add triples from the data of the dataframes**
#
# For example, add triples like the following (but not only):
#
# - `[album] dbp:artist [artist]`,
# - `[album] rdfs:label [album_name]`,
# - `[album] rdf:type [genre]`
#
# Make sure you use URIs and Literals correctly.

# %%
for _, row in dfo.iterrows():
        album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
        
        if not pd.isna(row['Genre']):
            genres = row['Genre'].split(',')
            for genre in genres:
                subgenres = genre.split('/')
                for subgenre in subgenres:
                    subgenre = subgenre.replace("&", "").strip()
                    genre_uri = encode_uri("http://dbpedia.org/resource/" + subgenre + "_music")
                    g.add((album_uri, DBP.genre, genre_uri))

# %%
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    
    if not pd.isna(row['Subgenre']):
        subgenres = row['Subgenre'].split(',')
        for subgenre in subgenres:
            subgenre = subgenre.replace("&", "and").strip()
            subgenre_uri = encode_uri("http://dbpedia.org/resource/" + subgenre)
            g.add((album_uri, DBP.subgenre, subgenre_uri))

# %%
all_genres = set()

for _, row in dfo.iterrows():
    if pd.notna(row['Genre']):
        genres = [genre.strip() for genre in row['Genre'].replace(" / ", ",").split(',')]
        if "& Country" in genres:
            genres.remove("& Country")
            genres.append("Country")
        all_genres.update(genres)

for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    # We'll add genres and subgenres from the 'Genres' column
    if pd.notna(row['Genres']):
        genres_and_subgenres = [gs.strip() for gs in row['Genres'].replace(" / ", ",").split(',')]

        for gs in genres_and_subgenres:
            gs = gs.replace(",", "").strip()  # handle comma-separated genres
            if gs in all_genres:
                genre_uri = encode_uri("http://dbpedia.org/resource/" + gs + "_music")
                g.add((album_uri, DBP.genre, genre_uri))
            else:
                subgenre_uri = encode_uri("http://dbpedia.org/resource/" + gs)
                g.add((album_uri, DBP.subgenre, subgenre_uri))

# %%
# [album] dbp:artist [artist]
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    artist_uri = encode_uri("http://dbpedia.org/resource/" + row['Artist'])

    g.add((album_uri, DBP.artist, artist_uri))

# %%
# [album] rdfs:label [album_name]
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])

    g.add((album_uri, RDFS.label, Literal(row['Album'])))

# %%
# [album] dbp:year [Year]
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    year = row['Year']
    
    if not pd.isna(year):
        year_literal = Literal(int(year), datatype=XSD.gYear)
        g.add((album_uri, DBP.year, year_literal))

# %%
# [album] dbp:releaseDate [Release Date]
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    date = row['Release Date']
    
    if not pd.isna(date):
            release_date = parser.parse(date).date()
            date_literal = Literal(release_date.isoformat(), datatype=XSD.date)
            g.add((album_uri, DBP.releaseDate, date_literal))

# %%
# [album] dbp:averageRating [Average Rating]
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    
    if not pd.isna(row['Average Rating']):
        rating_literal = Literal(row['Average Rating'], datatype=XSD.float)
        g.add((album_uri, DBP.rating, rating_literal))

# %%
# [album] dbp:numberOfRatings [Number of Ratings]
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    
    if not pd.isna(row['Number of Ratings']):
        rating_str = row['Number of Ratings'].replace(",", "")
        rating_value = int(rating_str)
        rating_literal = Literal(rating_value, datatype=XSD.integer)
        g.add((album_uri, DBP.numberOfRatings, rating_literal))

# %%
# [album] dbp:numberOfReviews [Number of Reviews]
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    
    if not pd.isna(row['Number of Reviews']):
        reviews_value = int(rating_str)
        reviews_literal = Literal(reviews_value, datatype=XSD.integer)
        g.add((album_uri, DBP.numberOfReviews, reviews_literal))

# %%
for _, row in dfo.iterrows():
    album_uri = encode_uri("http://dbpedia.org/resource/" + row['Album'])
    
    if not pd.isna(row['Descriptors']):
        a = row['Descriptors'].split(',')
        for i in a:
            i = i.replace(' ', '')
            g.add((album_uri, EX.descriptors, Literal(i)))

# %% [markdown]
# Some entities appear as both album and artist or as both album and gebre/subgenre. This will be a problem for later inferences, so we need to disambiguate.

# %%
def disambiguate_albums_and_artists(graph):
    new_graph = Graph()

    album_entities = set()
    artist_entities = set()

    # Collect the entities that are used as albums and as artists
    for s, p, o in graph:
        if p == DBP.artist:
            album_entities.add(s)
            artist_entities.add(o)

    # Entities that are used both as an album and an artist
    conflicting_entities = album_entities.intersection(artist_entities)

    for s, p, o in graph:
        # If the subject is a conflicting entity, create a new album entity
        if s in conflicting_entities:
            s = URIRef(str(s) + "_(album)")
        new_graph.add((s, p, o))

    return new_graph

# Usage:
g = disambiguate_albums_and_artists(g)

# %%
def disambiguate_albums_and_genres(graph):

    albums = set()
    genres = set()
    
    for s, p, o in graph:
        if p == DBP.artist:
            albums.add(s)
        elif p == DBP.genre or p == DBP.subgenre:
            genres.add(o)
            
    overlap = albums.intersection(genres)
    
    # Create a new graph with updated subjects
    new_graph = Graph()
    
    for s, p, o in graph:
        if s in overlap:
            new_s = URIRef(str(s) + "_(album)")
        else:
            new_s = s
        new_graph.add((new_s, p, o))
    
    return new_graph

g = disambiguate_albums_and_genres(g)

# %%
g.serialize(destination='musicgraph1.ttl', format='turtle')
# Out:
# <Graph identifier=N86a50f6213b949f58004a3eda0c944cf (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### **`2. Integrate your data with DBpedia's`**
#
# You MUST extend the knowledge you already have on your local KG with the following from DBpedia:
# - band members
# - city of birth of members
# - country of birth of members
# - founding city of the band
# - founding country of the band
#
# You can also add more information regarding albums (optional)
#
#
#
# Recommendations and hints:
# - How to find IRIs from DBpedia that match the entities in the local KG?
#   1) guessing the IRI with simple tricks:
#      - the album 'Rubber Soul' on DBpedia is `dbr:Rubber_Soul`, and this 'translation' may work for other albums (don't do it manually)
#      - the album 'Led Zeppelin' on DBpedia is `dbr:Led_Zeppelin_(album)` as the same name is also associated to the band
#   2) through their `rdfs:label`: for instance, the artist [Amy Winehouse](https://en.wikipedia.org/wiki/Amy_Winehouse) has 'Amy Winehouse' as label on DBpedia and therfore after the matching the IRI of the entity can be extracted
#   3) using the [DBpedia lookup endpoint](https://github.com/dbpedia/lookup). The following request tries to find the DBpedia entity for the artist [Fabrizio De Andrè](https://en.wikipedia.org/wiki/Fabrizio_De_Andr%C3%A9): https://lookup.dbpedia.org/api/search/KeywordSearch?QueryString=fabrizio%20de%20andre&format=json&MaxHits=5
# - restrict the search to entities of type 'Album', 'Band', 'Country', etc, in order to avoid overloading DBPedia's endpoint (see [here](http://mappings.dbpedia.org/server/ontology/classes/) for a list of DBPedia classes) and thus avoid high latency or being banned
# - note that sometimes useful properties to reach entities have the `dbp` prefix which is different from `dbo` ([more info](https://parklize.blogspot.com/2016/05/dbpedia-difference-between-dbo-and-dbp.html)). It's ok to use both
# - here is a **non-exaustive** list of useful properties: `dbp:hometown`, `dbo:birthPlace`, `dbo:country`, `dbo:formerBandMember`
# - how to find properties that link two entities of our interest?
#   1) by checking the [DBpedia ontology](https://akswnc7.informatik.uni-leipzig.de/dstreitmatter/archivo/dbpedia.org/ontology/2023.05.12-020000/ontology_type=parsed.owl) manually
#   2) by checking the DBpedia ontology with Protégé
#   3) using the DBpedia resource pages and exploiting your knowledge (or Wikipedia information). For instance, let us consider [Metallica](https://en.wikipedia.org/wiki/Metallica), I know that [Dave Mustaine](https://en.wikipedia.org/wiki/Dave_Mustaine) was a member, therefore I ask myself: How are these two entities linked in the DBpedia KG? On the [DBpedia page of Metallica](https://dbpedia.org/page/Metallica) we can find that the property used is `dbo:formerBandMember` thus I can use this property to get band members
#   4) running SPARQL queries like the following in the DBpedia endpoint:
#       ```
#       SELECT DISTINCT ?p
#       WHERE {
#         ?s a dbo:Band .
#         ?o a dbo:MusicalArtist .
#         ?s ?p ?o .
#       }
#       ```
#   5) if you are curious enough you can check [ABSTAT](http://abstat.disco.unimib.it/about.html), a tool for KG exploration with a nice interface
# - please notice that DBpedia is not perfect so is reccomendable to check the type of the candidates before including them

# %% [markdown]
# Create a set of all the artists so I do not have to run multiple queries on the same artist.

# %%
unique_artists_complete = dfo['Artist'].unique()

# %% [markdown]
# Check if the artist is a Band, but if it is not try adding _(band) at the end of the URI and run the query again.

# %%
for artist in unique_artists_complete:
    artist_uri = encode_uri("http://dbpedia.org/resource/" + artist)

    # Construct SPARQL query
    query = f"""
    ASK {{
        <{artist_uri}> rdf:type dbo:Band .
    }}
    """
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    
    if results['boolean']:
        print(f"{artist_uri} is a band")
        g.add((URIRef(artist_uri), RDF.type, DBO.Band))
    else:

        # Add _band to the URI and check again
        artist_uri_band = artist_uri + "_(band)"
        query = f"""
        ASK {{
            <{artist_uri_band}> rdf:type dbo:Band .
        }}
        """
        sparql.setQuery(query)
        sparql.setReturnFormat(JSON)
        results = sparql.query().convert()
        
        if results['boolean']:
            print(f"{artist_uri_band} is a band")
            g.add((URIRef(artist_uri_band), RDF.type, DBO.Band))
        else:
            print(f"{artist_uri_band} does not exist as a band in DBpedia")

# %% [markdown]
# For all the URIs where it was necessary to add _(band) at the end of the URI in order to make DBPedia find the
# correct one, replace all the occurrences of the nonband URIs with the _(band) URI.

# %%
def replace_band_uris(graph):
    new_graph = Graph()

    band_uris = [str(s) for s, p, o in graph if str(s).endswith('_(band)')]
    non_band_uris = [uri.replace('_(band)', '') for uri in band_uris]

    for s, p, o in graph:
        
        if type(s) == URIRef and str(s) in non_band_uris:
            s = URIRef(str(s) + '_(band)')

        if type(o) == URIRef and str(o) in non_band_uris:
            o = URIRef(str(o) + '_(band)')

        new_graph.add((s, p, o))
    
    return new_graph

g = replace_band_uris(g)

# %%
def add_band_hometown(graph):
    new_graph = Graph()

    for s, p, o in graph:
        new_graph.add((s, p, o))

        # If the object is dbo:Band, query DBpedia for the band's hometown
        if o == DBO.Band:
            query = f"""
            SELECT ?hometown WHERE {{
                <{s}> dbo:hometown ?hometown .
                # ?hometown a dbo:City .
            }}
            """
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)

            # Execute the query and get the results
            try:
                results = sparql.query().convert()
            except Exception as e:
                print(f"Failed to fetch hometown for band: {s}. Error: {e}")
                continue

            # Add each hometown to the graph
            for result in results["results"]["bindings"]:
                if "hometown" in result:
                    hometown = result["hometown"]["value"]
                    if hometown.startswith("http://dbpedia.org/resource/"):
                        hometown_uri = URIRef(hometown)
                        new_graph.add((s, DBO.hometown, hometown_uri))

    return new_graph

g = add_band_hometown(g)

# %%
def add_band_country_of_origin(graph):
    new_graph = Graph()

    # Iterate over all triples in the graph
    for s, p, o in graph:
        # Add the triple to the new graph
        new_graph.add((s, p, o))

        # If the object is dbo:Band, query DBpedia for the band's country of origin
        if o == DBO.Band:
            query = f"""
            SELECT ?country WHERE {{
                <{s}> dbo:hometown/dbo:country ?country .
                # ?country a dbo:Country .
    
            }}
            """
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)

            # Execute the query and get the results
            try:
                results = sparql.query().convert()
            except Exception as e:
                print(f"Failed to fetch hometown and origin for band: {s}. Error: {e}")
                continue

            # Add each hometown and origin to the graph
            for result in results["results"]["bindings"]:
                if "country" in result:
                    country = result["country"]["value"]
                    if country.startswith("http://dbpedia.org/resource/"):
                        country_uri = URIRef(country)
                        new_graph.add((s, DBO.origin, country_uri))

    return new_graph

g = add_band_country_of_origin(g)

# %%
# Add current and former band members to the graph.
def add_band_members(graph):
    # Create a new graph to store the updated data
    new_graph = Graph()

    # Iterate over all triples in the graph
    for s, p, o in graph:
        # Add the triple to the new graph
        new_graph.add((s, p, o))

        # If the subject is a band, query DBpedia for its members
        if str(o) == str(DBO.Band):
            # Construct the SPARQL queries
            queries = [
                f"""
                SELECT ?member WHERE {{
                    <{s}> dbo:bandMember ?member .
                }}
                """,
                f"""
                SELECT ?member WHERE {{
                    <{s}> dbo:formerBandMember ?member .
                }}
                """
            ]

            for query in queries:
                sparql.setQuery(query)
                sparql.setReturnFormat(JSON)

                # Execute the query and get the results
                try:
                    results = sparql.query().convert()
                except:
                    print(f"Failed to fetch members for band: {s}")
                    continue

                # Determine whether the members are current or former members based on the query
                member_predicate = DBO.bandMember if 'dbo:bandMember' in query else DBO.formerBandMember

                # Add each band member to the graph
                for result in results["results"]["bindings"]:
                    member_uri = URIRef(result["member"]["value"])
                    new_graph.add((s, member_predicate, member_uri))

    return new_graph

g = add_band_members(g)

# %%
def add_birth_cities(graph):
    new_graph = Graph()

    # Iterate over all triples in the graph
    for s, p, o in graph:
        # Add the triple to the new graph
        new_graph.add((s, p, o))

        # If the predicate is bandMember, query DBpedia for the member's city of birth
        if str(p) == str(DBO.bandMember):
            # Construct the SPARQL query
            query = f"""
            SELECT ?city WHERE {{
                <{o}> dbo:birthPlace|dbp:birthPlace ?city .
                # ?city a dbo:City . 
            }}
            """
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)

            # Execute the query and get the results
            try:
                results = sparql.query().convert()
            except:
                print(f"Failed to fetch city of birth for member: {o}")
                continue

            # Add each city of birth to the graph
            for result in results["results"]["bindings"]:
                city = result["city"]["value"]
                if city.startswith("http://dbpedia.org/resource/"):
                    city_uri = URIRef(city)
                    new_graph.add((o, DBO.birthPlace, city_uri))

    return new_graph

g = add_birth_cities(g)

# %%
def add_birth_country(graph):
    new_graph = Graph()

    # Iterate over all triples in the graph
    for s, p, o in graph:
        # Add the triple to the new graph
        new_graph.add((s, p, o))

        # If the predicate is bandMember, query DBpedia for the member's country of birth
        if str(p) == str(DBO.bandMember):
            query = f"""
            SELECT ?country WHERE {{
                <{o}> (dbo:birthPlace|dbp:birthPlace) ?place .
                OPTIONAL {{ ?place (dbo:country|dbp:country) ?country . }}
                FILTER EXISTS {{ ?country a dbo:Country }}.
            }}
            """
            sparql.setQuery(query)
            sparql.setReturnFormat(JSON)

            # Execute the query and get the results
            try:
                results = sparql.query().convert()
            except Exception as e:
                print(f"Failed to fetch country of birth for member: {o}. Error: {e}")
                continue

            # Add each country of birth to the graph
            for result in results["results"]["bindings"]:
                if "country" in result:
                    country = result["country"]["value"]
                    if country.startswith("http://dbpedia.org/resource/"):
                        country_uri = URIRef(country)
                        new_graph.add((o, DBO.country, country_uri))
 
    return new_graph

g = add_birth_country(g)

# %%
g.serialize(destination='musicgraph2.ttl', format='turtle')

# %% [markdown]
# # **`3. Gathering Information from unstructured data`**
#
# Knowledge can be gathered from unstructured data as well as structured data. A great encyclopaedic source is Wikipedia whose articles follow a very strict pattern. For instance, the first lines about a person are reserved for biographical data and his or her occupation, therefore we can exploit it to understand the role of a band member and add this information to our KG.
#
# In steps:
# 1) get the article from Wikipedia and extract the summary. You can use [Wikipedia-api](https://pypi.org/project/Wikipedia-API/) (see the code below)
# 2) extract the band member role (guitarist, bassist, keyboardist, singer, drummer, etc) using rules
# 3) add this information to the KG
#
# Recommendations and hints:
# - some artists have multiple roles, add them all
# - some artists have multiple bands, it is not required to understand the role for each band, keep it simple.
# - extraction rules can be very simple (simple string matchers + if-else)  or more complex ones (e.g., regex, ChatGPT requests), it doesn't matter in terms of points.

# %%
g = Graph()
g.parse('musicgraph2.ttl', format = 'turtle')

# %%
band_member_roles = ["guitarist", "bassist", "keyboardist", "singer", "drummer", "vocalist", "songwriter", "lead vocalist", "lead singer" , "rhythm guitarist", "backing vocalist", "bass guitarist", "lead guitarist", "musician"]

# %%
def extract_band_member_roles(summary, band_member_roles):
    roles = []
    for role in band_member_roles:
        if role.lower() in summary.lower():
            roles.append(role)
    return roles

# %%
def add_band_member_roles(graph):
    new_graph = graph

    # Iterate over each triple in the graph
    for s, p, o in graph:
        if p == URIRef("http://dbpedia.org/ontology/bandMember") or p == URIRef("http://dbpedia.org/ontology/formerBandMember"):
            band_member_uri = str(o)
            band_member_title = urllib.parse.unquote(band_member_uri.split('/')[-1])

            # Get the Wikipedia page for the band member
            wiki_wiki = wikipediaapi.Wikipedia('en')
            page_py = wiki_wiki.page(band_member_title)

            if page_py.exists():
                print("Wikipedia page found for ", o)
                summary = page_py.summary[:200]
                roles = extract_band_member_roles(summary, band_member_roles)

                # Add band member roles to the knowledge graph
                for role in roles:
                    print(f"Adding role '{role}' for band member '{band_member_title}'")
                    new_graph.add((o, EX.role, Literal(role)))
            else:
                print("Wikipedia page not found for ", o)
    return new_graph


g = add_band_member_roles(g)

# %%
g.serialize(destination='musicgraph3.ttl', format='turtle')

# %% [markdown]
# ### **`4. Include a small ontology and a  genres taxonomy`**
#
# Using RDFlib, add classes such as Person, MusicAlbum, and so on to your KG. Add the domain and range for each property you use.
#
# This will be needed later for inferring the types of the entities of your KG.

# %%
g = Graph()
g.parse("musicgraph3.ttl", format="turtle")
# Out:
# <Graph identifier=N81ddbbe745fd446c92dd5591a7e34c74 (<class 'rdflib.graph.Graph'>)>

# %%
OWL = Namespace("http://www.w3.org/2002/07/owl#")

# %%
# Create classes
g.add((DBO.Album, RDF.type, RDFS.Class))
g.add((DBO.Person, RDF.type, RDFS.Class))
g.add((DBO.MusicGenre, RDF.type, RDFS.Class))
g.add((DBO.MusicArtist, RDF.type, RDFS.Class))
g.add((DBO.BandMember, RDF.type, RDFS.Class))
g.add((DBO.City, RDF.type, RDFS.Class))
g.add((DBO.Country, RDF.type, RDFS.Class))
g.add((DBO.Band, RDF.type, RDFS.Class))

# Set domain and range for properties
g.add((DBO.country, RDFS.domain, DBO.BandMember))
g.add((DBO.country, RDFS.range, DBO.Country))

g.add((DBO.birthPlace, RDFS.domain, DBO.BandMember))
g.add((DBO.birthPlace, RDFS.range, DBO.City))

g.add((DBP.genre, RDFS.domain, DBO.Album))
g.add((DBP.genre, RDFS.range, DBO.MusicGenre))

g.add((DBP.subgenre, RDFS.domain, DBO.Album))
g.add((DBP.subgenre, RDFS.range, DBO.MusicGenre))

g.add((DBO.bandMember, RDFS.domain, DBO.Band))
g.add((DBO.bandMember, RDFS.range, DBO.BandMember))

g.add((DBO.formerBandMember, RDFS.domain, DBO.Band))
g.add((DBO.formerBandMember, RDFS.range, DBO.BandMember))

g.add((DBP.artist, RDFS.domain, DBO.Album))
g.add((DBP.artist, RDFS.range, DBO.MusicArtist))

g.add((DBO.origin, RDFS.domain, DBO.Band))
g.add((DBO.origin, RDFS.range, DBO.Country))

g.add((DBO.hometown, RDFS.domain, DBO.Band))
g.add((DBO.hometown, RDFS.range, DBO.City))

g.add((DBP.numberOfRatings, RDFS.domain, DBO.Album))
g.add((DBP.numberOfRatings, RDFS.range, XSD.integer))

g.add((DBP.numberOfReviews, RDFS.domain, DBO.Album))
g.add((DBP.numberOfReviews, RDFS.range, XSD.integer))

g.add((DBP.rating, RDFS.domain, DBO.Album))
g.add((DBP.rating, RDFS.range, XSD.float))

g.add((DBP.year, RDFS.domain, DBO.Album))
g.add((DBP.year, RDFS.range, XSD.gYear))

g.add((DBP.releaseDate, RDFS.domain, DBO.Album))
g.add((DBP.releaseDate, RDFS.range, XSD.date))

g.add((EX.descriptors, RDFS.domain, DBO.Album))
g.add((EX.descriptors, RDFS.range, XSD.string))

g.add((EX.role, RDFS.domain, DBO.BandMember))
g.add((EX.role, RDFS.range, XSD.string))

g.add((DBO.birthPlace, RDFS.domain, DBO.BandMember))
g.add((DBO.birthPlace, RDFS.range, DBO.City))

g.add((DBO.country, RDFS.domain, DBO.BandMember))
g.add((DBO.country, RDFS.range, DBO.Country))

g.add((EX.ratingCategory, RDFS.domain, DBO.Album))
g.add((EX.ratingCategory, RDFS.range, XSD.string))

g.add((DBP.bandGenres, RDFS.domain, DBO.Band))
g.add((DBP.bandGenres, RDFS.range, DBO.MusicGenre))

# Set subClassOf relations
g.add((DBO.Band, RDFS.subClassOf, DBO.MusicArtist))

g.add((DBO.BandMember, RDFS.subClassOf, DBO.Person))
# Out:
# <Graph identifier=N81ddbbe745fd446c92dd5591a7e34c74 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Moreover, the first dataframe has 'Genre' and 'Subgenre' columns.
# Extract a genres taxonomy from the dataset and include it in your RDF KG. This will be needed later for inferring genres from subgenres.
#
# E.g.: add triples to the graph like:
#
# - `[subgenre] rdfs:subClassOf [genre]`.
# - `[album] rdf:type [genre]`.
#
# This should be done for all genres and subgenres (with an iteration, not manually).

# %% [markdown]
# Each word is mapped to its genre. This allows me to infer that rap is a subClassOf Hip Hop, which would not be possible with a simple string matching approach.
# At this stage, I had to make some stylistic choices, such as mapping swing to Jazz and metal to Rock.

# %%
genre_mappings = {
    "rock": "Rock",
    "pop": "Pop",
    "funk": "Funk",
    "soul": "Soul",
    "hop": "Hip_Hop",
    "country": "Country",
    "jazz": "Jazz",
    "latin": "Latin",
    "blues": "Blues",
    "world": "World",
    "classical": "Classical",
    "metal": "Rock",
    "folk": "Folk",
    "reggae": "Reggae",
    "house": "Eleactronic",
    "electronic": "Electronic",
    "punk" : "Rock",
    "grunge" : "Rock",
    "rap" : "Hip_Hop",
    "bop" : "Jazz",
    "swing" : "Jazz"
}

# %%
def get_genre_subgenre_triples(graph, genre_mappings):
    new_triples = []
    
    for s, p, o in graph:
        if p == DBP.genre:
            new_triples.append((s, RDF.type, o))
        if p == DBP.subgenre:
            subgenre = str(o).split('/')[-1].replace("_", " ").lower()
            for genre_key, genre_value in genre_mappings.items():
                if genre_key in subgenre:
                    genre_uri = URIRef('http://dbpedia.org/resource/' + genre_value.replace(" ", "_") + '_music')
                    subgenre_uri = o
                    new_triples.append((subgenre_uri, RDFS.subClassOf, genre_uri))
                new_triples.append((s, RDF.type, o))
    
    return new_triples

# %%
new_triples = get_genre_subgenre_triples(g, genre_mappings)

for triple in new_triples:
    g.add(triple)

# %%
g.serialize("musicgraph4.ttl", format="turtle")

# %% [markdown]
# ### **`5. Materialize inferences`**
#
# Add to your KG inferences that you can make from the data on your KG (e.g., with SPARQL queries, or with OWLRL, ...).
#
# **<ins>Some</ins>**  **<ins>examples</ins>**
# - if you have that `[album] rdf:type [genre1]` and `[genre1] rdfs:subClassOf [genre2]`, add the triple `[album] rdf:type [genre2]`. Same for domains, ranges, subclasses, subproperties, OWL features, etc.
# - if the nationality of a group member is missing, you can infer it from the nationality of the band
#
# Run a few SPARQL queries on the graph to see the inferred triples.

# %%
g = Graph()
g = g.parse("musicgraph4.ttl", format = "turtle")

# %%
owlrl.DeductiveClosure(owlrl.RDFS_OWLRL_Semantics).expand(g)

# %% [markdown]
# As many bandMembers are missing a dbo:country property because it was not possible to retrieve their country of
# origin for some of them, we will infer their dbo:country from the dbo:origin of their band.
# We do that for both bandMembers and formerBandMembers.

# %%
for band in g.subjects(RDF.type, DBO.Band):
    band_country = g.value(band, DBO.origin)
    
    if band_country:
        for band_member in g.objects(band, DBO.bandMember):
            if not g.value(band_member, DBO.country):
                g.add((band_member, DBO.country, band_country))

# %%
for band in g.subjects(RDF.type, DBO.Band):
    band_country = g.value(band, DBO.origin)
    
    if band_country:
        for band_member in g.objects(band, DBO.formerBandMember):
            if not g.value(band_member, DBO.country):
                g.add((band_member, DBO.country, band_country))

# %% [markdown]
# We can add a scale where we can rate the Albums based on their rating between:
#
# > 4-5 : Great
#
# > 3-4 : Good
#
# > 2-3 : Average
#
# > 1-2 : Bad
#
# > 0-1 : Horrible

# %%
for s in g.subjects(RDF.type, DBO.Album):
    rating = g.value(s, DBP.rating)
    if rating is not None:
        
        if 4 <= rating <= 5:
            rating_category = "Great"
        elif 3 <= rating < 4:
            rating_category = "Good"
        elif 2 <= rating < 3:
            rating_category = "Average"
        elif 1 <= rating < 2:
            rating_category = "Bad"
        else:
            rating_category = "Horrible"
        
        g.add((s, EX.ratingCategory, Literal(rating_category)))

# %% [markdown]
# I will add bandGenres triple for bands to later query for bands that have songs in different genres.
# I will infer them from the albums they were dbp:artist of.

# %%
def update_graph_with_bandGenres(graph):

    query = """
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX dbp: <http://dbpedia.org/property/>
    
    CONSTRUCT {
      # ?band dbp:bandGenres ?genre .
    }
    WHERE {
      # ?album dbp:artist ?band ;
              a ?genre .
      # ?genre a dbo:MusicGenre .
      # ?band a dbo:Band .
    }
    """
    
    new_graph = graph.query(query)

    # Merge the new triples with the existing graph
    graph += new_graph

    return graph


g = update_graph_with_bandGenres(g)

# %%
g.serialize("finalmusicgraph2.ttl", format="turtle")
# Out:
# <Graph identifier=Ndf9afdb6d5ae43b0aebcdcdb5b2070a4 (<class 'rdflib.graph.Graph'>)>

# %%
qres = g.query(
    """
    PREFIX ns1: <http://www.example.org/>
    SELECT ?album ?rating_category
    WHERE {
        # ?album ns1:ratingCategory ?rating_category.
    }
    """)

for row in qres:
    print("%s rated as %s" % row)
# Out:
# http://dbpedia.org/resource/!!Destroy-Oh-Boy!! rated as Great
# http://dbpedia.org/resource/#1_Record rated as Great
# http://dbpedia.org/resource/'Allelujah!_Don't_Bend!_Ascend! rated as Great
# http://dbpedia.org/resource/'Frisco_Mabel_Joy rated as Great
# http://dbpedia.org/resource/'Round_About_Midnight rated as Great
# http://dbpedia.org/resource/(A)_Senile_Animal rated as Great
# http://dbpedia.org/resource/(I'm)_Stranded rated as Great
# http://dbpedia.org/resource/(Listen_For)_The_Rag_and_Bone_Man rated as Great
# http://dbpedia.org/resource/(What's_the_Story)_Morning_Glory? rated as Great
# http://dbpedia.org/resource/(_) rated as Great
# http://dbpedia.org/resource/(pronounced_'lĕh-'nérd_'skin-'nérd) rated as Great
# http://dbpedia.org/resource/+'Justments rated as Great
# http://dbpedia.org/resource/...And_Justice_for_All rated as Great
# http://dbpedia.org/resource/...And_Out_Come_the_Wolves rated as Great
# http://dbpedia.org/resource/...And_the_Battle_Begun rated as Great
# http://dbpedia.org/resource/...And_the_Circus_Leaves_Town rated as Great
# http://dbpedia.org/resource/...Doedskvad rated as Great
# http://dbpedia.org/resource/...For_Victory rated as Great
# http://dbpedia.org/resource/...In_Jane_From_Occupied_Europe rated as Great
# http://dbpedia.org/resource/...Like_Clockwork rated as Great
# http://dbpedia.org/resource/...Majestic_Thou_in_Ruin rated as Great
# http://dbpedia.org/resource/...To_Be_Continued rated as Great
# http://dbpedia.org/resource/...and_His_Mother_Called_Him_Bill rated as Great
# http://dbpedia.org/resource////Codename:_Dustsucker rated as Great
# http://dbpedia.org/resource/0 rated as Great
# http://dbpedia.org/resource/01010101 rated as Great
# http://dbpedia.org/resource/0_+_2_=_1 rated as Great
# http://dbpedia.org/resource/10,000_Days rated as Great
# http://dbpedia.org/resource/10.000_anos_depois_entre_Vénus_e_Marte rated as Great
# http://dbpedia.org/resource/10.21 rated as Great
# http://dbpedia.org/resource/1184 rated as Great
# http://dbpedia.org/resource/13 rated as Great
# http://dbpedia.org/resource/1492:_Conquest_of_Paradise rated as Great
# http://dbpedia.org/resource/154 rated as Great
# http://dbpedia.org/resource/16_Lovers_Lane rated as Great
# http://dbpedia.org/resource/187_He_Wrote rated as Great
# http://dbpedia.org/resource/1972 rated as Great
# http://dbpedia.org/resource/1990 rated as Great
# http://dbpedia.org/resource/1996 rated as Great
# http://dbpedia.org/resource/1999 rated as Great
# http://dbpedia.org/resource/2 rated as Great
# http://dbpedia.org/resource/2001 rated as Great
# http://dbpedia.org/resource/2001:_Instrumentals_Only rated as Great
# http://dbpedia.org/resource/2012_-_2017 rated as Great
# http://dbpedia.org/resource/20_palavras_ao_redor_do_Sol rated as Great
# http://dbpedia.org/resource/2112 rated as Great
# http://dbpedia.org/resource/24_Préludes,_Op._28 rated as Great
# http://dbpedia.org/resource/24_Préludes,_Op._28;_Préludes_Nr._25,_Op._45;_Nr._26,_Op._Posth. rated as Great
# http://dbpedia.org/resource/2nd rated as Great
# http://dbpedia.org/resource/330,003_Crossdressers_From_Beyond_the_Rig_Veda rated as Great
# http://dbpedia.org/resource/3_+_3 rated as Great
# http://dbpedia.org/resource/3_Feet_High_and_Rising rated as Great
# http://dbpedia.org/resource/3_Gymnopédies_&_Other_Piano_Works_·_und_andere_Klavierstücke rated as Great
# http://dbpedia.org/resource/3rd rated as Great
# http://dbpedia.org/resource/4,_5,_6 rated as Great
# http://dbpedia.org/resource/4:44 rated as Great
# http://dbpedia.org/resource/4_Balladen;_Barcarolle;_Fantasie rated as Great
# http://dbpedia.org/resource/4_Visions rated as Great
# http://dbpedia.org/resource/4eva_Is_a_Mighty_Long_Time rated as Great
# http://dbpedia.org/resource/5 rated as Great
# http://dbpedia.org/resource/5_by_Monk_by_5 rated as Great
# http://dbpedia.org/resource/666 rated as Great
# http://dbpedia.org/resource/69_Love_Songs rated as Great
# http://dbpedia.org/resource/6_&_12_String_Guitar rated as Great
# http://dbpedia.org/resource/6_Feet_Deep rated as Great
# http://dbpedia.org/resource/6_Pieces_of_Silver rated as Great
# http://dbpedia.org/resource/6_String_Quartets rated as Great
# http://dbpedia.org/resource/7 rated as Great
# http://dbpedia.org/resource/76:14 rated as Great
# http://dbpedia.org/resource/8 rated as Great
# http://dbpedia.org/resource/808s_&_Heartbreak rated as Great
# http://dbpedia.org/resource/8½ rated as Great
# http://dbpedia.org/resource/93_'Til_Infinity rated as Great
# http://dbpedia.org/resource/99.9_F° rated as Great
# http://dbpedia.org/resource/? rated as Great
# http://dbpedia.org/resource/A-Z rated as Great
# http://dbpedia.org/resource/ABC_Music:_The_Radio_1_Sessions rated as Great
# http://dbpedia.org/resource/AFTER_5_CLASH rated as Great
# http://dbpedia.org/resource/ATLiens rated as Great
# http://dbpedia.org/resource/A_18'_del_sol rated as Great
# http://dbpedia.org/resource/A_Beginner's_Mind rated as Great
# http://dbpedia.org/resource/A_Blaze_in_the_Northern_Sky rated as Great
# http://dbpedia.org/resource/A_Boy_Named_Charlie_Brown rated as Great
# http://dbpedia.org/resource/A_Boy_ボーイ rated as Great
# http://dbpedia.org/resource/A_Caress_of_the_Void rated as Great
# http://dbpedia.org/resource/A_Charlie_Brown_Christmas rated as Great
# http://dbpedia.org/resource/A_Christmas_Gift_for_You_From_Philles_Records rated as Great
# http://dbpedia.org/resource/A_Clockwork_Orange rated as Great
# http://dbpedia.org/resource/A_Crow_Looked_at_Me rated as Great
# http://dbpedia.org/resource/A_Dawn_to_Fear rated as Great
# http://dbpedia.org/resource/A_Deeper_Kind_of_Slumber rated as Great
# http://dbpedia.org/resource/A_Different_Kind_of_Tension rated as Great
# http://dbpedia.org/resource/A_Distant_Thunder rated as Great
# http://dbpedia.org/resource/A_Farewell_to_Kings rated as Great
# http://dbpedia.org/resource/A_Flame_to_the_Ground_Beneath rated as Great
# http://dbpedia.org/resource/A_German_Requiem rated as Great
# http://dbpedia.org/resource/A_Ghost_Is_Born rated as Great
# http://dbpedia.org/resource/A_Gift_From_a_Flower_to_a_Garden rated as Great
# http://dbpedia.org/resource/A_Handful_of_Beauty rated as Great
# http://dbpedia.org/resource/A_Hard_Day's_Night rated as Great
# http://dbpedia.org/resource/A_Hard_Road rated as Great
# http://dbpedia.org/resource/A_I_A:_Alien_Observer rated as Great
# http://dbpedia.org/resource/A_Kiss_in_the_Dreamhouse rated as Great
# http://dbpedia.org/resource/A_Little_Man_and_a_House_and_the_Whole_World_Window rated as Great
# http://dbpedia.org/resource/A_Long_Hot_Summer rated as Great
# http://dbpedia.org/resource/A_Love_Supreme rated as Great
# http://dbpedia.org/resource/A_Man_Needs_a_Woman rated as Great
# http://dbpedia.org/resource/A_Man_and_the_Blues rated as Great
# http://dbpedia.org/resource/A_Meeting_by_the_River rated as Great
# http://dbpedia.org/resource/A_Moon_Shaped_Pool rated as Great
# http://dbpedia.org/resource/A_Natural_Disaster rated as Great
# http://dbpedia.org/resource/A_New_Perspective rated as Great
# http://dbpedia.org/resource/A_New_World_Record rated as Great
# http://dbpedia.org/resource/A_Night_at_the_Opera rated as Great
# http://dbpedia.org/resource/A_Night_in_Tunisia rated as Great
# http://dbpedia.org/resource/A_Pagan_Place rated as Great
# http://dbpedia.org/resource/A_Piece_of_Strange rated as Great
# http://dbpedia.org/resource/A_Pleasant_Shade_of_Gray rated as Great
# http://dbpedia.org/resource/A_Prince_Among_Thieves rated as Great
# http://dbpedia.org/resource/A_Promise rated as Great
# http://dbpedia.org/resource/A_Rainbow_in_Curved_Air rated as Great
# http://dbpedia.org/resource/A_River_Ain't_Too_Much_to_Love rated as Great
# http://dbpedia.org/resource/A_Saucerful_of_Secrets rated as Great
# http://dbpedia.org/resource/A_Secret_Wish rated as Great
# http://dbpedia.org/resource/A_Single_Man rated as Great
# http://dbpedia.org/resource/A_Social_Grace rated as Great
# http://dbpedia.org/resource/A_Sombre_Dance rated as Great
# http://dbpedia.org/resource/A_Space_in_Time rated as Great
# http://dbpedia.org/resource/A_Sultans_Ransom rated as Great
# http://dbpedia.org/resource/A_Sun_That_Never_Sets rated as Great
# http://dbpedia.org/resource/A_Swingin'_Affair! rated as Great
# http://dbpedia.org/resource/A_Tab_in_the_Ocean rated as Great
# http://dbpedia.org/resource/A_Third_of_a_Lifetime rated as Great
# http://dbpedia.org/resource/A_Tiny_House,_in_Secret_Speeches,_Polar_Equals rated as Great
# http://dbpedia.org/resource/A_Tribute_to_Jack_Johnson rated as Great
# http://dbpedia.org/resource/A_Trick_of_the_Tail rated as Great
# http://dbpedia.org/resource/A_Tábua_de_Esmeralda rated as Great
# http://dbpedia.org/resource/A_Via-Láctea rated as Great
# http://dbpedia.org/resource/A_Walk_Across_the_Rooftops rated as Great
# http://dbpedia.org/resource/A_Wizard,_a_True_Star rated as Great
# http://dbpedia.org/resource/A_dança_da_solidão rated as Great
# http://dbpedia.org/resource/A_divina_comédia_ou_ando_meio_desligado rated as Great
# http://dbpedia.org/resource/A_mulher_do_fim_do_mundo rated as Great
# http://dbpedia.org/resource/A_peleja_do_Diabo_com_o_dono_do_céu rated as Great
# http://dbpedia.org/resource/A_toda_Cuba_le_gusta rated as Great
# http://dbpedia.org/resource/Aaliyah_(album) rated as Great
# http://dbpedia.org/resource/Abandon_All_Life rated as Great
# http://dbpedia.org/resource/Abattoir_Blues_/_The_Lyre_of_Orpheus rated as Great
# http://dbpedia.org/resource/Abbey_Is_Blue rated as Great
# http://dbpedia.org/resource/Abbey_Road rated as Great
# http://dbpedia.org/resource/Abigail rated as Great
# http://dbpedia.org/resource/Above rated as Great
# http://dbpedia.org/resource/Above_the_Weeping_World rated as Great
# http://dbpedia.org/resource/Abraxas rated as Great
# http://dbpedia.org/resource/Absence rated as Great
# http://dbpedia.org/resource/Absent_Friends rated as Great
# http://dbpedia.org/resource/Absolutely_Free rated as Great
# http://dbpedia.org/resource/Abyss rated as Great
# http://dbpedia.org/resource/Acabou_chorare rated as Great
# http://dbpedia.org/resource/Accelerated_Evolution rated as Great
# http://dbpedia.org/resource/Accident_of_Birth rated as Great
# http://dbpedia.org/resource/Ace_of_Spades rated as Great
# http://dbpedia.org/resource/Achievement rated as Great
# http://dbpedia.org/resource/Achtung_Baby rated as Great
# http://dbpedia.org/resource/Acquiring_the_Taste rated as Great
# http://dbpedia.org/resource/Across_the_Dark rated as Great
# http://dbpedia.org/resource/Act_II:_The_Father_of_Death rated as Great
# http://dbpedia.org/resource/Act_II:_The_Meaning_of,_and_All_Things_Regarding_Ms._Leading rated as Great
# http://dbpedia.org/resource/Act_IV:_Rebirth_in_Reprise rated as Great
# http://dbpedia.org/resource/Actor rated as Great
# http://dbpedia.org/resource/Actos_inexplicables rated as Great
# http://dbpedia.org/resource/Actually rated as Great
# http://dbpedia.org/resource/Adam's_Apple rated as Great
# http://dbpedia.org/resource/Addicted rated as Great
# http://dbpedia.org/resource/Adelie_Land rated as Great
# http://dbpedia.org/resource/Adiós_Nonino rated as Great
# http://dbpedia.org/resource/Adoniran_Barbosa_(album) rated as Great
# http://dbpedia.org/resource/Adventures_in_Paradise rated as Great
# http://dbpedia.org/resource/Aerial rated as Great
# http://dbpedia.org/resource/Aerial_Ballet rated as Great
# http://dbpedia.org/resource/Affinità-divergenze_fra_il_compagno_Togliatti_e_noi:_Del_conseguimento_della_maggiore_età rated as Great
# http://dbpedia.org/resource/Afreaka! rated as Great
# http://dbpedia.org/resource/Africa_/_Brass rated as Great
# http://dbpedia.org/resource/Africa_Express_Presents..._Terry_Riley's_In_C_Mali rated as Great
# http://dbpedia.org/resource/Africa_Must_Be_Free_by_1983 rated as Great
# http://dbpedia.org/resource/Afro-Cuban_(album) rated as Great
# http://dbpedia.org/resource/Afrociberdelia rated as Great
# http://dbpedia.org/resource/Afrodisiac rated as Great
# http://dbpedia.org/resource/After rated as Great
# http://dbpedia.org/resource/After_Bathing_at_Baxter's rated as Great
# http://dbpedia.org/resource/After_Midnight rated as Great
# http://dbpedia.org/resource/After_chabón rated as Great
# http://dbpedia.org/resource/After_the_Gold_Rush rated as Great
# http://dbpedia.org/resource/After_the_Rain rated as Great
# http://dbpedia.org/resource/Aftermath rated as Great
# http://dbpedia.org/resource/Against_the_Grain rated as Great
# http://dbpedia.org/resource/Agent_Orange_(album) rated as Great
# http://dbpedia.org/resource/Ain't_That_Good_News rated as Great
# http://dbpedia.org/resource/Ainda rated as Great
# http://dbpedia.org/resource/Aion rated as Great
# http://dbpedia.org/resource/Aion;_Pfhat;_Konx-Om-Pax rated as Great
# http://dbpedia.org/resource/Aja rated as Great
# http://dbpedia.org/resource/Akhnaten rated as Great
# http://dbpedia.org/resource/Akira rated as Great
# http://dbpedia.org/resource/Al_Green_Explores_Your_Mind rated as Great
# http://dbpedia.org/resource/Al_Green_Gets_Next_to_You rated as Great
# http://dbpedia.org/resource/Al_final_de_este_viaje... rated as Great
# http://dbpedia.org/resource/Aladdin_Sane rated as Great
# http://dbpedia.org/resource/Alan_Vega_·_Martin_Rev rated as Great
# http://dbpedia.org/resource/Album:_Generic_Flipper rated as Great
# http://dbpedia.org/resource/Alenar rated as Great
# http://dbpedia.org/resource/Alfredo rated as Great
# http://dbpedia.org/resource/Alice rated as Great
# http://dbpedia.org/resource/Alice_in_Chains_(album) rated as Great
# http://dbpedia.org/resource/Alice_in_Hell rated as Great
# http://dbpedia.org/resource/Alien rated as Great
# http://dbpedia.org/resource/Alien_Lanes rated as Great
# http://dbpedia.org/resource/Alina rated as Great
# http://dbpedia.org/resource/All rated as Great
# http://dbpedia.org/resource/All_'n_All rated as Great
# http://dbpedia.org/resource/All_American_Music rated as Great
# http://dbpedia.org/resource/All_Bitches_Die rated as Great
# http://dbpedia.org/resource/All_Eyez_on_Me rated as Great
# http://dbpedia.org/resource/All_Hail_West_Texas rated as Great
# http://dbpedia.org/resource/All_Mod_Cons rated as Great
# http://dbpedia.org/resource/All_My_Heroes_Are_Cornballs rated as Great
# http://dbpedia.org/resource/All_Things_Must_Pass rated as Great
# http://dbpedia.org/resource/All_We_Got_Iz_Us rated as Great
# http://dbpedia.org/resource/All_We_Love_We_Leave_Behind rated as Great
# http://dbpedia.org/resource/All_of_the_Above rated as Great
# http://dbpedia.org/resource/All_the_Footprints_You've_Ever_Left_and_the_Fear_Expecting_Ahead rated as Great
# http://dbpedia.org/resource/All_the_Pretty_Little_Horses rated as Great
# http://dbpedia.org/resource/Alligator rated as Great
# http://dbpedia.org/resource/Alma_de_diamante rated as Great
# http://dbpedia.org/resource/Almendra_(album) rated as Great
# http://dbpedia.org/resource/Almoraima rated as Great
# http://dbpedia.org/resource/Alone rated as Great
# http://dbpedia.org/resource/Alphataurus_(album) rated as Great
# http://dbpedia.org/resource/Altars_of_Madness rated as Great
# http://dbpedia.org/resource/Alternative_4 rated as Great
# http://dbpedia.org/resource/Alturas_de_Machu_Pichu rated as Great
# http://dbpedia.org/resource/Alucinação rated as Great
# http://dbpedia.org/resource/Amadeus rated as Great
# http://dbpedia.org/resource/Amarcord rated as Great
# http://dbpedia.org/resource/Amarok rated as Great
# http://dbpedia.org/resource/Amber rated as Great
# http://dbpedia.org/resource/Ambient_1:_Music_for_Airports rated as Great
# http://dbpedia.org/resource/Ambient_2:_The_Plateaux_of_Mirror rated as Great
# http://dbpedia.org/resource/Ambient_4:_Isolationism rated as Great
# http://dbpedia.org/resource/Ambient_4:_On_Land rated as Great
# http://dbpedia.org/resource/AmeriKKKa's_Most_Wanted rated as Great
# http://dbpedia.org/resource/America rated as Great
# http://dbpedia.org/resource/American_Beauty rated as Great
# http://dbpedia.org/resource/American_Football_(album) rated as Great
# http://dbpedia.org/resource/American_III:_Solitary_Man rated as Great
# http://dbpedia.org/resource/American_IV:_The_Man_Comes_Around rated as Great
# http://dbpedia.org/resource/American_Nervoso rated as Great
# http://dbpedia.org/resource/American_Recordings rated as Great
# http://dbpedia.org/resource/American_V:_A_Hundred_Highways rated as Great
# http://dbpedia.org/resource/American_Water rated as Great
# http://dbpedia.org/resource/Amnesiac rated as Great
# http://dbpedia.org/resource/Among_the_Living rated as Great
# http://dbpedia.org/resource/Amoroso rated as Great
# http://dbpedia.org/resource/Ample_Destruction rated as Great
# http://dbpedia.org/resource/Amplifier_Worship rated as Great
# http://dbpedia.org/resource/An_Ancient_Muse rated as Great
# http://dbpedia.org/resource/An_Empty_Bliss_Beyond_This_World rated as Great
# http://dbpedia.org/resource/An_Evil_Heat rated as Great
# http://dbpedia.org/resource/An_Invisible_World_Revealed rated as Great
# http://dbpedia.org/resource/Anabelas rated as Great
# http://dbpedia.org/resource/Ancestors_Call rated as Great
# http://dbpedia.org/resource/Ancient_Dreams rated as Great
# http://dbpedia.org/resource/And_Their_Refinement_of_the_Decline rated as Great
# http://dbpedia.org/resource/And_Then_Nothing_Turned_Itself_Inside-Out rated as Great
# http://dbpedia.org/resource/And_the_Cannons_of_Destruction_Have_Begun... rated as Great
# http://dbpedia.org/resource/And_the_Glass_Handed_Kites rated as Great
# http://dbpedia.org/resource/Andrew_Bird_&_The_Mysterious_Production_of_Eggs rated as Great
# http://dbpedia.org/resource/Andy_Irvine_&_Paul_Brady_(album) rated as Great
# http://dbpedia.org/resource/Angel's_Egg rated as Great
# http://dbpedia.org/resource/Angel_Dust rated as Great
# http://dbpedia.org/resource/Angel_Song rated as Great
# http://dbpedia.org/resource/Angel_Witch_(album) rated as Great
# http://dbpedia.org/resource/Angel_of_Salvation rated as Great
# http://dbpedia.org/resource/Angels_and_Daemons_at_Play rated as Great
# http://dbpedia.org/resource/Angels_of_Distress rated as Great
# http://dbpedia.org/resource/Anima_latina rated as Great
# http://dbpedia.org/resource/Animals rated as Great
# http://dbpedia.org/resource/Anime_salve rated as Great
# http://dbpedia.org/resource/Annihilation_of_the_Wicked rated as Great
# http://dbpedia.org/resource/Anno_Domini_High_Definition rated as Great
# http://dbpedia.org/resource/Anodyne rated as Great
# http://dbpedia.org/resource/Another_Green_World rated as Great
# http://dbpedia.org/resource/Another_Music_in_a_Different_Kitchen rated as Great
# http://dbpedia.org/resource/Another_Perfect_Day rated as Great
# http://dbpedia.org/resource/Another_Side_of_Bob_Dylan rated as Great
# http://dbpedia.org/resource/Another_Thought rated as Great
# http://dbpedia.org/resource/Anthems_to_the_Welkin_at_Dusk rated as Great
# http://dbpedia.org/resource/Anthology_(Movie_Themes_1974-1998) rated as Great
# http://dbpedia.org/resource/Anti-Kahraman:_90_Nesli rated as Great
# http://dbpedia.org/resource/Anticapital rated as Great
# http://dbpedia.org/resource/Antisocialites rated as Great
# http://dbpedia.org/resource/Antithesis_of_Light rated as Great
# http://dbpedia.org/resource/Any_Other_City rated as Great
# http://dbpedia.org/resource/Apocalypse_91...The_Enemy_Strikes_Black rated as Great
# http://dbpedia.org/resource/Apocalypse_Now rated as Great
# http://dbpedia.org/resource/Apollo:_Atmospheres_&_Soundtracks rated as Great
# http://dbpedia.org/resource/Apollo_18 rated as Great
# http://dbpedia.org/resource/Apologies_to_the_Queen_Mary rated as Great
# http://dbpedia.org/resource/Apostrophe_(') rated as Great
# http://dbpedia.org/resource/Appetite_for_Destruction rated as Great
# http://dbpedia.org/resource/Apple_Venus_Volume_1 rated as Great
# http://dbpedia.org/resource/April_in_Paris rated as Great
# http://dbpedia.org/resource/Aqualung rated as Great
# http://dbpedia.org/resource/Aquatic rated as Great
# http://dbpedia.org/resource/Aquemini rated as Great
# http://dbpedia.org/resource/Arachnoïd_(album) rated as Great
# http://dbpedia.org/resource/Arbeit_macht_frei rated as Great
# http://dbpedia.org/resource/Arbos rated as Great
# http://dbpedia.org/resource/Arcane_Rain_Fell rated as Great
# http://dbpedia.org/resource/Architecture_&_Morality rated as Great
# http://dbpedia.org/resource/Are_You_Experienced rated as Great
# http://dbpedia.org/resource/Aretha_Now rated as Great
# http://dbpedia.org/resource/Argus rated as Great
# http://dbpedia.org/resource/Argybargy rated as Great
# http://dbpedia.org/resource/Arise rated as Great
# http://dbpedia.org/resource/Arizona_Bay rated as Great
# http://dbpedia.org/resource/Armageddon_(album) rated as Great
# http://dbpedia.org/resource/Armchair_Boogie rated as Great
# http://dbpedia.org/resource/Armed_Forces rated as Great
# http://dbpedia.org/resource/Arnold_Schoenberg_2:_Streichquartette_I-IV rated as Great
# http://dbpedia.org/resource/Arntor rated as Great
# http://dbpedia.org/resource/Around_the_Fur rated as Great
# http://dbpedia.org/resource/Around_the_World_in_a_Day rated as Great
# http://dbpedia.org/resource/Art_Angels rated as Great
# http://dbpedia.org/resource/Art_Blakey's_Jazz_Messengers_With_Thelonious_Monk_(album) rated as Great
# http://dbpedia.org/resource/Art_Blakey_and_The_Jazz_Messengers_[Moanin'] rated as Great
# http://dbpedia.org/resource/Art_Pepper_Meets_the_Rhythm_Section rated as Great
# http://dbpedia.org/resource/Artaud rated as Great
# http://dbpedia.org/resource/Arthur_Verocai_(album) rated as Great
# http://dbpedia.org/resource/Arthur_or_the_Decline_and_Fall_of_the_British_Empire rated as Great
# http://dbpedia.org/resource/Arular rated as Great
# http://dbpedia.org/resource/As_Falls_Wichita,_So_Falls_Wichita_Falls rated as Great
# http://dbpedia.org/resource/As_the_Weird_Travel_On rated as Great
# http://dbpedia.org/resource/Asante rated as Great
# http://dbpedia.org/resource/Ascenseur_pour_l'échafaud rated as Great
# http://dbpedia.org/resource/Ascension_[Edition_II] rated as Great
# http://dbpedia.org/resource/Ascension_[Edition_I] rated as Great
# http://dbpedia.org/resource/Ash_Ra_Tempel_(album) rated as Great
# http://dbpedia.org/resource/Ashes_2_Ashes,_Dust_2_Dust rated as Great
# http://dbpedia.org/resource/Ashes_Against_the_Grain rated as Great
# http://dbpedia.org/resource/Ashes_Are_Burning rated as Great
# http://dbpedia.org/resource/Ask_the_Ages rated as Great
# http://dbpedia.org/resource/Astigmatic rated as Great
# http://dbpedia.org/resource/Astral_Weeks rated as Great
# http://dbpedia.org/resource/Asylum rated as Great
# http://dbpedia.org/resource/At_Action_Park rated as Great
# http://dbpedia.org/resource/At_Basin_Street rated as Great
# http://dbpedia.org/resource/At_Last! rated as Great
# http://dbpedia.org/resource/At_the_Heart_of_Winter rated as Great
# http://dbpedia.org/resource/Atom_Heart_Mother rated as Great
# http://dbpedia.org/resource/Atomizer rated as Great
# http://dbpedia.org/resource/Atrocity_Exhibition rated as Great
# http://dbpedia.org/resource/Attack_of_the_Grey_Lantern rated as Great
# http://dbpedia.org/resource/Au-delà_du_délire rated as Great
# http://dbpedia.org/resource/Aura rated as Great
# http://dbpedia.org/resource/Aurora rated as Great
# http://dbpedia.org/resource/Aus_den_sieben_Tagen rated as Great
# http://dbpedia.org/resource/Autechre_[LP5] rated as Great
# http://dbpedia.org/resource/Autobahn rated as Great
# http://dbpedia.org/resource/Automatic_for_the_People rated as Great
# http://dbpedia.org/resource/Autumn_Aurora rated as Great
# http://dbpedia.org/resource/Autumn_Eternal rated as Great
# http://dbpedia.org/resource/Avalancha rated as Great
# http://dbpedia.org/resource/Avalon rated as Great
# http://dbpedia.org/resource/Avalon_Sutra_/_As_Long_As_I_Can_Hold_My_Breath rated as Great
# http://dbpedia.org/resource/Aviary rated as Great
# http://dbpedia.org/resource/Awake rated as Great
# http://dbpedia.org/resource/Awaken_the_Guardian rated as Great
# http://dbpedia.org/resource/Awakening_the_World rated as Great
# http://dbpedia.org/resource/Axe_to_Fall rated as Great
# http://dbpedia.org/resource/Axioma_Ethica_Odini rated as Great
# http://dbpedia.org/resource/Axis:_Bold_as_Love rated as Great
# http://dbpedia.org/resource/Aégis rated as Great
# http://dbpedia.org/resource/Baazaar rated as Great
# http://dbpedia.org/resource/Babylon_by_Gus,_Vol_1:_O_ano_do_macaco rated as Great
# http://dbpedia.org/resource/Bachelor_No._2_(Or,_the_Last_Remains_of_the_Dodo) rated as Great
# http://dbpedia.org/resource/Back_Porch_Bluegrass rated as Great
# http://dbpedia.org/resource/Back_Stabbers rated as Great
# http://dbpedia.org/resource/Back_in_Black rated as Great
# http://dbpedia.org/resource/Back_to_Back:_Duke_Ellington_and_Johnny_Hodges_Play_the_Blues rated as Great
# http://dbpedia.org/resource/Back_to_Black rated as Great
# http://dbpedia.org/resource/Back_to_Times_of_Splendor rated as Great
# http://dbpedia.org/resource/Back_to_the_World rated as Great
# http://dbpedia.org/resource/Bad rated as Great
# http://dbpedia.org/resource/Bad_Brains_(album) rated as Great
# http://dbpedia.org/resource/Bad_Girls rated as Great
# http://dbpedia.org/resource/Bad_Love rated as Great
# http://dbpedia.org/resource/Bad_News_Is_Coming rated as Great
# http://dbpedia.org/resource/Bad_Reputation rated as Great
# http://dbpedia.org/resource/Bad_Timing rated as Great
# http://dbpedia.org/resource/Badmotorfinger rated as Great
# http://dbpedia.org/resource/Baduizm rated as Great
# http://dbpedia.org/resource/Bakesale rated as Great
# http://dbpedia.org/resource/Ballads rated as Great
# http://dbpedia.org/resource/Balladyna rated as Great
# http://dbpedia.org/resource/Balls_to_the_Wall rated as Great
# http://dbpedia.org/resource/Banco_del_Mutuo_Soccorso_(album) rated as Great
# http://dbpedia.org/resource/Band_on_the_Run rated as Great
# http://dbpedia.org/resource/Bandana rated as Great
# http://dbpedia.org/resource/Bandolier rated as Great
# http://dbpedia.org/resource/Bandwagonesque rated as Great
# http://dbpedia.org/resource/Banjo-Kazooie rated as Great
# http://dbpedia.org/resource/Banquet_in_the_Darkness rated as Great
# http://dbpedia.org/resource/Bar_Kokhba_(album) rated as Great
# http://dbpedia.org/resource/Barbaro_(ma_non_troppo) rated as Great
# http://dbpedia.org/resource/Bare_Knuckle rated as Great
# http://dbpedia.org/resource/Bare_Nuckle_II rated as Great
# http://dbpedia.org/resource/Barefoot_Boy rated as Great
# http://dbpedia.org/resource/Barndomens_Stigar rated as Great
# http://dbpedia.org/resource/Barry_Lyndon rated as Great
# http://dbpedia.org/resource/Basie rated as Great
# http://dbpedia.org/resource/Basket_of_Light rated as Great
# http://dbpedia.org/resource/Basra rated as Great
# http://dbpedia.org/resource/Bass_Culture rated as Great
# http://dbpedia.org/resource/Bass_on_Top rated as Great
# http://dbpedia.org/resource/Bastards rated as Great
# http://dbpedia.org/resource/Bastion rated as Great
# http://dbpedia.org/resource/Bath rated as Great
# http://dbpedia.org/resource/Batman rated as Great
# http://dbpedia.org/resource/Batman_Returns rated as Great
# http://dbpedia.org/resource/Battle_Cry rated as Great
# http://dbpedia.org/resource/Bayou_Country rated as Great
# http://dbpedia.org/resource/Be rated as Great
# http://dbpedia.org/resource/Be_Forewarned rated as Great
# http://dbpedia.org/resource/Beasts_of_No_Nation rated as Great
# http://dbpedia.org/resource/Beaucoup_Fish rated as Great
# http://dbpedia.org/resource/Beauty_Reaps_the_Blood_of_Solitude rated as Great
# http://dbpedia.org/resource/Beauty_and_the_Beast rated as Great
# http://dbpedia.org/resource/Beauty_and_the_Beat rated as Great
# http://dbpedia.org/resource/Bee_Thousand rated as Great
# http://dbpedia.org/resource/Before_and_After_Science rated as Great
# http://dbpedia.org/resource/Befriended rated as Great
# http://dbpedia.org/resource/Beggars_Banquet rated as Great
# http://dbpedia.org/resource/Begin rated as Great
# http://dbpedia.org/resource/Behaviour rated as Great
# http://dbpedia.org/resource/Behind_the_Realms_of_Madness rated as Great
# http://dbpedia.org/resource/Being_There rated as Great
# http://dbpedia.org/resource/Believe_It rated as Great
# http://dbpedia.org/resource/Bells,_Boots_and_Shambles rated as Great
# http://dbpedia.org/resource/Bellybutton rated as Great
# http://dbpedia.org/resource/Belonging rated as Great
# http://dbpedia.org/resource/Below_the_Heavens rated as Great
# http://dbpedia.org/resource/Below_the_Lights rated as Great
# http://dbpedia.org/resource/Below_the_Salt rated as Great
# http://dbpedia.org/resource/Ben rated as Great
# http://dbpedia.org/resource/Ben_Webster_Meets_Oscar_Peterson rated as Great
# http://dbpedia.org/resource/Bend_Sinister rated as Great
# http://dbpedia.org/resource/Beneath_the_Remains rated as Great
# http://dbpedia.org/resource/Benefit rated as Great
# http://dbpedia.org/resource/Benji rated as Great
# http://dbpedia.org/resource/Bergtatt:_Et_eeventyr_i_5_capitler rated as Great
# http://dbpedia.org/resource/Berry_Is_on_Top rated as Great
# http://dbpedia.org/resource/Betty_Davis_(album) rated as Great
# http://dbpedia.org/resource/Beverly_Glenn-Copeland_(album) rated as Great
# http://dbpedia.org/resource/Beyond_the_Crimson_Horizon rated as Great
# http://dbpedia.org/resource/Beyond_the_Veil rated as Great
# http://dbpedia.org/resource/Białe_wakacje rated as Great
# http://dbpedia.org/resource/Bicho rated as Great
# http://dbpedia.org/resource/Bicicleta rated as Great
# http://dbpedia.org/resource/Big_Fun rated as Great
# http://dbpedia.org/resource/Big_Science rated as Great
# http://dbpedia.org/resource/Big_Wave rated as Great
# http://dbpedia.org/resource/Biglietto_per_l'Inferno_(album) rated as Great
# http://dbpedia.org/resource/Bilateral rated as Great
# http://dbpedia.org/resource/Bill_Fay_(album) rated as Great
# http://dbpedia.org/resource/Billie_Holiday_(album) rated as Great
# http://dbpedia.org/resource/Billion_Dollar_Babies rated as Great
# http://dbpedia.org/resource/Biomech rated as Great
# http://dbpedia.org/resource/Bir_Pesimistin_Gözyaşları rated as Great
# http://dbpedia.org/resource/Birds_of_Fire rated as Great
# http://dbpedia.org/resource/Birthday_Blues rated as Great
# http://dbpedia.org/resource/Bitches_Brew rated as Great
# http://dbpedia.org/resource/Bitter_Funeral_Beer rated as Great
# http://dbpedia.org/resource/Bizarre_Ride_II_the_Pharcyde rated as Great
# http://dbpedia.org/resource/Bizarro rated as Great
# http://dbpedia.org/resource/Bl_ck_B_st_rds rated as Great
# http://dbpedia.org/resource/Black_Antlers rated as Great
# http://dbpedia.org/resource/Black_Celebration rated as Great
# http://dbpedia.org/resource/Black_Earth rated as Great
# http://dbpedia.org/resource/Black_Fire rated as Great
# http://dbpedia.org/resource/Black_Foliage:_Animation_Music_Volume_1 rated as Great
# http://dbpedia.org/resource/Black_Future rated as Great
# http://dbpedia.org/resource/Black_Hand_Inn rated as Great
# http://dbpedia.org/resource/Black_Hole_/_Blank_Canvas rated as Great
# http://dbpedia.org/resource/Black_Love rated as Great
# http://dbpedia.org/resource/Black_Market rated as Great
# http://dbpedia.org/resource/Black_Messiah rated as Great
# http://dbpedia.org/resource/Black_Metal_(album) rated as Great
# http://dbpedia.org/resource/Black_Monk_Time rated as Great
# http://dbpedia.org/resource/Black_Moses rated as Great
# http://dbpedia.org/resource/Black_Rose:_A_Rock_Legend rated as Great
# http://dbpedia.org/resource/Black_Sabbath_(album) rated as Great
# http://dbpedia.org/resource/Black_Sabbath_Vol._4 rated as Great
# http://dbpedia.org/resource/Black_Saint rated as Great
# http://dbpedia.org/resource/Black_Sea rated as Great
# http://dbpedia.org/resource/Black_Sheep_Boy rated as Great
# http://dbpedia.org/resource/Black_Unity rated as Great
# http://dbpedia.org/resource/Black_Up rated as Great
# http://dbpedia.org/resource/Black_Woman rated as Great
# http://dbpedia.org/resource/Black_in_Mind rated as Great
# http://dbpedia.org/resource/Black_on_Both_Sides rated as Great
# http://dbpedia.org/resource/Blackheart_Man rated as Great
# http://dbpedia.org/resource/Blacklisted rated as Great
# http://dbpedia.org/resource/Blackout_(album) rated as Great
# http://dbpedia.org/resource/Blackwater_Park rated as Great
# http://dbpedia.org/resource/Blank_Generation rated as Great
# http://dbpedia.org/resource/Blasphemy_Made_Flesh rated as Great
# http://dbpedia.org/resource/Blast_From_the_Past rated as Great
# http://dbpedia.org/resource/Blast_Tyrant rated as Great
# http://dbpedia.org/resource/Blazing_Arrow rated as Great
# http://dbpedia.org/resource/Bleeding rated as Great
# http://dbpedia.org/resource/Bless_the_Weather rated as Great
# http://dbpedia.org/resource/Blessed_Are_the_Sick rated as Great
# http://dbpedia.org/resource/Blessing_in_Disguise rated as Great
# http://dbpedia.org/resource/Bleu_pétrole rated as Great
# http://dbpedia.org/resource/Blind_Faith_(album) rated as Great
# http://dbpedia.org/resource/Blinking_Lights_and_Other_Revelations rated as Great
# http://dbpedia.org/resource/Blissard rated as Great
# http://dbpedia.org/resource/Blizzard_of_Ozz rated as Great
# http://dbpedia.org/resource/Blod-draum rated as Great
# http://dbpedia.org/resource/Blonde rated as Great
# http://dbpedia.org/resource/Blonde_on_Blonde rated as Great
# http://dbpedia.org/resource/Blood_&_Chocolate rated as Great
# http://dbpedia.org/resource/Blood_Fire_Death rated as Great
# http://dbpedia.org/resource/Blood_Lust rated as Great
# http://dbpedia.org/resource/Blood_Money rated as Great
# http://dbpedia.org/resource/Blood_Mountain rated as Great
# http://dbpedia.org/resource/Blood_Sugar_Sex_Magik rated as Great
# http://dbpedia.org/resource/Blood_Visions rated as Great
# http://dbpedia.org/resource/Blood_on_the_Tracks rated as Great
# http://dbpedia.org/resource/Bloodborne rated as Great
# http://dbpedia.org/resource/Bloody_Kisses rated as Great
# http://dbpedia.org/resource/Bloom rated as Great
# http://dbpedia.org/resource/Blow_by_Blow rated as Great
# http://dbpedia.org/resource/Blowin'_the_Blues_Away rated as Great
# http://dbpedia.org/resource/Blowing_In_From_Chicago rated as Great
# http://dbpedia.org/resource/Blowout_Comb rated as Great
# http://dbpedia.org/resource/Blue rated as Great
# http://dbpedia.org/resource/Blue_&_Sentimental rated as Great
# http://dbpedia.org/resource/Blue_Afternoon rated as Great
# http://dbpedia.org/resource/Blue_Bell_Knoll rated as Great
# http://dbpedia.org/resource/Blue_Lines rated as Great
# http://dbpedia.org/resource/Blue_Screen_Life rated as Great
# http://dbpedia.org/resource/Blue_Train rated as Great
# http://dbpedia.org/resource/Blue_Valentine rated as Great
# http://dbpedia.org/resource/Blue_Velvet rated as Great
# http://dbpedia.org/resource/Blue_Öyster_Cult_(album) rated as Great
# http://dbpedia.org/resource/Blues rated as Great
# http://dbpedia.org/resource/Blues-ette rated as Great
# http://dbpedia.org/resource/Blues_&_Roots rated as Great
# http://dbpedia.org/resource/Blues_Breakers rated as Great
# http://dbpedia.org/resource/Blues_From_Laurel_Canyon rated as Great
# http://dbpedia.org/resource/Blues_From_the_Gutter rated as Great
# http://dbpedia.org/resource/Blues_Walk rated as Great
# http://dbpedia.org/resource/Blues_for_the_Red_Sun rated as Great
# http://dbpedia.org/resource/Blues_in_Orbit rated as Great
# http://dbpedia.org/resource/Bluffer's_Guide_to_the_Flight_Deck rated as Great
# http://dbpedia.org/resource/Blush_Music rated as Great
# http://dbpedia.org/resource/Bocanada rated as Great
# http://dbpedia.org/resource/Body_Meta rated as Great
# http://dbpedia.org/resource/Body_and_Soul rated as Great
# http://dbpedia.org/resource/Bomber rated as Great
# http://dbpedia.org/resource/Bomberman_Hero rated as Great
# http://dbpedia.org/resource/Bonded_by_Blood rated as Great
# http://dbpedia.org/resource/Bone_Machine rated as Great
# http://dbpedia.org/resource/Bookends rated as Great
# http://dbpedia.org/resource/Boris_at_Last_-Feedbacker- rated as Great
# http://dbpedia.org/resource/Born_Into_Trouble_as_the_Sparks_Fly_Upward. rated as Great
# http://dbpedia.org/resource/Born_Under_a_Bad_Sign rated as Great
# http://dbpedia.org/resource/Born_in_the_U.S.A. rated as Great
# http://dbpedia.org/resource/Born_to_Run rated as Great
# http://dbpedia.org/resource/Bossanova rated as Great
# http://dbpedia.org/resource/Boston_(album) rated as Great
# http://dbpedia.org/resource/Bottomless_Pit rated as Great
# http://dbpedia.org/resource/Boxer rated as Great
# http://dbpedia.org/resource/Boys_and_Girls rated as Great
# http://dbpedia.org/resource/Boys_for_Pele rated as Great
# http://dbpedia.org/resource/Bram_Stoker's_Dracula rated as Great
# http://dbpedia.org/resource/Brasil rated as Great
# http://dbpedia.org/resource/Brass rated as Great
# http://dbpedia.org/resource/Brave rated as Great
# http://dbpedia.org/resource/Brave_Murder_Day rated as Great
# http://dbpedia.org/resource/Brave_New_World rated as Great
# http://dbpedia.org/resource/Braveheart rated as Great
# http://dbpedia.org/resource/Breakfast_in_America rated as Great
# http://dbpedia.org/resource/Breaking_Atoms rated as Great
# http://dbpedia.org/resource/Breaking_Point rated as Great
# http://dbpedia.org/resource/Breathe_Awhile rated as Great
# http://dbpedia.org/resource/Brel_[Les_Marquises] rated as Great
# http://dbpedia.org/resource/Brick_Body_Kids_Still_Daydream rated as Great
# http://dbpedia.org/resource/Bridge_Across_Forever rated as Great
# http://dbpedia.org/resource/Bridge_Over_Troubled_Water rated as Great
# http://dbpedia.org/resource/Bridge_of_Sighs rated as Great
# http://dbpedia.org/resource/Bridges rated as Great
# http://dbpedia.org/resource/Bright_Green_Field rated as Great
# http://dbpedia.org/resource/Bright_Phoebus rated as Great
# http://dbpedia.org/resource/Brighten_the_Corners rated as Great
# http://dbpedia.org/resource/Brilliant_Corners rated as Great
# http://dbpedia.org/resource/Brilliant_Trees rated as Great
# http://dbpedia.org/resource/Bring_the_Family rated as Great
# http://dbpedia.org/resource/Bringing_It_All_Back_Home rated as Great
# http://dbpedia.org/resource/British_Steel rated as Great
# http://dbpedia.org/resource/Brother,_Sister rated as Great
# http://dbpedia.org/resource/Brotherhood rated as Great
# http://dbpedia.org/resource/Brothers_and_Sisters rated as Great
# http://dbpedia.org/resource/Brothers_in_Arms rated as Great
# http://dbpedia.org/resource/Brown_Sugar rated as Great
# http://dbpedia.org/resource/Brown_and_Roach_Incorporated rated as Great
# http://dbpedia.org/resource/Brutalism rated as Great
# http://dbpedia.org/resource/Bryter_Layter rated as Great
# http://dbpedia.org/resource/Brötzmann_/_Van_Hove_/_Bennink_(album) rated as Great
# http://dbpedia.org/resource/Bubblegum rated as Great
# http://dbpedia.org/resource/Buddy_Holly_(album) rated as Great
# http://dbpedia.org/resource/Budgie_(album) rated as Great
# http://dbpedia.org/resource/Buena_Vista_Social_Club_(album) rated as Great
# http://dbpedia.org/resource/Buena_Vista_Social_Club_Presents_Ibrahim_Ferrer rated as Great
# http://dbpedia.org/resource/Buffalo_Springfield_Again rated as Great
# http://dbpedia.org/resource/Bug rated as Great
# http://dbpedia.org/resource/Buhaina's_Delight rated as Great
# http://dbpedia.org/resource/Buhloone_Mind_State rated as Great
# http://dbpedia.org/resource/Bullhead rated as Great
# http://dbpedia.org/resource/Bullitt rated as Great
# http://dbpedia.org/resource/Burn rated as Great
# http://dbpedia.org/resource/Burn_the_Sun rated as Great
# http://dbpedia.org/resource/Burnin' rated as Great
# http://dbpedia.org/resource/Burnt_Offerings rated as Great
# http://dbpedia.org/resource/Burnt_Weeny_Sandwich rated as Great
# http://dbpedia.org/resource/Burritos,_Inspiration_Point,_Fork_Balloon_Sports,_Cards_in_the_Spokes,_Automatic_Biographies,_Kites,_Kung_Fu,_Trophies,_Banana_Peels_We've_Slipped_On_and_Egg_Shells_We've_Tippy_Toed_Over rated as Great
# http://dbpedia.org/resource/Bury_Me_at_Makeout_Creek rated as Great
# http://dbpedia.org/resource/Buy rated as Great
# http://dbpedia.org/resource/By_Inheritance rated as Great
# http://dbpedia.org/resource/By_the_Time_I_Get_to_Phoenix rated as Great
# http://dbpedia.org/resource/Byrd_in_Hand rated as Great
# http://dbpedia.org/resource/Bílé_inferno rated as Great
# http://dbpedia.org/resource/C'era_una_volta_il_West rated as Great
# http://dbpedia.org/resource/C'era_una_volta_in_America rated as Great
# http://dbpedia.org/resource/CTRL rated as Great
# http://dbpedia.org/resource/Cabaret_(album) rated as Great
# http://dbpedia.org/resource/Cabeça_dinossauro rated as Great
# http://dbpedia.org/resource/Cabretta rated as Great
# http://dbpedia.org/resource/Caesar_Demos rated as Great
# http://dbpedia.org/resource/Caetano_Veloso_(album) rated as Great
# http://dbpedia.org/resource/Caifanes_(album) rated as Great
# http://dbpedia.org/resource/Caifanes_Vol._2_[El_Diablito] rated as Great
# http://dbpedia.org/resource/Cajas_de_música_difíciles_de_parar rated as Great
# http://dbpedia.org/resource/Calculating_Infinity rated as Great
# http://dbpedia.org/resource/California rated as Great
# http://dbpedia.org/resource/Caligula rated as Great
# http://dbpedia.org/resource/Call_Me rated as Great
# http://dbpedia.org/resource/Call_Me_If_You_Get_Lost rated as Great
# http://dbpedia.org/resource/Call_of_the_Valley rated as Great
# http://dbpedia.org/resource/Calling_Card rated as Great
# http://dbpedia.org/resource/Camel_(album) rated as Great
# http://dbpedia.org/resource/Camembert_electrique rated as Great
# http://dbpedia.org/resource/Campo_di_Marte rated as Great
# http://dbpedia.org/resource/Can't_Buy_a_Thrill rated as Great
# http://dbpedia.org/resource/Canaxis_5 rated as Great
# http://dbpedia.org/resource/Canción_animal rated as Great
# http://dbpedia.org/resource/Cannonball_Adderley_Quintet_in_Chicago rated as Great
# http://dbpedia.org/resource/Cantar rated as Great
# http://dbpedia.org/resource/Cantata_de_Santa_María_de_Iquique rated as Great
# http://dbpedia.org/resource/Canticles_of_Ecstasy rated as Great
# http://dbpedia.org/resource/Cantiga_de_longe rated as Great
# http://dbpedia.org/resource/Cantigas_do_Maio rated as Great
# http://dbpedia.org/resource/Cantofabule rated as Great
# http://dbpedia.org/resource/Canções_praieiras rated as Great
# http://dbpedia.org/resource/Capital_Punishment rated as Great
# http://dbpedia.org/resource/Captain_Beyond_(album) rated as Great
# http://dbpedia.org/resource/Captain_Fantastic_and_the_Brown_Dirt_Cowboy rated as Great
# http://dbpedia.org/resource/Captain_Marvel rated as Great
# http://dbpedia.org/resource/Captain_My_Captain rated as Great
# http://dbpedia.org/resource/Car_Wheels_on_a_Gravel_Road rated as Great
# http://dbpedia.org/resource/Caravan_(album) rated as Great
# http://dbpedia.org/resource/Caravanserai rated as Great
# http://dbpedia.org/resource/Cargo_(album) rated as Great
# http://dbpedia.org/resource/Carlos,_Erasmo... rated as Great
# http://dbpedia.org/resource/Carmina_Burana rated as Great
# http://dbpedia.org/resource/Carol_of_Harvest_(album) rated as Great
# http://dbpedia.org/resource/Carrie_&_Lowell rated as Great
# http://dbpedia.org/resource/Cartola_(album) rated as Great
# http://dbpedia.org/resource/Casino rated as Great
# http://dbpedia.org/resource/Castelos_&_ruínas rated as Great
# http://dbpedia.org/resource/Catch_Thirtythree rated as Great
# http://dbpedia.org/resource/Catch_a_Fire rated as Great
# http://dbpedia.org/resource/Catch_for_Us_the_Foxes rated as Great
# http://dbpedia.org/resource/Catherine_Ribeiro_+_2_Bis_(album) rated as Great
# http://dbpedia.org/resource/Caught_Up rated as Great
# http://dbpedia.org/resource/Cause_of_Death rated as Great
# http://dbpedia.org/resource/Cavalcade rated as Great
# http://dbpedia.org/resource/Cave_Story rated as Great
# http://dbpedia.org/resource/Celeste_(album) rated as Great
# http://dbpedia.org/resource/Cell-Scape rated as Great
# http://dbpedia.org/resource/Cello-Suiten rated as Great
# http://dbpedia.org/resource/Cello_Concerto;_Sea_Pictures rated as Great
# http://dbpedia.org/resource/Center_of_Attention rated as Great
# http://dbpedia.org/resource/Ceres_&_Calypso_in_the_Deep_Time rated as Great
# http://dbpedia.org/resource/Ceux_du_dehors rated as Great
# http://dbpedia.org/resource/Chairs_Missing rated as Great
# http://dbpedia.org/resource/Chameleon_in_the_Shadow_of_the_Night rated as Great
# http://dbpedia.org/resource/Change rated as Great
# http://dbpedia.org/resource/Change_of_the_Century rated as Great
# http://dbpedia.org/resource/Changes rated as Great
# http://dbpedia.org/resource/Changó_(album) rated as Great
# http://dbpedia.org/resource/Chaos_A.D. rated as Great
# http://dbpedia.org/resource/Chaos_Is_Me rated as Great
# http://dbpedia.org/resource/Chaos_and_Creation_in_the_Backyard rated as Great
# http://dbpedia.org/resource/Chaosphere rated as Great
# http://dbpedia.org/resource/Chappaqua_Suite rated as Great
# http://dbpedia.org/resource/Chapter_1:_Delirium rated as Great
# http://dbpedia.org/resource/Chapter_One:_Latin_America rated as Great
# http://dbpedia.org/resource/Character rated as Great
# http://dbpedia.org/resource/Charmed rated as Great
# http://dbpedia.org/resource/Cheap_Thrills rated as Great
# http://dbpedia.org/resource/Cheap_Trick_(album) rated as Great
# http://dbpedia.org/resource/Check_Your_Head rated as Great
# http://dbpedia.org/resource/Chega_de_saudade rated as Great
# http://dbpedia.org/resource/Chelsea_Girl rated as Great
# http://dbpedia.org/resource/Chemist rated as Great
# http://dbpedia.org/resource/Chet_Baker_Sings rated as Great
# http://dbpedia.org/resource/Chicago_Transit_Authority_(album) rated as Great
# http://dbpedia.org/resource/Chicago_[II] rated as Great
# http://dbpedia.org/resource/Chico_Buarque_(album) rated as Great
# http://dbpedia.org/resource/Children_of_God rated as Great
# http://dbpedia.org/resource/Chill_Out rated as Great
# http://dbpedia.org/resource/Chinatown rated as Great
# http://dbpedia.org/resource/Chocolate_and_Cheese rated as Great
# http://dbpedia.org/resource/Choice_Cuts rated as Great
# http://dbpedia.org/resource/Choir_Concerto rated as Great
# http://dbpedia.org/resource/Choirs_of_the_Eye rated as Great
# http://dbpedia.org/resource/Chopin_/_Brahms_/_Liszt_/_Ravel_/_Prokofieff rated as Great
# http://dbpedia.org/resource/Christmas_and_the_Beads_of_Sweat rated as Great
# http://dbpedia.org/resource/Chrono_Cross rated as Great
# http://dbpedia.org/resource/Chrono_Trigger rated as Great
# http://dbpedia.org/resource/Chuck_Person's_Eccojams_Vol._1 rated as Great
# http://dbpedia.org/resource/Chutes_Too_Narrow rated as Great
# http://dbpedia.org/resource/Cigarette_Smoke_Phantom rated as Great
# http://dbpedia.org/resource/Cinema_transcendental rated as Great
# http://dbpedia.org/resource/Circles rated as Great
# http://dbpedia.org/resource/Citadel rated as Great
# http://dbpedia.org/resource/City rated as Great
# http://dbpedia.org/resource/City_of_Caterpillar_(album) rated as Great
# http://dbpedia.org/resource/Ciudad_de_Brahman rated as Great
# http://dbpedia.org/resource/Clandestine rated as Great
# http://dbpedia.org/resource/Clarity rated as Great
# http://dbpedia.org/resource/Clear_Spot rated as Great
# http://dbpedia.org/resource/Clepsydra;_Astray rated as Great
# http://dbpedia.org/resource/Clics_modernos rated as Great
# http://dbpedia.org/resource/Clifford_Brown_and_Max_Roach_(album) rated as Great
# http://dbpedia.org/resource/Climax rated as Great
# http://dbpedia.org/resource/Climbing! rated as Great
# http://dbpedia.org/resource/Close_Encounters_of_the_Third_Kind rated as Great
# http://dbpedia.org/resource/Close_to_a_World_Below rated as Great
# http://dbpedia.org/resource/Close_to_the_Edge rated as Great
# http://dbpedia.org/resource/Closer rated as Great
# http://dbpedia.org/resource/Closing_Time rated as Great
# http://dbpedia.org/resource/Clouds_Taste_Metallic rated as Great
# http://dbpedia.org/resource/Clube_da_Esquina rated as Great
# http://dbpedia.org/resource/Clube_da_Esquina_2 rated as Great
# http://dbpedia.org/resource/Clutching_at_Straws rated as Great
# http://dbpedia.org/resource/Coal rated as Great
# http://dbpedia.org/resource/Cobra_and_Phases_Group_Play_Voltage_in_the_Milky_Night rated as Great
# http://dbpedia.org/resource/Coffin_for_Head_of_State rated as Great
# http://dbpedia.org/resource/Coisas rated as Great
# http://dbpedia.org/resource/Cold_Fact rated as Great
# http://dbpedia.org/resource/Cold_River_Songs rated as Great
# http://dbpedia.org/resource/Cold_Roses rated as Great
# http://dbpedia.org/resource/Cold_Steel..._for_an_Iron_Age rated as Great
# http://dbpedia.org/resource/Coleman_Hawkins_Encounters_Ben_Webster rated as Great
# http://dbpedia.org/resource/Coles_Corner rated as Great
# http://dbpedia.org/resource/Colony rated as Great
# http://dbpedia.org/resource/Colored_Sands rated as Great
# http://dbpedia.org/resource/Colors rated as Great
# http://dbpedia.org/resource/Colossal_Youth rated as Great
# http://dbpedia.org/resource/Coltrane rated as Great
# http://dbpedia.org/resource/Coltrane's_Sound rated as Great
# http://dbpedia.org/resource/Coma_of_Souls rated as Great
# ...
# http://dbpedia.org/resource/Wildhoney rated as Great
# http://dbpedia.org/resource/Wildlife rated as Great
# http://dbpedia.org/resource/Will_of_Gods_Is_a_Great_Power rated as Great
# http://dbpedia.org/resource/Will_the_Circle_Be_Unbroken rated as Great
# http://dbpedia.org/resource/Willis_Alan_Ramsey_(album) rated as Great
# http://dbpedia.org/resource/Willisau_(Quartet)_1991 rated as Great
# http://dbpedia.org/resource/Willpower rated as Great
# http://dbpedia.org/resource/Willy_and_the_Poor_Boys rated as Great
# http://dbpedia.org/resource/Wind's_Poem rated as Great
# http://dbpedia.org/resource/Winobranie rated as Great
# http://dbpedia.org/resource/Winter's_Gate rated as Great
# http://dbpedia.org/resource/Winter_in_America rated as Great
# http://dbpedia.org/resource/Winterkaelte rated as Great
# http://dbpedia.org/resource/Wintersun_(album) rated as Great
# http://dbpedia.org/resource/Wiosna_Ludu rated as Great
# http://dbpedia.org/resource/Wired rated as Great
# http://dbpedia.org/resource/Wish rated as Great
# http://dbpedia.org/resource/Wish_Someone_Would_Care rated as Great
# http://dbpedia.org/resource/Wish_You_Were_Here rated as Great
# http://dbpedia.org/resource/Wishbone_Ash_(album) rated as Great
# http://dbpedia.org/resource/Witchcult_Today rated as Great
# http://dbpedia.org/resource/Witchi-Tai-To rated as Great
# http://dbpedia.org/resource/With_Hearts_Toward_None rated as Great
# http://dbpedia.org/resource/With_Oden_on_Our_Side rated as Great
# http://dbpedia.org/resource/With_The_Oscar_Peterson_Trio_#1 rated as Great
# http://dbpedia.org/resource/With_a_Little_Help_From_My_Friends rated as Great
# http://dbpedia.org/resource/Within_the_Realm_of_a_Dying_Sun rated as Great
# http://dbpedia.org/resource/Without_You_I'm_Nothing rated as Great
# http://dbpedia.org/resource/Wolf_City rated as Great
# http://dbpedia.org/resource/Wolfheart rated as Great
# http://dbpedia.org/resource/Wonderful_Rainbow rated as Great
# http://dbpedia.org/resource/Word...Life rated as Great
# http://dbpedia.org/resource/Words_That_Go_Unspoken,_Deeds_That_Go_Undone rated as Great
# http://dbpedia.org/resource/Work_Song rated as Great
# http://dbpedia.org/resource/Workin'_With_the_Miles_Davis_Quintet rated as Great
# http://dbpedia.org/resource/Workingman's_Dead rated as Great
# http://dbpedia.org/resource/Workout rated as Great
# http://dbpedia.org/resource/World_Coming_Down rated as Great
# http://dbpedia.org/resource/World_Downfall rated as Great
# http://dbpedia.org/resource/World_Extermination rated as Great
# http://dbpedia.org/resource/World_Galaxy rated as Great
# http://dbpedia.org/resource/World_Without_God rated as Great
# http://dbpedia.org/resource/World_Without_Tears rated as Great
# http://dbpedia.org/resource/World_of_Echo rated as Great
# http://dbpedia.org/resource/Worry. rated as Great
# http://dbpedia.org/resource/Woven_Hand_(album) rated as Great
# http://dbpedia.org/resource/Wowee_Zowee rated as Great
# http://dbpedia.org/resource/Wrath_of_the_Math rated as Great
# http://dbpedia.org/resource/Wrecking_Ball rated as Great
# http://dbpedia.org/resource/Written_in_Waters rated as Great
# http://dbpedia.org/resource/Wrong rated as Great
# http://dbpedia.org/resource/X-Aspirations rated as Great
# http://dbpedia.org/resource/XO rated as Great
# http://dbpedia.org/resource/XTRMNTR rated as Great
# http://dbpedia.org/resource/XXX rated as Great
# http://dbpedia.org/resource/X_(album) rated as Great
# http://dbpedia.org/resource/Xaphan:_Book_of_Angels_Volume_9 rated as Great
# http://dbpedia.org/resource/Xenogears rated as Great
# http://dbpedia.org/resource/Y rated as Great
# http://dbpedia.org/resource/Yank_Crime rated as Great
# http://dbpedia.org/resource/Yankee_Hotel_Foxtrot rated as Great
# http://dbpedia.org/resource/Yanqui_U.X.O. rated as Great
# http://dbpedia.org/resource/Yasimika rated as Great
# http://dbpedia.org/resource/Yasmina,_a_Black_Woman rated as Great
# http://dbpedia.org/resource/Yayayi_(album) rated as Great
# http://dbpedia.org/resource/Year_of_the_Cat rated as Great
# http://dbpedia.org/resource/Year_of_the_Snitch rated as Great
# http://dbpedia.org/resource/Yeezus rated as Great
# http://dbpedia.org/resource/Yellow_Magic_Orchestra_(album) rated as Great
# http://dbpedia.org/resource/Yendo_de_la_cama_al_living rated as Great
# http://dbpedia.org/resource/Yerself_Is_Steam rated as Great
# http://dbpedia.org/resource/Yes_We_Can rated as Great
# http://dbpedia.org/resource/Yeti rated as Great
# http://dbpedia.org/resource/Yoshimi_Battles_the_Pink_Robots rated as Great
# http://dbpedia.org/resource/You rated as Great
# http://dbpedia.org/resource/You'd_Prefer_an_Astronaut rated as Great
# http://dbpedia.org/resource/You're_Dead! rated as Great
# http://dbpedia.org/resource/You're_Living_All_Over_Me rated as Great
# http://dbpedia.org/resource/You're_Never_Alone_With_a_Schizophrenic rated as Great
# http://dbpedia.org/resource/You're_Not_Alone rated as Great
# http://dbpedia.org/resource/You_Are_Free rated as Great
# http://dbpedia.org/resource/You_Are_My_Everlovin_/_Celestial_Power rated as Great
# http://dbpedia.org/resource/You_Don't_Mess_Around_With_Jim rated as Great
# http://dbpedia.org/resource/You_Fail_Me rated as Great
# http://dbpedia.org/resource/You_Forgot_It_in_People rated as Great
# http://dbpedia.org/resource/You_Got_My_Mind_Messed_Up rated as Great
# http://dbpedia.org/resource/You_Must_Believe_in_Spring rated as Great
# http://dbpedia.org/resource/You_Want_It_Darker rated as Great
# http://dbpedia.org/resource/You_Will_Never_Know_Why rated as Great
# http://dbpedia.org/resource/You_Won't_Get_What_You_Want rated as Great
# http://dbpedia.org/resource/Young,_Gifted_and_Black rated as Great
# http://dbpedia.org/resource/Younger_Than_Yesterday rated as Great
# http://dbpedia.org/resource/Your_Funeral_..._My_Trial rated as Great
# http://dbpedia.org/resource/Your_Name rated as Great
# http://dbpedia.org/resource/Your_Queen_Is_a_Reptile rated as Great
# http://dbpedia.org/resource/Youth_of_America rated as Great
# http://dbpedia.org/resource/Ys rated as Great
# http://dbpedia.org/resource/Yèkatit:_Ethio_Jazz rated as Great
# http://dbpedia.org/resource/Zabumbê-bum-á rated as Great
# http://dbpedia.org/resource/Zarathustra rated as Great
# http://dbpedia.org/resource/Zauberberg rated as Great
# http://dbpedia.org/resource/Ze_słowem_biegnę_do_ciebie rated as Great
# http://dbpedia.org/resource/Zeichnungen_des_Patienten_O.T. rated as Great
# http://dbpedia.org/resource/Zeit rated as Great
# http://dbpedia.org/resource/Zen_Arcade rated as Great
# http://dbpedia.org/resource/Ziltoid_the_Omniscient rated as Great
# http://dbpedia.org/resource/Zombie rated as Great
# http://dbpedia.org/resource/Zoundegnon_Bernard_'Papillon'_guitariste_principal rated as Great
# http://dbpedia.org/resource/Zuckerzeit rated as Great
# http://dbpedia.org/resource/Zuma rated as Great
# http://dbpedia.org/resource/Zé_Ramalho_(album) rated as Great
# http://dbpedia.org/resource/cLOUDDEAD_(album) rated as Great
# http://dbpedia.org/resource/channel_ORANGE rated as Great
# http://dbpedia.org/resource/drukqs rated as Great
# http://dbpedia.org/resource/elseq_4 rated as Great
# http://dbpedia.org/resource/good_kid,_m.A.A.d_city rated as Great
# http://dbpedia.org/resource/in_vain rated as Great
# http://dbpedia.org/resource/janet. rated as Great
# http://dbpedia.org/resource/m_b_v rated as Great
# http://dbpedia.org/resource/mikgazer_vol.1 rated as Great
# http://dbpedia.org/resource/mu_First_Part rated as Great
# http://dbpedia.org/resource/qp rated as Great
# http://dbpedia.org/resource/s.o.n.o.g.r.a.m. rated as Great
# http://dbpedia.org/resource/undun rated as Great
# http://dbpedia.org/resource/½_Mensch rated as Great
# http://dbpedia.org/resource/À_l'âme_enflammée,_l'âme_constellée... rated as Great
# http://dbpedia.org/resource/À_vontade rated as Great
# http://dbpedia.org/resource/África_Brasil rated as Great
# http://dbpedia.org/resource/Ágætis_byrjun rated as Great
# http://dbpedia.org/resource/Âme_debout rated as Great
# http://dbpedia.org/resource/Ænima rated as Great
# http://dbpedia.org/resource/Écailles_de_lune rated as Great
# http://dbpedia.org/resource/Échate_un_cantecito rated as Great
# http://dbpedia.org/resource/Études_Op.10_&_Op.25 rated as Great
# http://dbpedia.org/resource/Ëmëhntëhtt-Ré rated as Great
# http://dbpedia.org/resource/Üdü_Ẁüdü rated as Great
# http://dbpedia.org/resource/Œuvres_d'Erik_Satie rated as Great
# http://dbpedia.org/resource/Światła_miasta rated as Great
# http://dbpedia.org/resource/Βραχνός_προφήτης rated as Great
# http://dbpedia.org/resource/ΚΕΦΑΛΗΞΘ_[Psalm_69] rated as Great
# http://dbpedia.org/resource/Армагеддон-попс rated as Great
# http://dbpedia.org/resource/Бодун rated as Great
# http://dbpedia.org/resource/Голос_сталі rated as Great
# http://dbpedia.org/resource/Группа_крови rated as Great
# http://dbpedia.org/resource/Девушки_поют rated as Great
# http://dbpedia.org/resource/Долгая_счастливая_жизнь rated as Great
# http://dbpedia.org/resource/Домой! rated as Great
# http://dbpedia.org/resource/Звезда rated as Great
# http://dbpedia.org/resource/Звезда_по_имени_Солнце rated as Great
# http://dbpedia.org/resource/Здорово_и_вечно rated as Great
# http://dbpedia.org/resource/Игра_с_огнем rated as Great
# http://dbpedia.org/resource/Как_я_стал_предателем rated as Great
# http://dbpedia.org/resource/Кино_(Чёрный_альбом) rated as Great
# http://dbpedia.org/resource/Китицi_(Kytytsi) rated as Great
# http://dbpedia.org/resource/Кров_у_наших_криницях_(Blood_in_Our_Wells) rated as Great
# http://dbpedia.org/resource/Кровоизлияние rated as Great
# http://dbpedia.org/resource/Кровь_за_кровь rated as Great
# http://dbpedia.org/resource/Лиловый_день rated as Great
# http://dbpedia.org/resource/Литоургиiа_(Litourgiya) rated as Great
# http://dbpedia.org/resource/Лунный_переворот rated as Great
# http://dbpedia.org/resource/Одбрана_и_последњи_дани rated as Great
# http://dbpedia.org/resource/Последний_герой rated as Great
# http://dbpedia.org/resource/Продано! rated as Great
# http://dbpedia.org/resource/Прыг-скок:_Детские_песенки rated as Great
# http://dbpedia.org/resource/Птица rated as Great
# http://dbpedia.org/resource/Русский_альбом rated as Great
# http://dbpedia.org/resource/Русское_поле_экспериментов rated as Great
# http://dbpedia.org/resource/Сто_лет_одиночества rated as Great
# http://dbpedia.org/resource/Стыд_и_срам rated as Great
# http://dbpedia.org/resource/Это_мама rated as Great
# http://dbpedia.org/resource/א_(Alef) rated as Great
# http://dbpedia.org/resource/ג_(Gimel) rated as Great
# http://dbpedia.org/resource/ማሕሙድ_፡_ኣሕመድ_፡_(Mahmoud_Ahmed) rated as Great
# http://dbpedia.org/resource/⊿_(Triangle) rated as Great
# http://dbpedia.org/resource/★_[Blackstar] rated as Great
# http://dbpedia.org/resource/あくまのうた_(Akuma_no_uta) rated as Great
# http://dbpedia.org/resource/あらためまして、はじめまして、ミドリです。_(Aratamemashite,_hajimemashite,_Midori_desu.) rated as Great
# http://dbpedia.org/resource/かがやき_(Kagayaki) rated as Great
# http://dbpedia.org/resource/きくおミク6_(Kikuo_Miku_6) rated as Great
# http://dbpedia.org/resource/ごはんができたよ_(Gohan_ga_Dekita_yo) rated as Great
# http://dbpedia.org/resource/つまんね_(Tsumanne) rated as Great
# http://dbpedia.org/resource/となりのトトロ_(Tonari_no_Totoro) rated as Great
# http://dbpedia.org/resource/もののけ姫_(Mononoke-hime) rated as Great
# http://dbpedia.org/resource/アダンの風_(Windswept_Adan) rated as Great
# http://dbpedia.org/resource/アンハッピーリフレイン_(Unhappy_Refrain) rated as Great
# http://dbpedia.org/resource/ゲームボーイ『ポケモン』のサウンドがまるごと入って、遊べるCD_(GameBoy_『Pokémon』_no_Sound_ga_Marugoto_Itte,_Asoberu_CD) rated as Great
# http://dbpedia.org/resource/スーパーマリオ_ヨッシーアイランド_オリジナル・サウンド・ヴァージョン_(Super_Mario_Yoshi_Island_Original_Sound_Version) rated as Great
# http://dbpedia.org/resource/ゼノブレイド_Xenoblade rated as Great
# http://dbpedia.org/resource/ゼルダの伝説:_ムジュラの仮面_(The_Legend_of_Zelda:_Majora's_Mask) rated as Great
# http://dbpedia.org/resource/ゼルダの伝説_～風のタクト～_(The_Legend_of_Zelda:_The_Wind_Waker) rated as Great
# http://dbpedia.org/resource/ドラム_(Drum) rated as Great
# http://dbpedia.org/resource/ニンテンドーDS_ポケモン_ダイヤモンド&パール_スーパーミュージックコレクション_(Nintendo_DS_Pokémon_Diamond_&_Pearl_Super_Music_Collection) rated as Great
# http://dbpedia.org/resource/ハウルの動く城_(Hauru_no_ugoku_shiro) rated as Great
# http://dbpedia.org/resource/ピンポン_オリジナルサウンドトラック rated as Great
# http://dbpedia.org/resource/ファイナルファンタジーIV_(Final_Fantasy_IV) rated as Great
# http://dbpedia.org/resource/ファイナルファンタジーVI_(Final_Fantasy_VI) rated as Great
# http://dbpedia.org/resource/ファイナルファンタジーX_(Final_Fantasy_X) rated as Great
# http://dbpedia.org/resource/ファンファーレ_(Fanfare) rated as Great
# http://dbpedia.org/resource/フリクリ_(FLCL):_OST_1_~_Addict rated as Great
# http://dbpedia.org/resource/プラトニック_プラネット_(Platonic_Planet) rated as Great
# http://dbpedia.org/resource/マホロボシヤ_(Mahoroboshiya) rated as Great
# http://dbpedia.org/resource/ワンダと巨像_大地の咆哮_(Wander_and_the_Colossus:_Roar_of_the_Earth) rated as Great
# http://dbpedia.org/resource/ワールドイズユアーズ_(World_Is_Yours) rated as Great
# http://dbpedia.org/resource/一触即発_(Isshoku-Sokuhatsu) rated as Great
# http://dbpedia.org/resource/光のカケラ_(Hikari_No_Kakera) rated as Great
# http://dbpedia.org/resource/冀西南林路行_(Inside_the_Cable_Temple) rated as Great
# http://dbpedia.org/resource/剃刀乙女_(Kamisori_otome) rated as Great
# http://dbpedia.org/resource/剣風伝奇ベルセルク_(Berserk) rated as Great
# http://dbpedia.org/resource/加爾基_精液_栗ノ花_(Kalk_samen_kuri_no_hana) rated as Great
# http://dbpedia.org/resource/勝訴ストリップ_(Shōso_strip) rated as Great
# http://dbpedia.org/resource/千と千尋の神隠し_(Sen_to_Chihiro_no_kamikakushi) rated as Great
# http://dbpedia.org/resource/呼吸_(Kokyuu) rated as Great
# http://dbpedia.org/resource/塊魂サウンドトラック「塊フォルテッシモ魂」_(Katamari_Damacy_Soundtrack:_Katamari_Fortissimo_Damacy) rated as Great
# http://dbpedia.org/resource/大人_(Adult) rated as Great
# http://dbpedia.org/resource/天使のたまご_音楽編_/_水に棲む_(Tenshi_no_tamago_ongaku_hen_/_Mizu_ni_sumu) rated as Great
# http://dbpedia.org/resource/天空の城ラピュタ_(Tenkū_no_shiro_Laputa) rated as Great
# http://dbpedia.org/resource/宇宙_日本_世田谷_(Uchū_Nippon_Setagaya) rated as Great
# http://dbpedia.org/resource/平成風俗_(Heisei_fūzoku) rated as Great
# http://dbpedia.org/resource/恋人へ_(Koibito_e) rated as Great
# http://dbpedia.org/resource/悪魔城ドラキュラX～月下の夜想曲～_(Akumajo_Dracula_X_~Gekka_no_Nocturne~) rated as Great
# http://dbpedia.org/resource/悲愴_(Pathétique) rated as Great
# http://dbpedia.org/resource/攻殻機動隊:_Stand_Alone_Complex_O.S.T._(Ghost_in_the_Shell:_Stand_Alone_Complex_O.S.T.) rated as Great
# http://dbpedia.org/resource/放課後ティータイムII_(Ho-kago_Tea_Time_Second) rated as Great
# http://dbpedia.org/resource/救済の技法_(Kyuusai_no_gihou) rated as Great
# http://dbpedia.org/resource/教育_(Kyōiku) rated as Great
# http://dbpedia.org/resource/新しい日の誕生_(Atarashī_hi_no_tanjō) rated as Great
# http://dbpedia.org/resource/星間性交 rated as Great
# http://dbpedia.org/resource/映画_聲の形_オリジナル・サウンドトラック_A_Shape_of_Light rated as Great
# http://dbpedia.org/resource/春と修羅_(Haru_to_Shura) rated as Great
# http://dbpedia.org/resource/渋星_(Shibuboshi) rated as Great
# http://dbpedia.org/resource/無罪モラトリアム_(Muzai_moratorium) rated as Great
# http://dbpedia.org/resource/現実を超えて_(Genjitsu_o_koete) rated as Great
# http://dbpedia.org/resource/白虎野_(Byakkoya) rated as Great
# http://dbpedia.org/resource/真・女神転生III_Nocturne_(Shin_Megami_Tensei_III:_Nocturne) rated as Great
# http://dbpedia.org/resource/空中キャンプ_(Kūchū_Camp) rated as Great
# http://dbpedia.org/resource/輪廻交響楽_(Ecophony_Rinne) rated as Great
# http://dbpedia.org/resource/革命京劇_(Revolutionary_Pekinese_Opera) rated as Great
# http://dbpedia.org/resource/革命京劇_(Revolutionary_Pekinese_Opera)_Ver.1.28 rated as Great
# http://dbpedia.org/resource/風の谷のナウシカ_はるかな地へ_(Kaze_no_tani_no_Naushika) rated as Great
# http://dbpedia.org/resource/魔女の宅急便_(Majo_no_takkyūbin) rated as Great
# http://dbpedia.org/resource/가장_보통의_존재 rated as Great
# http://dbpedia.org/resource/공중도덕_(Gongjoong_Doduk) rated as Great
# http://dbpedia.org/resource/기생충_(Parasite) rated as Great
# http://dbpedia.org/resource/무너지기_(Crumbling) rated as Great
# http://dbpedia.org/resource/올드보이_(Old_Boy) rated as Great
# http://dbpedia.org/resource/Salisbury rated as Great
# http://dbpedia.org/resource/Miami rated as Great
# http://dbpedia.org/resource/Berlin rated as Great
# http://dbpedia.org/resource/Los_Angeles rated as Great

# %%
query = """
    SELECT ?s
    WHERE {
        # ?s a rdfs:Class .
    }
"""

results = g.query(query)

for result in results:
    print(result)
# Out:
# (rdflib.term.URIRef('http://dbpedia.org/ontology/Album'),)
# (rdflib.term.URIRef('http://dbpedia.org/ontology/Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/ontology/BandMember'),)
# (rdflib.term.URIRef('http://dbpedia.org/ontology/City'),)
# (rdflib.term.URIRef('http://dbpedia.org/ontology/Country'),)
# (rdflib.term.URIRef('http://dbpedia.org/ontology/MusicArtist'),)
# (rdflib.term.URIRef('http://dbpedia.org/ontology/MusicGenre'),)
# (rdflib.term.URIRef('http://dbpedia.org/ontology/Person'),)

# %% [markdown]
# Check for MusicArtists that are also bands to check the range related inference.

# %%
query = """
    PREFIX dbo: <http://dbpedia.org/ontology/>
    SELECT ?s
    WHERE {
        # ?s a dbo:MusicArtist .
        # ?s a dbo:Band .
    }
"""

results = g.query(query)

for result in results:
    print(result)
# Out:
# (rdflib.term.URIRef('http://dbpedia.org/resource/!T.O.O.H.!'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/...And_You_Will_Know_Us_by_the_Trail_of_Dead'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/12_Rods'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/13th_Floor_Elevators'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/16_Horsepower'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/ABBA'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/ABC_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/A_Sei_Voci'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/A_Silver_Mt._Zion'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaliyah'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Acrimony'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Afro-Cuban_All_Stars'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/After_Crying'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/After_the_Burial'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Agent_Orange_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Agitation_Free'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Akercocke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alaska_y_Dinarama'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alban_Berg_Quartett'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Almendra_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alphataurus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alquin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Altar_of_Plagues'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alvvays'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/American_Football_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Amon_Amarth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/And_Also_the_Trees'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ange'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Angel_Witch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Antony_and_the_Johnsons'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Aphrodite's_Child"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arctic_Monkeys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arcturus_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Armageddon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Armia'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Armored_Saint'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Art_Ensemble_of_Chicago'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Artillery_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ash_Ra_Tempel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ashbury_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ashra_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/At_the_Drive-In'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Atila_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Avantasia'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Avishai_Cohen_Trio'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Axe_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bacamarte'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barón_Rojo'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Be'lakor"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Behemoth_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Folds_Five'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Big_Big_Train'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Big_L'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Biglietto_per_l'Inferno"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Biosphere'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bjork'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Black_Country,_New_Road'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Black_Moon_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Black_Uhuru'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blind_Faith'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bloc_Party'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blondie_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blood,_Sweat_&_Tears'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bluetile_Lounge'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bodychoke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bon_Iver'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Boston_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brand_New_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brand_X'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Breach_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Breakout_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/British_Sea_Power'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brocas_Helm_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Broken_Social_Scene'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brutal_Truth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brutality_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Buena_Vista_Social_Club'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Buffalo_Springfield'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Burial'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Calexico_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Camberwell_Now'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Camp_Lo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cannibal_Ox'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Cap'n_Jazz"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Captain_Beefheart_and_His_Magic_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Captain_Beyond'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cargo_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carly_Rae_Jepsen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carnage_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Catapilla'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Catharsis_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Celeste_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cheer-Accident'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chet_Baker'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chicago_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chicken_Shack'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Choking_Victim'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Death'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chrome_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cirith_Ungol_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/City_of_Caterpillar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clann_Zú'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cloven_Hoof_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cock_Sparrer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Coheed_and_Cambria'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Coldplay'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colour_Haze'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Common_Sense_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Company_Flow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Comus_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Consorzio_Suonatori_Indipendenti'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Contortions'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Convulse_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Crack_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Crass'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cressida_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Crosby,_Stills_&_Nash'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Crowded_House'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Crucis_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Culture_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dark_Angel_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Darkspace_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dead_Prez'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Deafheaven'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Death_Angel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Death_Cab_for_Cutie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Deep_Turtle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Def_Leppard'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Deltron_3030'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Demigod_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Demilich_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Demon_Fuzz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Demoniac'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Derek_and_the_Dominos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Descendents'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Destruction_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Devo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dexys_Midnight_Runners'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Diamond_Head_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dillard_&_Clark'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dillinger_Four'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dinosaur'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dinosaur_Jr'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dirty_Three'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Discharge_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Discipline_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Disillusion_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dolly_Mixture_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dolorian'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dorothy_Carter'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Down_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Draconian_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dragged_Into_Sunlight'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dungen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dusk_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dust_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dusty_Springfield'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dystopia_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dün_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/EPMD'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Earth_Wind_&_Fire'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/East_of_Eden_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Edan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eddie_and_the_Hot_Rods'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eightball_&_MJG'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/El_Último_de_la_Fila'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Elder_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Elio_e_le_Storie_Tese'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Elvis_Costello_and_The_Attractions'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Emerson,_Lake_&_Palmer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Emerson_String_Quartet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Emmylou_Harris'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/England_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ensiferum'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Envy_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Equilibrium_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Esbjörn_Svensson_Trio'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Estatic_Fear'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eurythmics'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Evergrey'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Everything_Everything'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Extol'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Extremoduro'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/FKA_twigs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/FLUX_Quartet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Falconer_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fantômas_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Faraquet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fear_Before_the_March_of_Flames'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fear_Factory'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Felt_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fever_Ray'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fifth_Angel'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Flamin'_Groovies"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Flipper_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Flotation_Toy_Warning'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Flotsam_and_Jetsam_(band)'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Flower_Travellin'_Band"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Forbidden_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fotheringay'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Four_Tops'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Freestyle_Fellowship'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Frightened_Rabbit'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Frumpy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fruupp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fugees'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Funeral_Diner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Galneryus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gang_of_Four_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Geinoh_Yamashirogumi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Giles_Corey_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Global_Communication'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gnidrolog'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Goldfrapp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Goodie_Mob'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gotthard_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Grand_Funk_Railroad'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Grandaddy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Granicus_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Grave_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Grave_Digger_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gravediggaz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Green_Carnation'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Grobschnitt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Group_1850'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gun_(band)'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Guns_N'_Roses"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Halford_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Harem_Scarem'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Harmonia_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Heavens_Gate_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Heldon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hell_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Heltah_Skeltah'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hibria'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/High_Tide_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hole_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hoodoo_Gurus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hopesfall'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hunger_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Huun-Huur-Tu'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/IAM_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Igra_Staklenih_Perli'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ike_&_Tina_Turner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Il_Balletto_di_Bronzo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/In_the_Woods...'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Infernäl_Mäjesty'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Infester'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Injury_Reserve'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Interpol'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Irish_Coffee_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jag_Panzer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/James_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/James_Gang'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/James_Taylor'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jan_Dukes_de_Grey'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Japanese_Breakfast'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jawbreaker_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jericho_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jerry_Lee_Lewis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jesu'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jill_Scott'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jimmy_Eat_World'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Joe_Cocker'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/John_Mayall_&_The_Bluesbreakers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/João_Donato'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Juggaknots'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jumbo_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/KMD'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kaliber_44'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kate_&_Anna_McGarrigle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kazik_na_Żywo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Keef_Hartley_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kenny_Burrell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kenny_Drew'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kero_Kero_Bonito'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Khan_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/King_Gizzard_&_the_Lizard_Wizard'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Klaus_Mitffoch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kleenex_Girl_Wonder'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kronos_Quartet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kury_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kylie_Minogue'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/LaBelle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Laddio_Bolocko'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lady_Pank'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lake_of_Tears'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lamp_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lavender_Country'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Leatherwolf'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Leevi_and_the_Leavings'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lemon_Demon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lenny_Valentino'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Les_McCann'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Leño'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Liege_Lord'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Life_Without_Buildings'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lift_to_Experience'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lil_Wayne'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lily_Chou-Chou'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lole_y_Manuel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lords_of_the_Underground'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Los_Fabulosos_Cadillacs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Los_Hermanos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Los_Planetas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Louis_Armstrong'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Louis_Armstrong_and_His_All-Stars'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lowrider'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Lucifer's_Friend"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Luna_Sea'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lurker_of_Chalice'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lync'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Machine_Head_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mad_Season_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Magdalena_Bay_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Magnum_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Magrudergrind'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Main_Source'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Malevolent_Creation'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Malo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Manfred_Mann_Chapter_Three'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Manfred_Schoof'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Lanegan_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Masta_Ace_Incorporated'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Master's_Hammer"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Masterplan_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Masters_of_Reality'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Matching_Mole'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Maxophone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/May_Blitz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mazzy_Star'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mclusky'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mellow_Candle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Message_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Metamorfosi_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Metá_Metá'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mezquita_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Midlake'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mineral_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mink_DeVille'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Minutemen_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mission_of_Burma'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Moby_Grape'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Molested'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Monster_Magnet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Montrose_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Monty_Python'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Moondog_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Morbid_Saint'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Morly_Grey'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Moss_Icon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mournful_Congregation'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Muse_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Museo_Rosenbach'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Myslovitz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/N.W.A'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Naked_City_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Necrophobic'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Negură_Bunget'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/New_Bomb_Turks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/New_York_Dolls'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Night_Sun'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nightwish'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nitty_Gritty_Dirt_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/No_Trend'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nocturnus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nokturnal_Mortum'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Non_Phixion'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Novalis_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/November_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Novembre'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/October_Tide'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Off_Minor'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Okkervil_River'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Old_97's"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/On_the_Might_of_Princes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Onyx'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Operation_Ivy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Orchestra_Baobab'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Origami_Angel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ornatos_Violeta'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Orphaned_Land'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Os_Mutantes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Os_Paralamas_do_Sucesso'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Os_Tincoãs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Osanna'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Oxbow_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/PMMP'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pan_Sonic'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Panopticon_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Parquet_Courts'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Patife_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Patto'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Pavlov's_Dog_(band)"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pentangle_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Peste_Noire'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Phoenix_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Picchio_dal_Pozzo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pierre_Boulez'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pinback'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Placebo_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Poet_and_the_Roots'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Poison_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Poison_Idea'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Polaris_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Polvo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Portico_Quartet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Portraits_of_Past'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Possessed_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pretenders_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pretty_Things'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Primal_Scream'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Procol_Harum'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Prolapse_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Propaganda_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Protomartyr_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Public_Image_Ltd.'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pulsar_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pure_Reason_Revolution'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Purple_Mountains'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Quasimoto'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Quilapayún'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/R.L._Burnside'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Radwimps'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ramleh'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rammstein'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rancid_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ratos_de_Porão'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Reflection_Eternal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Refused'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Reigning_Sound'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Repulsion_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rilo_Kiley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rites_of_Spring'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Robyn_Hitchcock_and_The_Egyptians'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rodrigo_y_Gabriela'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rodriguez_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rose_Tattoo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rotting_Christ'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Royal_Hunt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rudimentary_Peni'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Runemagick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rx_Bandits'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ryan_Adams_&_The_Cardinals'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/SPK_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sacramentum_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sacrilege_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sadus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Saetia'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sam_&_Dave'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Samla_Mammas_Manna'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sanctuary_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sarah_Vaughan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sarcófago'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Saturnus_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Satyricon_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Scald_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Scanner_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Screaming_Trees'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sebadoh'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sebastian_Hardie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Secos_&_Molhados'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Secret_Chiefs_3'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Seventh_Wonder'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sex_Pistols'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Shabazz_Palaces'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Shadow_Gallery'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Shape_of_Despair'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sharon_Jones_and_The_Dap-Kings'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Shellac_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sieges_Even'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Siekiera'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sigh_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Silver_Apples'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Simple_Minds'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Sinead_O'Connor"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sinister_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Siouxsie_&_the_Banshees'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sir_Lord_Baltimore'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sixpence_None_the_Richer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Skepticism_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Skinny_Puppy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Skycamefalling'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Slaughter_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sleater_Kinney'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Slint'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Slough_Feg'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Slum_Village'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Small_Faces'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Smashing_Pumpkins'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Smif-n-Wessun'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Snapcase'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Snoop_Doggy_Dogg'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Social_Distortion'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Soft_Cell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Soft_Machine'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Solaris_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Son_Volt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sonic_Sum'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sons_of_Kemet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Soul_Coughing'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Souls_of_Mischief'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Southside_Johnny_&_The_Asbury_Jukes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Spanish_Love_Songs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Spinetta_Jade'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Spiritualized'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Spirogyra_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Spooky_Tooth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Spoon_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Spring_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Squid_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Standing_on_the_Corner_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steamhammer_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steel_Mill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Miller_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Reich_and_Musicians'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stiff_Little_Fingers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stormwitch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stratovarius'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sun_City_Girls'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sunn_O)))'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Super_Furry_Animals'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Suzanne_Vega'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sweet_Smoke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Swell_Maps'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Swirlies'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/T2_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/TLC_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Takács_Quartet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Taste_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tear_Gas_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Techno_Animal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Television_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Temple_of_the_Dog'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Terje_Rypdal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Terrorizer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tesla_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_13th_Floor_Elevators'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Abyssinians'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Afghan_Whigs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Angels_of_Light'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Arrogant_Sons_of_Bitches'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Avalanches'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/The_B-52's"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Beatnuts'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Black_Crowes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Blasting_Company'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Blues_Brothers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Cars'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Chariot_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Chemical_Brothers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Congos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Cracow_Klezmer_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Cramps'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Crazy_World_of_Arthur_Brown'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Crickets'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Crown_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Delfonics'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Devin_Townsend_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Devin_Townsend_Project'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Dillards'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Doobie_Brothers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Drifters'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Dukes_of_Stratosphear'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Durutti_Column'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Ex_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Exploding_Hearts'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Feelies'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Flower_Kings'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Flying_Burrito_Brothers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Gaslight_Anthem'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Gerogerigegege'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Gladiators_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Go!_Team'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Grateful_Dead'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Hellacopters'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Hotelier'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Incredible_String_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Innocence_Mission'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/The_J.B.'s"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Jazz_Messengers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_KLF'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Knife'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Koreatown_Oddity'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Left_Banke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Loud_Family'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Mamas_and_the_Papas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Michael_Schenker_Group'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Millennium_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Modern_Lovers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Move'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Nitty_Gritty_Dirt_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Notwist'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Only_Ones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Paul_Butterfield_Blues_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Pop_Group'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Posies'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Postal_Service'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Pretenders'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Pretty_Things'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Prodigy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Protomen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Pyramids_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Radio_Dept.'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Raincoats'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Rutles'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Shins'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Soft_Boys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Sonics'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Soundtrack_of_Our_Lives'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Stone_Roses'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Stranglers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Streets'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Stylistics'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Sundays'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Supremes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Sweet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Tea_Party'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Temptations'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_The'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Tony_Williams_Lifetime'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Tuss'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Undertones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Unicorns'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_United_States_of_America_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Verve'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Wedding_Present'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Wonder_Years_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Wrens'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Zombies'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Theatre_of_Tragedy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Theocracy_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/These_Immortal_Souls'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thinking_Fellers_Union_Local_282'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thinking_Plague'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thorns_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Three_Man_Army'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thrice'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Timeless_Miracle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tiro_de_Gracia'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Titãs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Toad_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tom_Petty_and_The_Heartbreakers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tom_Petty_and_the_Heartbreakers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tomasz_Stańko'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ton_Steine_Scherben'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Touché_Amoré'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Trapeze_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Traveling_Wilburys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Triumvirat'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Truly'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Truth_and_Janey'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tubeway_Army'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/U.K._(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Unida'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Van_Halen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Venom_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Vicious_Rumors'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Vio-Lence'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Virgin_Black'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Vox_Dei'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/War_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Warlord_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Weakling'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Weather_Report'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Weidorje'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Whiskeytown'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Whitesnake'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Whitney_Houston'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Windy_&_Carl'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Winterhawk_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wintersun'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wolf_Parade'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Women_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wu-Tang_Clan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wu_Tang_Clan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wussy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/X-Ray_Spex'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Yndi_Halda'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Young_Marble_Giants'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Zero_Boys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Świetliki'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/2Pac'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Acid_Bath'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aerosmith'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alcest'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alice_in_Chains'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anacrusis_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Angra_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Annihilator_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Area_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arena_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Asphyx'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Assück'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/At_the_Gates'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Atomic_Rooster'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Autopsy_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ayreon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bad_Brains'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bad_Religion'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Badfinger'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bark_Psychosis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bauhaus_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Belle_&_Sebastian'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Belle_and_Sebastian'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Between_the_Buried_and_Me'),)
# ...
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stars_of_the_Lid'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steeleye_Span'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Suede_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Supertramp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sweet_Trip'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Symphony_X'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/System_of_a_Down'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Talk_Talk'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Teenage_Fanclub'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ten_Years_After'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Testament_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Alan_Parsons_Project'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Clash'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Dillinger_Escape_Plan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Divine_Comedy_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Isley_Brothers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Jam'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Jayhawks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Jimi_Hendrix_Experience'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Meters'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Moody_Blues'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_National_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Pogues'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Replacements_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Residents'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Strokes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Waterboys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_White_Stripes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thy_Catafalque'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tindersticks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tool_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Trouble_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Type_O_Negative'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ulcerate'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Underworld'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/W.A.S.P.'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Windir'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wipers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wire_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Xiu_Xiu'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/ZZ_Top'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/A_Tribe_Called_Quest'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Agalloch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alice_Cooper'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anathema'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Animal_Collective'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/B.B._King'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bathory_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Beastie_Boys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Big_Star'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blind_Guardian'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brockhampton_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Budgie_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Buzzcocks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Can_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Candlemass'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Car_Seat_Headrest'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cardiacs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cheap_Trick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dark_Tranquillity'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Darkthrone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/De_La_Soul'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Deep_Purple'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Deftones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dexter_Gordon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dire_Straits'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Duke_Ellington'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ella_Fitzgerald'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Elvis_Presley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Esoteric_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fleetwood_Mac'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Free_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gang_Starr'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gong_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gorguts'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Gov't_Mule"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Guided_by_Voices'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hawkwind'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Henry_Cow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hüsker_Dü'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/IQ_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Iced_Earth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Incantation_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jay-Z'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Joanna_Newsom'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kamelot'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Killing_Joke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kraftwerk'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kreator'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Leprous'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lynyrd_Skynyrd'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Manilla_Road'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mastodon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Meshuggah'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Moonsorrow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Natural_Snow_Buildings'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nick_Cave_and_The_Bad_Seeds'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nine_Inch_Nails'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nirvana_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/OutKast'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Overkill_(band)'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Paysage_d'Hiver"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pixies'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Premiata_Forneria_Marconi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ramones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Renaissance_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/SBB_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Santana_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sepultura'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sigur_Rós'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Simon_&_Garfunkel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sleater-Kinney'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Slowdive'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sly_&_The_Family_Stone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Soda_Stereo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Solitude_Aeturnus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stevie_Ray_Vaughan_and_Double_Trouble'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Strawbs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Summoning_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Chameleons'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Go-Betweens'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Microphones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Necks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Police'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Ruins_of_Beverast'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/They_Might_Be_Giants'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/UFO_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ulver'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Unwound'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Uriah_Heep_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Voivod_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Weezer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wilco'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Yes_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Yo_La_Tengo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aretha_Franklin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Autechre'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bolt_Thrower'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Camel_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cocteau_Twins'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Converge_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dead_Can_Dance'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eric_Clapton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fates_Warning'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Fugazi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Funkadelic'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gamma_Ray_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Genesis_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Helloween'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Immolation_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jackie_McLean'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/John_Lee_Hooker'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kendrick_Lamar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Low_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lucinda_Williams'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Metallica'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Motorpsycho'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/New_Order'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/NoMeansNo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pat_Metheny_Group'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pavement_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pet_Shop_Boys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Popol_Vuh_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Roland_Kirk'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Running_Wild_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Scorpions_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Slayer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sparks_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Earle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tangerine_Dream'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Beach_Boys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Byrds'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Chasm_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Doors'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Flaming_Lips'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Gathering_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Velvet_Underground'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Therion_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tim_Hecker'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/U2'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Van_der_Graaf_Generator'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Virgin_Steele'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/XTC'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Boris_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Creedence_Clearwater_Revival'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Death_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Death_Grips'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Depeche_Mode'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Enslaved_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hank_Mobley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Katatonia'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/King_Diamond_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Magma_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Marillion'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Motörhead'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/My_Dying_Bride'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Neurosis_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/R.E.M.'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Roxy_Music'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Savatage'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Talking_Heads'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Allman_Brothers_Band'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Mothers_of_Invention'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Roots'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Smiths'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thin_Lizzy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ween'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Marley_&_The_Wailers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Coil_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Frank_Sinatra'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gentle_Giant'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jethro_Tull_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Judas_Priest'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/King_Crimson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Led_Zeppelin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Porcupine_Tree'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Radiohead'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rush_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sonic_Youth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steely_Dan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stereolab'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Cure'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Mountain_Goats'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Who'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Black_Sabbath'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Iron_Maiden'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Johnny_Cash'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jorge_Ben'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Opeth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pink_Floyd'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Swans_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thelonious_Monk'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Fall_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Kinks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Muddy_Waters'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Rolling_Stones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Beatles'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Miles_Davis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Various_Artists'),)

# %% [markdown]
# Check if I have any DBO.Person in the Graph to see if < Resource > a dbo:Person was inferred from
# the range of the bandMember property + dbo:BandMember rdfs:subClassOf dbo:Person

# %%
query = """
    PREFIX dbo: <http://dbpedia.org/ontology/>
    SELECT ?s
    WHERE {
        # ?s a dbo:Person .
    }
"""

results = g.query(query)

for result in results:
    print(result)
# Out:
# (rdflib.term.URIRef('http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/2-D_(character)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/A-Plus_(rapper)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/A._W._Yrjänä'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaron_Dalbec'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaron_Dessner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaron_Harris_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaron_Lee_Tasjan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaron_Rossi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaron_Stainthorpe'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aaron_Turner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Abdul_%22Duke%22_Fakir'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Abe_Cunningham'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Abradab'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ace_(The_Powerpuff_Girls)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Acey_Slade'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aceyalone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ad-Rock'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Clayton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Darski'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Duce'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Forkner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Jones_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Seymour_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Wiltzie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adam_Yauch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adonay_(músico)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrian_Borland'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrian_Jackson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrian_Oxaal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrian_Portas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrian_Smith'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrian_Utley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrian_White_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Adrián_Terrazas-González'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aesop_Dekker'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Agnetha_Fältskog'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ahrue_Luster'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aidan_Girt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Airto_Moreira'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Akhenaton_(rapper)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aki_Yli-Salomäki'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Al_Atkins'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Al_Barrow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Al_Doyle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Al_Jardine'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Al_Pitrelli'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alain_Guillard'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alain_Johannes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alain_Rochette'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Averill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Bishop'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Cartwright'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Clark_(keyboardist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Fitzgerald'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Gowen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Moore_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Morse'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Myers_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Parsons'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Reale'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Rubin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Spenner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Thomson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_White_(Oasis_drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_White_(Yes_drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alan_Wilder'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alap_Momin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Albert_Griffiths_(reggae_artist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Albert_Hammond_Jr.'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Albert_Kuvezin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alden_Penner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aldo_Tagliapietra'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alec_Baillie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alec_John_Such'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alejandro_Sokol'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Acuña'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Chilton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Hernandez_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Holzwarth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_James_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Lee_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Lifeson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Ligertwood'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Niven'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Rosamilia'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Scally'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Turner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alex_Van_Halen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alexander_Bapa'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alexander_Hacke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alexander_von_Meilenwald'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alexei_Saryglar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alf_Svensson_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Algis_Kizys'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ali-Ollie_Woodson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ali_McMordie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ali_Shaheed_Muhammad'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alison_Faith_Levy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alison_Goldfrapp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alison_Statton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Allan_Schwartzberg'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Allan_Sørensen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Allen_Ravenstine'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Allen_West_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Alvin_Lee'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Amadito_Valdés'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Amy_Crawford_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Amy_Millan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ana_da_Silva'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anatoli_Kuular'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anders_Björler'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anders_Lindström'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anders_Nyström'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andi_Deris'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andi_Kravljaca'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andie_Rathbone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andre_Andersen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrea_Bassato'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andreas_Axelsson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andreas_Blomqvist'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andreas_Kisser'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andreas_Lagios'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andreas_Olsson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Craighan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Eldritch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Falkous'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Innes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Latimer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Powell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Savage_(artist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Shives'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_VanWyngarden'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Vowles'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrew_Whiteman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andrey_Mongush'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/André_Jung_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/André_Olbrich'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Anderson_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Diagram'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Duncan_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Fletcher_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Fraser'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Gill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Hellaby'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Hess'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Hummel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_LaRocque'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Mackay'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Nicholson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Paley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Parker_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Powell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Pyle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Scott_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Sturmer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andy_Summers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anette_Olzon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Angela_Seo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Angry_Anderson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Angus_MacLise'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Angus_Young'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Angá_Díaz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ani_Cordero'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ankatu_Alquinta'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anna_Oxygen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anne_DeMarinis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anneke_van_Giersbergen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Annemarie_Roelofs'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anni-Frid_Lyngstad'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Annie_Haslam'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Annie_Lennox'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anohni'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anthony_Kiedis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anthony_Lant'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anthony_Martinez_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anthony_Moore'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Antoine_Paganotti'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Antonio_Sánchez_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aníbal_Kerpel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Apostolis_Anthimos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aquiles_Priester'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arabian_Prince'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ares_Tavolazzi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ari_Brown'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ariel_Engle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arik_Marshall'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arjen_Anthony_Lucassen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Armando_Marçal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Armando_Peraza'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Armistead_Burwell_Smith_IV'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arnaldo_Antunes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arno_Menses'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arno_Steffen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Art_Blakey'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Art_Garfunkel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Art_Neville'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arthur_Brown_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arthur_Googy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arthur_Kane'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Arve_Isdal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ash_Bowie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ash_Soan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ashley_Naylor'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Atom_Ellis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Atticus_Ross'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Audrey_Sylvain'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aurora_Alquinta'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Avey_Tare'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Axel_Mackenrott'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Axl_Rose'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aynsley_Dunbar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Azita_Youssefi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Aziz_Ibrahim'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/B._J._Wilson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Baba_Sissoko'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Baby_Consuelo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Baby_Stafford'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barbara_Gaskin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barbara_Martin_(singer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barbara_Thompson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barbarito_Torres'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barrie_Cadogan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barry_Andrews_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barry_Burns'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barry_Palmer_(British_singer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barry_Purkis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barry_Stern'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bart_Smits'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bart_Terlaak'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Barthélémy_Attisso'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Baz_Warne'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bekka_Bramlett'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Armstrong_(bass_player)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Bridwell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Christo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_E._King'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Jackson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Kenney'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Koller'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Lurie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Mandelson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Massarella'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Shepherd'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ben_Sidran'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benjamin_Goldwasser'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benjamin_Lazar_Davis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benjamin_Orr'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benjamin_Weikel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benji_Kirkpatrick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benny_Andersson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benny_Golson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benny_Green_(pianist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benoît_Alziary'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Benoît_David'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernard_Butler'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernard_Paganotti'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernard_Sumner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernhard_Beibl'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernie_Marsden'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernie_Shaw'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernie_Tormé'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bernie_Worrell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Berry_Oakley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bert_Sommer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Beth_Gibbons'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Beth_Harrington'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Betsi_Miller'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Betty_McGlown'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bev_Bevan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Beverly_Cotten-Dillard'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bi_Ribeiro'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bias_Boshell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Biff_Byford'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Big_Gipp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Big_John_Bates'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bigg_Jus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bilinda_Butcher'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Berry'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Champlin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Doss'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Drummond'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Evans_(saxophonist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Frisell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Hardman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Kelliher'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Kreutzmann'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Leeb'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Legend'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_MacCormick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Payne'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Pierce_(saxophonist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Pinkney'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Pohl'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Priddle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Wyman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Bremner_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Burnette'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Constable'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Conway_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Corgan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Gibbons'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Greer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Martin_(percussionist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Murcia'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Peterson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Rankin_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Ray_Latham'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Rymer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Werner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Billy_Yule'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Björn_Gelotte'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Björn_Ulvaeus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Black_Thought'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blackie_Lawless'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blaine_L._Reininger'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blair_Cunningham'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blaise_Garza'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blake_Richardson_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blake_Schwarzenbach'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blake_Sennett'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blas_Elias'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blaze_Bayley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blixa_Bargeld'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blondie_Chaplin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blu_(rapper)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blues_Saraceno'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Blurt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bo_Koster'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Bert'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Brunning'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Bryar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Casale'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Catley'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Bob_D'Amico"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Drake_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Egan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Henrit'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_James_(rock_singer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Johnson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Katsionis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Lewis_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Mann_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Mosley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Mothersbaugh'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Mould'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Sawyer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Siebenberg'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Skeat'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Stinson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Weir'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Welch_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bob_Weston_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobbie_Watson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Bare_Jr.'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Broom'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Caldwell_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Dall'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Gustafson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Harrison'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Hendricks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Kildea'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Schayer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Steele'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Timmons'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Watson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Whitlock'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Winkelman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bobby_Woodman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bon_Scott'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bono'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Boots_Riley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bootsy_Collins'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Boris_Williams'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brad_Elrod'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brad_Shepherd'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brad_Whitford'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bradford_Cox'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Branco_Mello'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Branden_Steineckert'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brandon_Cruz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brandon_Pertzborn'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brandt_Brauer_Frick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Branford_Marsalis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brann_Dailor'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brant_Bjork'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brenda_Sauter'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brendan_Canning'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brendan_Kelly_(musician)'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Brendan_O'Hare"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brendan_Perry'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brendan_Reed_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brendt_Allman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brent_Harding'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brent_Liles'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brent_Mydland'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brent_Smedley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bret_Hoffmann'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bret_Michaels'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brett_Anderson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brett_Gurewitz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brett_Nelson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brett_Netson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brett_Reed'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Baker_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Bell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Chippendale'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Connolly'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Cook_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Doherty_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Downey_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Fallon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Faloon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Gibson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Glascock'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Henneman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Johnson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Jones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Koonin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Lee_(singer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Lynch_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_MacLeod_(U.S._musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_May'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_McBride_(artist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_McMahan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Migdol'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Molko'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Ritchie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Robertson_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Viglione'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Britt_Daniel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Britt_Walford'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Franklin_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Gaitsch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Gilbert'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Johnston'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Kulick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Mitchell_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Rowland_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Slesinger'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Smith_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Williamson_(singer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruno_Bernas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruno_Ruder'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruno_Schaab'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bryan_Carrott'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bryan_Devendorf'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bryan_Hipp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bryant_Clifford_Meyer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bryce_Dessner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bryson_Graham'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Buck_Clarke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Buck_Dharma'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Buddy_Miles'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bun_B'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bun_E._Carlos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bunny_Brunel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Burke_Shelley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Burton_C._Bell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bush_Tetras'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Busta_Jones'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Butch_Trucks'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Byron_Berline'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/C'el_Revuelta"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/C.C._DeVille'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/C._J._Ramone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/CEvin_Key'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/CJ_(musician)'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Cait_O'Riordan"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Caitlin_Cary'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Calvin_Johnson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Calvin_Simon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Calvin_Weston'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cameron_Brown_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Camilo_Cintolesi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Candida_Doyle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cappadonna'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Captain_Kirk_Douglas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Caralee_McElroy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Caridad_Hierrezuelo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carl_Broemel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carl_McCoy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carl_Radle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carl_Sentance'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carl_Verheyen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carl_Wilson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carlo_Karges'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carlos_Cadona'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carlos_Garnett'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carmine_Rojas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carsten_Bohn'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carter_Jefferson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carwyn_Ellis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Casey_Chaos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Casey_Crescenzo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Casey_Grillo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cassie_Berman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Catherine_Ribeiro'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cedar_Walton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cedric_Myton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/CeeLo_Green'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Celia_Humphris'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cesar_Rosas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cesareo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chad_Smith'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chalk_Circle_(American_band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charles_Fambrough'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charles_Gavin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charles_Gocher'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charles_Hedger'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charles_Miller_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charles_Spearin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charlie_Burchill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charlie_Dominici'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charlie_Quintana'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charlie_Thomas_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charlie_Watts'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charly_Alberti'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chas_Cronk'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cherisse_Osei'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ches_Smith'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chi_Cheng_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chick_Churchill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chino_Moreno'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chip_Fields'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chiqui_Mariscal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Abrahams'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Baio'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Bell_(American_musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Braide'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Bratton_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Caffery'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Chaney'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Collins_(singer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Connelly_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Copping'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Curtis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Darrow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_DeGarmo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Difford'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Estes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Ethridge'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Frantz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Funk'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Geddes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Goss'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Hillman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Jasper'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Joyce'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Karrer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Kringel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Leslie_(folk_musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Lowe'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Maitland'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Mars'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Martin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Masuak'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_McCaughan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Payne_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Pennie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Pinnick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Prescott'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Rainbow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Reifert'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Robinson_(singer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Robison'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Slade'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Stainton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Stein'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Stewart_(author)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Stroffolino'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Tomson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Von_Sneidern'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Walla'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Wilson_(American_musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Wolstenholme'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chrissie_Hynde'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christ._(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christer_Espevoll'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_%22Witchhunter%22_Dudek'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Andreu'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Genet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Giesler'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Lasegue'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Lorenz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Olde_Wolbers'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Savill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Schmiel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Vander_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Vidal'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christian_Wargo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christine_McVie'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christofer_Johnsson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christoph_Heemann'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christoph_Schneider'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christopher_Amott'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christopher_Holland'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christopher_Pravdica'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Christopher_Tsagakis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chuck_Biscuits'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chuck_Cleaver'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chuck_D'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chuck_Dukowski'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chuck_Leavell'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chuck_Mangione'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chuck_Treece'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cian_Ciaran'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cindy_Birdsong'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cindy_Wilson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Circulus_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ciro_Pessoa'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clarence_%22Fuzzy%22_Haskins'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clarence_Seay'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Claudia_Brücken'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Claudia_Gonson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Claudio_Galieti'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Claudio_Parra'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Claudio_Sanchez'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clem_Clempson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cliff_Burton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cliff_Hugo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cliff_Martinez'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cliff_Williams'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clint_Conley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clint_Warwick'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clinton_Fearon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clinton_McKinnon_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clive_Burr'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clive_Palmer_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clyde_McPhatter'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Clyde_Stubblefield'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Coady_Willis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Coke_Escovedo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Bass'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Burgess_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Edwin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Greenwood'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Hodgkinson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Marston'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Meloy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Pearson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Sears'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Colin_Sharp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Compay_Segundo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Conny_Veit'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Conor_Oberst'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Conrad_Lant'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Conrad_Lozano'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Conrad_Schnitzler'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Console_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cook_Craig'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cordell_Mosson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Corky_Laing'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Courtney_Love'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Craig_Frost'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Craig_Fuller'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Craig_Goldy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Craig_Hooper'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cris_Kirkwood'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cuong_Vu'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Curt_Boettcher'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Curt_Cress'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Curt_Kirkwood'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Curtis_Fowlkes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Curtis_Fuller'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Curtis_Salgado'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cuti_Aste'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cyril_Jordan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Cyril_Neville'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/D'arcy_Wretzky"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/D._Boon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/D._C._Cooper'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/DJ_Feel-X'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/DJ_Lord'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/DJ_Premier'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/DJ_Subroc'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/DJ_Swamp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/DJ_Yella'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/DNA_Doe_Project'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Daddy_G'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dafydd_Ieuan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dagmar_Krause'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dale_Barlow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dale_Crover'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dale_Griffin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dale_Turner_(trumpeter)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dallas_Toler-Wade'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damo_Suzuki'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damon_Albarn'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damon_Edge'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damon_Good'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damon_Harris'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damon_Johnson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damon_Krukowski'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Damon_Reece'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dan_Ar_Braz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dan_Aykroyd'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dan_Bejar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dan_Berglund'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dan_Boeckner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dan_Braun'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dan_Briggs_(musician)'),)
# ...
# (rdflib.term.URIRef('http://dbpedia.org/resource/Louis_Cennamo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Louis_Price'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Luther_Grosvenor'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Luther_Rabb'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/MF_Doom'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Magnus_Sahlgren'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Malcolm_Mortimore'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Manfred_Mann_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Manuel_%22Puntillita%22_Licea'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Clarke_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Evans_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Hart'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Heaney'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Hollis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Ibold'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Kozelek'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Martin_Duffy_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Matti_Kärki'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mattias_Bärjed'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Max_Johnston_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mayhem_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Michael_Amott'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Michael_Cartellone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Michael_Hoenig'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Michael_McDonald_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Michael_Rother'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Michael_Wulf'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mick_Pointer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mickey_Simmonds'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mikael_Stanne'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mikael_Åkerfeldt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Heidorn'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Joyce_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Kinsella'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Mangini'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Portnoy'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Scalzi'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Watt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Wead'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Milla_Kapolke'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Miller_Anderson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Narada_Michael_Walden'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Neige_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Neil_Finn'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Nick_D'Virgilio"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nick_Oliveri'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nick_Sanderson_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nicke_Andersson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nicky_Hopkins'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nigel_Pegrum'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nocturno_Culto'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Ol'_Dirty_Bastard"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Omar_Rodríguez-López'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Orlando_%22Cachaíto%22_López'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Owen_Biddle_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paddy_McAloon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Patrick_Moraz'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_Gray_(English_musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_Hinojos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_McCartney'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_Weller'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_Wertico'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pete_Gill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pete_Solley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pete_Trewavas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Peter_Hook'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pharoahe_Monch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Phil_Elverum'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Phil_King_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pip_Pyle'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pusha_T'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pío_Leyva'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Randy_Black'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ray_Davis_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Richard_Barbieri'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rick_Kemp'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ricky_Fataar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rob_Halford'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Robert_Pollard'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Robert_Trujillo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Robo_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rod_Evans'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Roky_Erickson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Roland_Grapow'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rubén_González_(pianist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ry_Cooder'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ryan_Adams'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sami_Yaffa'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sammy_Hagar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sara_Lee_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sascha_Paeth'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Scott_Reeder_(bassist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Scott_Travis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sean_Price'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Snowy_Shaw'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stefan_Schwarzmann'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stephen_Malkmus'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Albini'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Hillage'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Jolliffe'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Morse'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_West_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steven_Wilson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Stone_Gossard'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Syd_Barrett'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ted_Parsons'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Terry_Woods'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Specials'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Triffids'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Theo_Peoples'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thomas_Pridgen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thurston_Moore'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Timi_Hansen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Todd_La_Torre'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tomas_Lindberg'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tommy_Bolin'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tommy_Karevik'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tommy_Victor'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tony_Maimone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tony_Newman_(drummer)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Trevor_Lucas'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Trey_Spruance'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Uwe_Lulis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Vangelis'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Vincent_Crane'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Vocals'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wagner_Lamounier'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Warren_Haynes'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wayne_Kramer_(guitarist)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/William_Breeze'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Álvaro_Henríquez'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Andre_Matos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bass_guitar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bill_Bruford'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brendan_Canty'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Dickinson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Buddy_Holly'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Carl_Palmer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chick_Corea'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Chris_Cutler'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dave_Gregory_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Devin_Townsend'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Donald_Byrd'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eddie_Jobson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eddie_Vedder'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Flea_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gene_Hoglan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gerry_Conway_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ginger_Baker'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gram_Parsons'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ibrahim_Ferrer'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jari_Kainulainen'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jason_Newsted'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Joe_Comeau'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Joey_Vera'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/John_Cale'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Josh_Homme'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jörg_Michael'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kenny_Aaronson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lech_Janerka'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lindsay_Cooper'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Linton_Kwesi_Johnson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Marky_Ramone'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Martin_Jackson'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Masta_Ace'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_McCready'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mike_Patton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mikkey_Dee'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Morrissey'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_Bostaph'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_Raven_(musician)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Paul_Simon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Pedro_Aznar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Phil_Miller'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Raekwon'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Richard_Sinclair'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Robert_Wyatt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Robin_Trower'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Roine_Stolt'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Rowland_S._Howard'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Sharlee_D'Angelo"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Thighpaulsandra'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tony_Campos'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Trevor_Dunn'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Uli_Kusch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Anton_Fier'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brockhampton_(band)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dave_Lombardo'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dave_Sinclair'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dr._Dre'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Drum_kit'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/El-P'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Gene_Clark'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ghostface_Killah'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Guitar'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ice_Cube'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jeff_Rosenstock'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Johnny_Marr'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jonny_Greenwood'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kamelot'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Keith_Jarrett'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Kenny_Dorham'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lou_Reed'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Manuel_Göttsching'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Matt_Cameron'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Paysage_d'Hiver"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Steve_Hackett'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Charly_García'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Danny_Elfman'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/David_Sylvian'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eric_Clapton'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jackie_McLean'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Jackson_Browne'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/John_Frusciante'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Luis_Alberto_Spinetta'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Madlib'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Nico'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Peter_Gabriel'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Ryuichi_Sakamoto'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Sandy_Denny'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Waylon_Jennings'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bert_Jansch'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Curtis_Mayfield'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Hank_Mobley'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/John_Zorn'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Mark_Lanegan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Neal_Morse'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Neil_Young'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Peter_Hammill'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Mothers_of_Invention'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brian_Eno'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Freddie_Hubbard'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Klaus_Schulze'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Lee_Morgan'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Wayne_Shorter'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/McCoy_Tyner'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Bruce_Springsteen'),)

# %% [markdown]
# Check for albums that are both Southern_Rock and Rock_music / Punk_Rock and Rock_music to see if the subclass relations added in the genres taxonomy section hold.

# %%
query = """

    SELECT ?s
    WHERE {
        # ?s a <http://dbpedia.org/resource/Rock_music> .
        # ?s a <http://dbpedia.org/resource/Southern_Rock> .
    }
"""

results = g.query(query)

for result in results:
    print(result)
# Out:
# (rdflib.term.URIRef("http://dbpedia.org/resource/(pronounced_'leh-'nerd_'skin-'nerd)"),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/(pronounced_'lĕh-'nérd_'skin-'nérd)"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Beggars_Banquet'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Brothers_and_Sisters'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Decoration_Day'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dixie_Chicken'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Dose'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Eat_a_Peach'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Feats_Don't_Fail_Me_Now"),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Hittin'_the_Note"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Idlewild_South'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/It_Still_Moves'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Life_Before_Insanity'),)
# (rdflib.term.URIRef("http://dbpedia.org/resource/Sailin'_Shoes"),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Second_Helping'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Southern_Rock_Opera'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Street_Survivors'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Allman_Brothers_Band_(album)'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Deep_End,_Volume_1'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Dirty_South'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/The_Southern_Harmony_and_Musical_Companion'),)
# (rdflib.term.URIRef('http://dbpedia.org/resource/Tres_Hombres'),)

# %% [markdown]
# ### **`6. Query the Graph`**
#
# Query your graph in a way that:
# - the usefulness of having added information from dbpedia is highlighted
# - inference is exploited
#
#
# **<ins>Some</ins>**  **<ins>examples</ins>** with the intentions:
#
#
# | ID | Query | Intention/insight |
# |----|------|-------------------|
# | 1  | which bands have at least one member with a different nationality? | just curiosity |
# | 2  | Which are the artist with many bands? | to spot session musicians, long-career artists, 'eclectic' artists |
# | 3  | which are the countries with more [ Latin Rock ]( https://en.wikipedia.org/wiki/Latin_rock ) bands? and what about [ Black Metal ]( https://en.wikipedia.org/wiki/Black_metal )? | I suppose that latin rock is more popular in Latin America countries while Black Metal in Scandinavian countries, but I may be wrong! |
# | 4  | Is there any artist who is a member of both a [ Britpop ]( https://en.wikipedia.org/wiki/Britpop ) band and a [ Hip hop ]( https://en.wikipedia.org/wiki/Hip_hop_music ) band | maybe to spot bands/artists with a strong musical contamination? e.g., [Damon Albarn ](https://en.wikipedia.org/wiki/Damon_Albarn) |
# | 5  | Which is the city with more bands in absolute? and what if we consider only [ Grunge ]( https://en.wikipedia.org/wiki/Grunge )? | maybe to discover a music scene or just a very influential city. |
# | 6  | Give me some band/artist from the same city of [ 2Pac ]( https://en.wikipedia.org/wiki/Tupac_Shakur ) | could be a way to find similar musical artists. What about adding also a time period and the musical genre? |
# | 7  | which are the bands with Argentine and Spanish members? | maybe because I love both the Argentine and Spanish sound and I hope there is something that matches both? e.g., [Los Rodriguez](https://en.wikipedia.org/wiki/Los_Rodr%C3%ADguez) |
#
#
#
#
# **Feel free to play and get cool insights**

# %% [markdown]
# Find Countries with black metal bands.

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?country (COUNT(?band) as ?count) 
    WHERE {
        # ?band a ns3:Band ;
            ns3:origin ?country ;
            ns1:bandGenres <http://dbpedia.org/resource/Black_Metal> .
    }
    GROUP BY ?country
    ORDER BY DESC(?count)
    """)

for row in qres:
    print("%s has %s Black Metal bands" % row)
# Out:
# http://dbpedia.org/resource/Norway has 6 Black Metal bands
# http://dbpedia.org/resource/Poland has 3 Black Metal bands
# http://dbpedia.org/resource/France has 2 Black Metal bands
# http://dbpedia.org/resource/Finland has 2 Black Metal bands
# http://dbpedia.org/resource/Switzerland has 1 Black Metal bands
# http://dbpedia.org/resource/United_States has 1 Black Metal bands

# %% [markdown]
# Find the cities with the most Bands.

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?city (COUNT(?band) as ?count) 
    WHERE {
        # ?band a ns3:Band ;
            ns3:hometown ?city .
    }
    GROUP BY ?city
    ORDER BY DESC(?count)
    """)

for row in qres:
    print("%s has %s bands" % row)
# Out:
# http://dbpedia.org/resource/London has 52 bands
# http://dbpedia.org/resource/New_York_City has 28 bands
# http://dbpedia.org/resource/Los_Angeles has 28 bands
# http://dbpedia.org/resource/San_Francisco has 19 bands
# http://dbpedia.org/resource/Seattle has 15 bands
# http://dbpedia.org/resource/Birmingham has 14 bands
# http://dbpedia.org/resource/Stockholm has 13 bands
# http://dbpedia.org/resource/Long_Island has 10 bands
# http://dbpedia.org/resource/Melbourne has 8 bands
# http://dbpedia.org/resource/Chicago has 8 bands
# http://dbpedia.org/resource/Helsinki has 8 bands
# http://dbpedia.org/resource/Gothenburg has 8 bands
# http://dbpedia.org/resource/Manchester has 8 bands
# http://dbpedia.org/resource/Hamburg has 8 bands
# http://dbpedia.org/resource/Sydney has 8 bands
# http://dbpedia.org/resource/Boston has 8 bands
# http://dbpedia.org/resource/Austin,_Texas has 7 bands
# http://dbpedia.org/resource/Buenos_Aires has 7 bands
# http://dbpedia.org/resource/San_Francisco,_California has 7 bands
# http://dbpedia.org/resource/Tokyo has 7 bands
# http://dbpedia.org/resource/Montreal has 7 bands
# http://dbpedia.org/resource/Brooklyn has 6 bands
# http://dbpedia.org/resource/Washington,_D.C. has 6 bands
# http://dbpedia.org/resource/Detroit has 6 bands
# http://dbpedia.org/resource/Glasgow has 6 bands
# http://dbpedia.org/resource/Olympia,_Washington has 6 bands
# http://dbpedia.org/resource/Canterbury has 6 bands
# http://dbpedia.org/resource/Milan has 5 bands
# http://dbpedia.org/resource/Toronto has 5 bands
# http://dbpedia.org/resource/Munich has 5 bands
# http://dbpedia.org/resource/Bristol has 5 bands
# http://dbpedia.org/resource/Portland,_Oregon has 5 bands
# http://dbpedia.org/resource/Vancouver has 5 bands
# http://dbpedia.org/resource/Tampa,_Florida has 5 bands
# http://dbpedia.org/resource/Copenhagen has 5 bands
# http://dbpedia.org/resource/Athens,_Georgia has 5 bands
# http://dbpedia.org/resource/Berlin has 4 bands
# http://dbpedia.org/resource/Kingston,_Jamaica has 4 bands
# http://dbpedia.org/resource/Los_Angeles,_California has 4 bands
# http://dbpedia.org/resource/Phoenix,_Arizona has 4 bands
# http://dbpedia.org/resource/Leeds has 4 bands
# http://dbpedia.org/resource/Cleveland has 4 bands
# http://dbpedia.org/resource/Cardiff has 4 bands
# http://dbpedia.org/resource/Cincinnati has 4 bands
# http://dbpedia.org/resource/Memphis,_Tennessee has 4 bands
# http://dbpedia.org/resource/Sacramento,_California has 4 bands
# http://dbpedia.org/resource/San_Jose,_California has 4 bands
# http://dbpedia.org/resource/Edinburgh has 4 bands
# http://dbpedia.org/resource/Paris has 4 bands
# http://dbpedia.org/resource/Sheffield has 3 bands
# http://dbpedia.org/resource/Cambridge has 3 bands
# http://dbpedia.org/resource/Warsaw has 3 bands
# http://dbpedia.org/resource/Newark,_New_Jersey has 3 bands
# http://dbpedia.org/resource/Oakland,_California has 3 bands
# http://dbpedia.org/resource/Buffalo,_New_York has 3 bands
# http://dbpedia.org/resource/Long_Beach,_California has 3 bands
# http://dbpedia.org/resource/Rome has 3 bands
# http://dbpedia.org/resource/San_Diego has 3 bands
# http://dbpedia.org/resource/Düsseldorf has 3 bands
# http://dbpedia.org/resource/Mexico_City has 3 bands
# http://dbpedia.org/resource/Athens has 3 bands
# http://dbpedia.org/resource/Philadelphia has 3 bands
# http://dbpedia.org/resource/Hereford has 3 bands
# http://dbpedia.org/resource/Liverpool has 3 bands
# http://dbpedia.org/resource/Newcastle_upon_Tyne has 3 bands
# http://dbpedia.org/resource/Bergen has 3 bands
# http://dbpedia.org/resource/Dublin has 3 bands
# http://dbpedia.org/resource/Denver has 2 bands
# http://dbpedia.org/resource/Minneapolis has 2 bands
# http://dbpedia.org/resource/Vienna has 2 bands
# http://dbpedia.org/resource/Las_Vegas_Valley has 2 bands
# http://dbpedia.org/resource/El_Paso,_Texas has 2 bands
# http://dbpedia.org/resource/Madrid has 2 bands
# http://dbpedia.org/resource/Chapel_Hill,_North_Carolina has 2 bands
# http://dbpedia.org/resource/Perth has 2 bands
# http://dbpedia.org/resource/Richmond,_Virginia has 2 bands
# http://dbpedia.org/resource/Bellingham,_Washington has 2 bands
# http://dbpedia.org/resource/Minneapolis,_Minnesota has 2 bands
# http://dbpedia.org/resource/Bellevue,_Washington has 2 bands
# http://dbpedia.org/resource/Belfast has 2 bands
# http://dbpedia.org/resource/Osaka has 2 bands
# http://dbpedia.org/resource/Middletown,_Connecticut has 2 bands
# http://dbpedia.org/resource/Atlanta,_Georgia has 2 bands
# http://dbpedia.org/resource/Flint,_Michigan has 2 bands
# http://dbpedia.org/resource/St._Louis,_Missouri has 2 bands
# http://dbpedia.org/resource/Katowice has 2 bands
# http://dbpedia.org/resource/Mysłowice has 2 bands
# http://dbpedia.org/resource/Denton,_Texas has 2 bands
# http://dbpedia.org/resource/Kharkiv has 2 bands
# http://dbpedia.org/resource/Oxnard,_California has 2 bands
# http://dbpedia.org/resource/Berkeley,_California has 2 bands
# http://dbpedia.org/resource/Miami,_Florida has 2 bands
# http://dbpedia.org/resource/Belo_Horizonte has 2 bands
# http://dbpedia.org/resource/Gelsenkirchen has 2 bands
# http://dbpedia.org/resource/Louisville,_Kentucky has 2 bands
# http://dbpedia.org/resource/Belleville,_Illinois has 2 bands
# http://dbpedia.org/resource/Brighton has 2 bands
# http://dbpedia.org/resource/Amsterdam has 2 bands
# http://dbpedia.org/resource/New_Brunswick,_New_Jersey has 2 bands
# http://dbpedia.org/resource/Tacoma,_Washington has 2 bands
# http://dbpedia.org/resource/Guildford has 2 bands
# http://dbpedia.org/resource/Stavanger has 2 bands
# http://dbpedia.org/resource/West_Berlin has 2 bands
# http://dbpedia.org/resource/Cologne has 2 bands
# http://dbpedia.org/resource/Raleigh,_North_Carolina has 2 bands
# http://dbpedia.org/resource/Sarasota,_Florida has 2 bands
# http://dbpedia.org/resource/Atlanta has 2 bands
# http://dbpedia.org/resource/Cambridge,_Massachusetts has 2 bands
# http://dbpedia.org/resource/Houston has 2 bands
# http://dbpedia.org/resource/Eskilstuna has 2 bands
# http://dbpedia.org/resource/Providence,_Rhode_Island has 2 bands
# http://dbpedia.org/resource/Arlington,_Texas has 2 bands
# http://dbpedia.org/resource/Alexandria,_Virginia has 2 bands
# http://dbpedia.org/resource/Oxford has 2 bands
# http://dbpedia.org/resource/Hoboken,_New_Jersey has 2 bands
# http://dbpedia.org/resource/Coventry has 2 bands
# http://dbpedia.org/resource/Zürich has 2 bands
# http://dbpedia.org/resource/Palm_Desert,_California has 2 bands
# http://dbpedia.org/resource/Nottingham has 2 bands
# http://dbpedia.org/resource/Jacksonville,_Florida has 2 bands
# http://dbpedia.org/resource/Oxford,_Ohio has 1 bands
# http://dbpedia.org/resource/Sweden_in_the_Eurovision_Song_Contest has 1 bands
# http://dbpedia.org/resource/Placentia,_California has 1 bands
# http://dbpedia.org/resource/Cork_(city) has 1 bands
# http://dbpedia.org/resource/Charlottetown has 1 bands
# http://dbpedia.org/resource/Urbana,_Illinois has 1 bands
# http://dbpedia.org/resource/Belfort has 1 bands
# http://dbpedia.org/resource/Gainesville,_Florida has 1 bands
# http://dbpedia.org/resource/Gdańsk has 1 bands
# http://dbpedia.org/resource/Eau_Claire,_Wisconsin has 1 bands
# http://dbpedia.org/resource/Luleå has 1 bands
# http://dbpedia.org/resource/Rzeszów has 1 bands
# http://dbpedia.org/resource/Rochester,_New_York has 1 bands
# http://dbpedia.org/resource/Tampa has 1 bands
# http://dbpedia.org/resource/Tucson,_Arizona has 1 bands
# http://dbpedia.org/resource/Arad,_Romania has 1 bands
# http://dbpedia.org/resource/Växjö has 1 bands
# http://dbpedia.org/resource/Moscow has 1 bands
# http://dbpedia.org/resource/Ventura,_California has 1 bands
# http://dbpedia.org/resource/Wolverhampton has 1 bands
# http://dbpedia.org/resource/Pori has 1 bands
# http://dbpedia.org/resource/Kuopio has 1 bands
# http://dbpedia.org/resource/Wellington,_New_Zealand has 1 bands
# http://dbpedia.org/resource/Manhattan_Beach,_California has 1 bands
# http://dbpedia.org/resource/Akron,_Ohio has 1 bands
# http://dbpedia.org/resource/Stoke-on-Trent has 1 bands
# http://dbpedia.org/resource/Leipzig has 1 bands
# http://dbpedia.org/resource/Oulu has 1 bands
# http://dbpedia.org/resource/Barcelona has 1 bands
# http://dbpedia.org/resource/Plasencia has 1 bands
# http://dbpedia.org/resource/Mjölby has 1 bands
# http://dbpedia.org/resource/Lugano has 1 bands
# http://dbpedia.org/resource/Modesto,_California has 1 bands
# http://dbpedia.org/resource/Gladbeck has 1 bands
# http://dbpedia.org/resource/Kristiansand has 1 bands
# http://dbpedia.org/resource/Wolfsburg has 1 bands
# http://dbpedia.org/resource/Hollywood,_Los_Angeles has 1 bands
# http://dbpedia.org/resource/Charlotte,_North_Carolina has 1 bands
# http://dbpedia.org/resource/Belgrade has 1 bands
# http://dbpedia.org/resource/Tempe,_Arizona has 1 bands
# http://dbpedia.org/resource/Colorado_Springs,_Colorado has 1 bands
# http://dbpedia.org/resource/Eugene,_Oregon has 1 bands
# http://dbpedia.org/resource/Philadelphia,_Pennsylvania has 1 bands
# http://dbpedia.org/resource/Mesa,_Arizona has 1 bands
# http://dbpedia.org/resource/Monterrey,_Nuevo_León has 1 bands
# http://dbpedia.org/resource/Long_Beach,_New_York has 1 bands
# http://dbpedia.org/resource/Wroclaw has 1 bands
# http://dbpedia.org/resource/New_York,_NY has 1 bands
# http://dbpedia.org/resource/Wrocław has 1 bands
# http://dbpedia.org/resource/Borås has 1 bands
# http://dbpedia.org/resource/Huntington_Beach,_California has 1 bands
# http://dbpedia.org/resource/Stamford,_Connecticut has 1 bands
# http://dbpedia.org/resource/Glasgow,_Scotland has 1 bands
# http://dbpedia.org/resource/Granada has 1 bands
# http://dbpedia.org/resource/Miami has 1 bands
# http://dbpedia.org/resource/Prague has 1 bands
# http://dbpedia.org/resource/Syracuse,_New_York has 1 bands
# http://dbpedia.org/resource/Santa_Monica,_California has 1 bands
# http://dbpedia.org/resource/Sheboygan,_Wisconsin has 1 bands
# http://dbpedia.org/resource/Alliance,_Ohio has 1 bands
# http://dbpedia.org/resource/Annapolis,_Maryland has 1 bands
# http://dbpedia.org/resource/Adelaide,_South_Australia has 1 bands
# http://dbpedia.org/resource/Compton,_California has 1 bands
# http://dbpedia.org/resource/Timișoara has 1 bands
# http://dbpedia.org/resource/Columbus,_Ohio has 1 bands
# http://dbpedia.org/resource/Kitee has 1 bands
# http://dbpedia.org/resource/Dallas,_Texas has 1 bands
# http://dbpedia.org/resource/Long_Island,_New_York has 1 bands
# http://dbpedia.org/resource/Dakar has 1 bands
# http://dbpedia.org/resource/Washington_DC has 1 bands
# http://dbpedia.org/resource/Porto has 1 bands
# http://dbpedia.org/resource/Bat_Yam has 1 bands
# http://dbpedia.org/resource/Petah_Tikva has 1 bands
# http://dbpedia.org/resource/Bahia,_Brazil has 1 bands
# http://dbpedia.org/resource/Southend-on-Sea has 1 bands
# http://dbpedia.org/resource/Leicester has 1 bands
# http://dbpedia.org/resource/Santiago,_Chile has 1 bands
# http://dbpedia.org/resource/Seal_Beach,_California has 1 bands
# http://dbpedia.org/resource/Antioch,_California has 1 bands
# http://dbpedia.org/resource/Oslo has 1 bands
# http://dbpedia.org/resource/Ellensburg,_Washington has 1 bands
# http://dbpedia.org/resource/Northampton,_Massachusetts has 1 bands
# http://dbpedia.org/resource/Chicago,_Illinois has 1 bands
# http://dbpedia.org/resource/Puławy has 1 bands
# http://dbpedia.org/resource/Schiedam has 1 bands
# http://dbpedia.org/resource/New_Braunfels,_Texas has 1 bands
# http://dbpedia.org/resource/Riihimäki has 1 bands
# http://dbpedia.org/resource/Las_Vegas has 1 bands
# http://dbpedia.org/resource/Fullerton,_California has 1 bands
# http://dbpedia.org/resource/East_Oakland,_Oakland,_California has 1 bands
# http://dbpedia.org/resource/Crown_Heights,_Brooklyn has 1 bands
# http://dbpedia.org/resource/Calumet_City,_Illinois has 1 bands
# http://dbpedia.org/resource/Douglasville,_Georgia has 1 bands
# http://dbpedia.org/resource/Lubbock,_Texas has 1 bands
# http://dbpedia.org/resource/Trollhättan has 1 bands
# http://dbpedia.org/resource/Salem,_Missouri has 1 bands
# http://dbpedia.org/resource/Portland,_OR has 1 bands
# http://dbpedia.org/resource/Shinjuku,_Tokyo has 1 bands
# http://dbpedia.org/resource/Worcester,_Massachusetts has 1 bands
# http://dbpedia.org/resource/Lancaster,_Pennsylvania has 1 bands
# http://dbpedia.org/resource/Murfreesboro,_Tennessee has 1 bands
# http://dbpedia.org/resource/Lund has 1 bands
# http://dbpedia.org/resource/Albuquerque,_New_Mexico has 1 bands
# http://dbpedia.org/resource/Windsor,_Ontario has 1 bands
# http://dbpedia.org/resource/Derry has 1 bands
# http://dbpedia.org/resource/Trondheim has 1 bands
# http://dbpedia.org/resource/Irvine,_California has 1 bands
# http://dbpedia.org/resource/Malmö has 1 bands
# http://dbpedia.org/resource/Billboard_200 has 1 bands
# http://dbpedia.org/resource/Cedar_Rapids,_Iowa has 1 bands
# http://dbpedia.org/resource/Pasadena,_California has 1 bands
# http://dbpedia.org/resource/Adelaide has 1 bands
# http://dbpedia.org/resource/Dearborn,_Michigan has 1 bands
# http://dbpedia.org/resource/Calgary has 1 bands
# http://dbpedia.org/resource/Indianapolis has 1 bands
# http://dbpedia.org/resource/Houma,_Louisiana has 1 bands
# http://dbpedia.org/resource/Ottawa has 1 bands
# http://dbpedia.org/resource/St._Petersburg,_Florida has 1 bands
# http://dbpedia.org/resource/Swansea has 1 bands
# http://dbpedia.org/resource/Evanston,_Illinois has 1 bands
# http://dbpedia.org/resource/Hermosa_Beach,_California has 1 bands
# http://dbpedia.org/resource/Denver,_Colorado has 1 bands
# http://dbpedia.org/resource/Mülheim_an_der_Ruhr has 1 bands
# http://dbpedia.org/resource/Omaha,_Nebraska has 1 bands
# http://dbpedia.org/resource/Fort_Collins has 1 bands
# http://dbpedia.org/resource/Tucson has 1 bands
# http://dbpedia.org/resource/Virginia_Beach,_Virginia has 1 bands
# http://dbpedia.org/resource/Melbourne,_Victoria has 1 bands
# http://dbpedia.org/resource/Brooklyn,_New_York has 1 bands
# http://dbpedia.org/resource/Cortland,_New_York has 1 bands
# http://dbpedia.org/resource/Richmond,_California has 1 bands
# http://dbpedia.org/resource/New_Orleans,_Louisiana has 1 bands
# http://dbpedia.org/resource/Minato,_Tokyo has 1 bands
# http://dbpedia.org/resource/The_Hague has 1 bands
# http://dbpedia.org/resource/Champaign,_Illinois has 1 bands
# http://dbpedia.org/resource/Boston,_Massachusetts has 1 bands
# http://dbpedia.org/resource/Springfield,_Missouri has 1 bands
# http://dbpedia.org/resource/Grand_Rapids,_Michigan has 1 bands
# http://dbpedia.org/resource/Marghera has 1 bands
# http://dbpedia.org/resource/Venice has 1 bands
# http://dbpedia.org/resource/Viña_del_Mar has 1 bands
# http://dbpedia.org/resource/San_Miguel,_Chile has 1 bands
# http://dbpedia.org/resource/Lincoln_Park,_Michigan has 1 bands
# http://dbpedia.org/resource/Lisbon has 1 bands
# http://dbpedia.org/resource/Chester has 1 bands
# http://dbpedia.org/resource/Hellerup has 1 bands
# http://dbpedia.org/resource/Ruston,_Louisiana has 1 bands
# http://dbpedia.org/resource/Greenville,_South_Carolina has 1 bands
# http://dbpedia.org/resource/Tampere has 1 bands
# http://dbpedia.org/resource/Stroud,_Gloucestershire has 1 bands
# http://dbpedia.org/resource/Guelph has 1 bands
# http://dbpedia.org/resource/Hurlingham,_Buenos_Aires has 1 bands
# http://dbpedia.org/resource/Bath,_Somerset has 1 bands
# http://dbpedia.org/resource/Chattanooga,_Tennessee has 1 bands
# http://dbpedia.org/resource/Canton,_Ohio has 1 bands
# http://dbpedia.org/resource/Kingston,_Ontario has 1 bands
# http://dbpedia.org/resource/Perth,_Western_Australia has 1 bands
# http://dbpedia.org/resource/Winnipeg has 1 bands
# http://dbpedia.org/resource/Nashville,_Tennessee has 1 bands
# http://dbpedia.org/resource/Port_Arthur,_Texas has 1 bands
# http://dbpedia.org/resource/Olsztyn has 1 bands
# http://dbpedia.org/resource/Milwaukee has 1 bands
# http://dbpedia.org/resource/Hønefoss has 1 bands
# http://dbpedia.org/resource/Sopot has 1 bands
# http://dbpedia.org/resource/Solingen has 1 bands
# http://dbpedia.org/resource/Baltimore,_Maryland has 1 bands
# http://dbpedia.org/resource/Boise,_Idaho has 1 bands
# http://dbpedia.org/resource/Lexington,_Kentucky has 1 bands
# http://dbpedia.org/resource/Poitiers has 1 bands
# http://dbpedia.org/resource/Bremen has 1 bands
# http://dbpedia.org/resource/Palo_Alto,_California has 1 bands
# http://dbpedia.org/resource/Zaragoza has 1 bands
# http://dbpedia.org/resource/Joensuu has 1 bands
# http://dbpedia.org/resource/Topeka,_Kansas has 1 bands
# http://dbpedia.org/resource/Concepción,_Chile has 1 bands
# http://dbpedia.org/resource/Montesano,_Washington has 1 bands
# http://dbpedia.org/resource/Issaquah,_Washington has 1 bands
# http://dbpedia.org/resource/Anacortes,_Washington has 1 bands
# http://dbpedia.org/resource/Eureka,_California has 1 bands
# http://dbpedia.org/resource/Örebro has 1 bands
# http://dbpedia.org/resource/La_Plata has 1 bands
# http://dbpedia.org/resource/Provincia_de_Buenos_Aires has 1 bands
# http://dbpedia.org/resource/Enschede has 1 bands
# http://dbpedia.org/resource/El_Cajon,_California has 1 bands
# http://dbpedia.org/resource/Lohja has 1 bands
# http://dbpedia.org/resource/Glendale,_California has 1 bands
# http://dbpedia.org/resource/New_Orleans has 1 bands
# http://dbpedia.org/resource/Shreveport,_Louisiana has 1 bands
# http://dbpedia.org/resource/Aurora,_Illinois has 1 bands
# http://dbpedia.org/resource/Auckland has 1 bands
# http://dbpedia.org/resource/Baltimore has 1 bands
# http://dbpedia.org/resource/Vällingby has 1 bands
# http://dbpedia.org/resource/Krefeld has 1 bands
# http://dbpedia.org/resource/San_Marcos,_Texas has 1 bands
# http://dbpedia.org/resource/Leesburg,_Virginia has 1 bands
# http://dbpedia.org/resource/Rockford,_Illinois has 1 bands
# http://dbpedia.org/resource/Sherbrooke has 1 bands
# http://dbpedia.org/resource/Dayton,_Ohio has 1 bands
# http://dbpedia.org/resource/Saint_Paul,_Minnesota has 1 bands
# http://dbpedia.org/resource/Southampton has 1 bands
# http://dbpedia.org/resource/Johnstown,_Pennsylvania has 1 bands
# http://dbpedia.org/resource/Essen,_Germany has 1 bands
# http://dbpedia.org/resource/Notodden has 1 bands
# http://dbpedia.org/resource/Wichita,_Kansas has 1 bands
# http://dbpedia.org/resource/Aberdeen,_Washington has 1 bands
# http://dbpedia.org/resource/Siemianowice_Śląskie has 1 bands
# http://dbpedia.org/resource/Reykjavík has 1 bands
# http://dbpedia.org/resource/Tumwater,_Washington has 1 bands
# http://dbpedia.org/resource/Salem,_Massachusetts has 1 bands
# http://dbpedia.org/resource/Plainfield,_New_Jersey has 1 bands
# http://dbpedia.org/resource/Yonkers,_New_York has 1 bands
# http://dbpedia.org/resource/Duluth,_Minnesota has 1 bands
# http://dbpedia.org/resource/Lee's_Summit has 1 bands
# http://dbpedia.org/resource/Stockton,_California has 1 bands
# http://dbpedia.org/resource/Hanover has 1 bands
# http://dbpedia.org/resource/Huntington_Park,_California has 1 bands
# http://dbpedia.org/resource/San_Antonio has 1 bands
# http://dbpedia.org/resource/Hawthorne,_California has 1 bands
# http://dbpedia.org/resource/Oklahoma_City,_Oklahoma has 1 bands
# http://dbpedia.org/resource/Haugesund has 1 bands
# http://dbpedia.org/resource/Tarpon_Springs,_Florida has 1 bands
# http://dbpedia.org/resource/Pomona,_California has 1 bands
# http://dbpedia.org/resource/Claremont,_California has 1 bands
# http://dbpedia.org/resource/Rio_de_Janeiro has 1 bands

# %% [markdown]
# Where is Jazz music the most popular?

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?city (COUNT(?band) as ?count) 
    WHERE {
        # ?band a ns3:Band ;
            ns3:hometown ?city ;
            ns1:bandGenres <http://dbpedia.org/resource/Jazz_music> .
            
    }
    GROUP BY ?city
    ORDER BY DESC(?count)
    """)

for row in qres:
    print("%s has %s bands" % row)
# Out:
# http://dbpedia.org/resource/New_York_City has 5 bands
# http://dbpedia.org/resource/London has 3 bands
# http://dbpedia.org/resource/Los_Angeles has 3 bands
# http://dbpedia.org/resource/Canterbury has 3 bands
# http://dbpedia.org/resource/Buenos_Aires has 2 bands
# http://dbpedia.org/resource/Chicago has 1 bands
# http://dbpedia.org/resource/Phoenix,_Arizona has 1 bands
# http://dbpedia.org/resource/Dakar has 1 bands
# http://dbpedia.org/resource/Oxnard,_California has 1 bands
# http://dbpedia.org/resource/East_Oakland,_Oakland,_California has 1 bands
# http://dbpedia.org/resource/Long_Beach,_California has 1 bands
# http://dbpedia.org/resource/Milan has 1 bands
# http://dbpedia.org/resource/Mülheim_an_der_Ruhr has 1 bands
# http://dbpedia.org/resource/Miami,_Florida has 1 bands
# http://dbpedia.org/resource/Brooklyn,_New_York has 1 bands
# http://dbpedia.org/resource/Munich has 1 bands
# http://dbpedia.org/resource/Tokyo has 1 bands
# http://dbpedia.org/resource/Cambridge,_Massachusetts has 1 bands
# http://dbpedia.org/resource/Bristol has 1 bands
# http://dbpedia.org/resource/Tampa,_Florida has 1 bands
# http://dbpedia.org/resource/San_Francisco has 1 bands
# http://dbpedia.org/resource/Arlington,_Texas has 1 bands
# http://dbpedia.org/resource/Sydney has 1 bands
# http://dbpedia.org/resource/Lee's_Summit has 1 bands
# http://dbpedia.org/resource/Paris has 1 bands
# http://dbpedia.org/resource/Pomona,_California has 1 bands
# http://dbpedia.org/resource/Philadelphia has 1 bands

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?country (COUNT(?band) as ?count) 
    WHERE {
        # ?band a ns3:Band ;
            ns3:origin ?country ;
            ns1:bandGenres <http://dbpedia.org/resource/Jazz_music> .
            
    }
    GROUP BY ?country
    ORDER BY DESC(?count)
    """)

for row in qres:
    print("%s has %s bands" % row)
# Out:
# http://dbpedia.org/resource/United_States has 18 bands
# http://dbpedia.org/resource/United_Kingdom has 7 bands
# http://dbpedia.org/resource/Kent has 3 bands
# http://dbpedia.org/resource/Argentina has 2 bands
# http://dbpedia.org/resource/Senegal has 1 bands
# http://dbpedia.org/resource/Italy has 1 bands
# http://dbpedia.org/resource/Japan has 1 bands
# http://dbpedia.org/resource/Australia has 1 bands
# http://dbpedia.org/resource/France has 1 bands

# %% [markdown]
# Which are the bands with Italian members?

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?band (COUNT(?bandMember) as ?count) 
    WHERE {
        # ?band a ns3:Band ;
            ns3:bandMember ?bandMember .
        # ?bandMember a ns3:BandMember ;
                ns3:country <http://dbpedia.org/resource/Italy> .
            
    }
    GROUP BY ?band
    ORDER BY DESC(?count)
    """)

for row in qres:
    print("%s has %s Italian BandMembers" % row)
# Out:
# http://dbpedia.org/resource/Premiata_Forneria_Marconi has 4 Italian BandMembers
# http://dbpedia.org/resource/Le_Orme has 3 Italian BandMembers
# http://dbpedia.org/resource/Elio_e_le_Storie_Tese has 2 Italian BandMembers
# http://dbpedia.org/resource/Area_(band) has 1 Italian BandMembers
# http://dbpedia.org/resource/Angra_(band) has 1 Italian BandMembers
# http://dbpedia.org/resource/Museo_Rosenbach has 1 Italian BandMembers
# http://dbpedia.org/resource/Sumo_(band) has 1 Italian BandMembers
# http://dbpedia.org/resource/Whitesnake has 1 Italian BandMembers

# %% [markdown]
# Which are the Bands that have bandMembers from Argentina?

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?band (COUNT(?bandMember) as ?count) 
    WHERE {
        # ?band a ns3:Band ;
            ns3:bandMember ?bandMember .
        # ?bandMember a ns3:BandMember ;
                ns3:country <http://dbpedia.org/resource/Argentina> .
            
    }
    GROUP BY ?band
    ORDER BY DESC(?count)
    """)

for row in qres:
    print("%s has %s BandMembers from Argentina" % row)
# Out:
# http://dbpedia.org/resource/Sumo_(band) has 8 BandMembers from Argentina
# http://dbpedia.org/resource/Serú_Girán has 4 BandMembers from Argentina
# http://dbpedia.org/resource/Soda_Stereo has 2 BandMembers from Argentina
# http://dbpedia.org/resource/Los_Fabulosos_Cadillacs has 2 BandMembers from Argentina
# http://dbpedia.org/resource/Therion_(band) has 1 BandMembers from Argentina
# http://dbpedia.org/resource/The_Mars_Volta has 1 BandMembers from Argentina
# http://dbpedia.org/resource/Viper_(band) has 1 BandMembers from Argentina

# %% [markdown]
# And what about Spain?

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?band (COUNT(?bandMember) as ?count) 
    WHERE {
        # ?band a ns3:Band ;
            ns3:bandMember ?bandMember .
        # ?bandMember a ns3:BandMember ;
                ns3:country <http://dbpedia.org/resource/Spain> .
            
    }
    GROUP BY ?band
    ORDER BY DESC(?count)
    """)

for row in qres:
    print("%s has %s BandMembers from Spain" % row)
# Out:
# http://dbpedia.org/resource/Héroes_del_Silencio has 4 BandMembers from Spain
# http://dbpedia.org/resource/Leño has 3 BandMembers from Spain
# http://dbpedia.org/resource/Extremoduro has 2 BandMembers from Spain

# %% [markdown]
# Check the number of ratings to find the most popular albums and artists in a specific time. What about the decade 1980 - 1990?

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    SELECT ?album ?artist ?numberOfRatings
    WHERE {
        # ?album a ns3:Album ;
            ns1:artist ?artist ;
            ns1:numberOfRatings ?numberOfRatings ;
            ns1:releaseDate ?releaseDate ;
            ns1:year ?year .
        FILTER ((?releaseDate >= "1980-01-01"^^xsd:date && ?releaseDate < "1991-01-01"^^xsd:date) 
        || (?year >= "1980"^^xsd:gYear && ?year < "1991"^^xsd:gYear))
    }
    ORDER BY DESC(?numberOfRatings)
    """)

for row in qres:
    print("%s by %s has %s ratings " % row)
# Out:
# http://dbpedia.org/resource/Remain_in_Light by http://dbpedia.org/resource/Talking_Heads has 36196 ratings
# http://dbpedia.org/resource/The_Queen_Is_Dead by http://dbpedia.org/resource/The_Smiths has 35400 ratings
# http://dbpedia.org/resource/Doolittle by http://dbpedia.org/resource/Pixies has 34101 ratings
# http://dbpedia.org/resource/Master_of_Puppets by http://dbpedia.org/resource/Metallica has 30780 ratings
# http://dbpedia.org/resource/Disintegration by http://dbpedia.org/resource/The_Cure has 29436 ratings
# http://dbpedia.org/resource/Closer by http://dbpedia.org/resource/Joy_Division has 28898 ratings
# http://dbpedia.org/resource/Daydream_Nation by http://dbpedia.org/resource/Sonic_Youth has 27963 ratings
# http://dbpedia.org/resource/Surfer_Rosa by http://dbpedia.org/resource/Pixies has 24269 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Beatles has 21363 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Beatles has 21363 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Replacements_(band) has 21363 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Replacements_(band) has 21363 ratings
# http://dbpedia.org/resource/The_Smiths_(album) by http://dbpedia.org/resource/The_Smiths has 19860 ratings
# http://dbpedia.org/resource/Rain_Dogs by http://dbpedia.org/resource/Tom_Waits has 19301 ratings
# http://dbpedia.org/resource/Violator by http://dbpedia.org/resource/Depeche_Mode has 19055 ratings
# http://dbpedia.org/resource/Thriller by http://dbpedia.org/resource/Michael_Jackson has 18323 ratings
# http://dbpedia.org/resource/Meat_Is_Murder by http://dbpedia.org/resource/The_Smiths has 18222 ratings
# http://dbpedia.org/resource/The_Stone_Roses_(album) by http://dbpedia.org/resource/The_Stone_Roses has 17367 ratings
# http://dbpedia.org/resource/Purple_Rain by http://dbpedia.org/resource/Prince_and_The_Revolution has 16754 ratings
# http://dbpedia.org/resource/Purple_Rain by http://dbpedia.org/resource/Prince_and_the_Revolution has 16754 ratings
# http://dbpedia.org/resource/Appetite_for_Destruction by http://dbpedia.org/resource/Guns_N'_Roses has 16526 ratings
# http://dbpedia.org/resource/Appetite_for_Destruction by http://dbpedia.org/resource/Guns_n'_Roses has 16526 ratings
# http://dbpedia.org/resource/Back_in_Black by http://dbpedia.org/resource/AC/DC has 15828 ratings
# http://dbpedia.org/resource/Psychocandy by http://dbpedia.org/resource/The_Jesus_and_Mary_Chain has 15387 ratings
# http://dbpedia.org/resource/The_Joshua_Tree by http://dbpedia.org/resource/U2 has 14446 ratings
# http://dbpedia.org/resource/Paul's_Boutique by http://dbpedia.org/resource/Beastie_Boys has 14433 ratings
# http://dbpedia.org/resource/Murmur by http://dbpedia.org/resource/R.E.M. has 14362 ratings
# http://dbpedia.org/resource/It_Takes_a_Nation_of_Millions_to_Hold_Us_Back by http://dbpedia.org/resource/Public_Enemy has 12599 ratings
# http://dbpedia.org/resource/Damaged by http://dbpedia.org/resource/Black_Flag_(band) has 11522 ratings
# http://dbpedia.org/resource/Faith by http://dbpedia.org/resource/George_Michael has 11155 ratings
# http://dbpedia.org/resource/Faith by http://dbpedia.org/resource/The_Cure has 11155 ratings
# http://dbpedia.org/resource/Double_Nickels_on_the_Dime by http://dbpedia.org/resource/Minutemen_(band) has 11105 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Beatles has 10775 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Beatles has 10775 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Replacements_(band) has 10775 ratings
# http://dbpedia.org/resource/Let_It_Be by http://dbpedia.org/resource/The_Replacements_(band) has 10775 ratings
# http://dbpedia.org/resource/Straight_Outta_Compton by http://dbpedia.org/resource/N.W.A has 10591 ratings
# http://dbpedia.org/resource/Nebraska by http://dbpedia.org/resource/Bruce_Springsteen has 9857 ratings
# http://dbpedia.org/resource/Desire by http://dbpedia.org/resource/Bob_Dylan has 9487 ratings
# http://dbpedia.org/resource/Desire by http://dbpedia.org/resource/Tuxedomoon has 9487 ratings
# http://dbpedia.org/resource/War_(album) by http://dbpedia.org/resource/U2 has 9409 ratings
# http://dbpedia.org/resource/Bad by http://dbpedia.org/resource/Michael_Jackson has 8721 ratings
# http://dbpedia.org/resource/Graceland by http://dbpedia.org/resource/Paul_Simon has 8658 ratings
# http://dbpedia.org/resource/Born_in_the_U.S.A. by http://dbpedia.org/resource/Bruce_Springsteen has 8501 ratings
# http://dbpedia.org/resource/1999 by http://dbpedia.org/resource/Prince has 7970 ratings
# http://dbpedia.org/resource/3_Feet_High_and_Rising by http://dbpedia.org/resource/De_La_Soul has 7926 ratings
# http://dbpedia.org/resource/Document by http://dbpedia.org/resource/R.E.M. has 7827 ratings
# http://dbpedia.org/resource/Brothers_in_Arms by http://dbpedia.org/resource/Dire_Straits has 7809 ratings
# http://dbpedia.org/resource/Los_Angeles by http://dbpedia.org/resource/Flying_Lotus has 7741 ratings
# http://dbpedia.org/resource/Los_Angeles by http://dbpedia.org/resource/X has 7741 ratings
# http://dbpedia.org/resource/So by http://dbpedia.org/resource/Peter_Gabriel has 7414 ratings
# http://dbpedia.org/resource/Fear_of_a_Black_Planet by http://dbpedia.org/resource/Public_Enemy has 7160 ratings
# http://dbpedia.org/resource/Tim by http://dbpedia.org/resource/The_Replacements_(band) has 6989 ratings
# http://dbpedia.org/resource/Synchronicity by http://dbpedia.org/resource/The_Police has 6777 ratings
# http://dbpedia.org/resource/New_Day_Rising by http://dbpedia.org/resource/Husker_Du has 6564 ratings
# http://dbpedia.org/resource/New_Day_Rising by http://dbpedia.org/resource/Hüsker_Dü has 6564 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Ali_Farka_Touré has 6356 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Ali_Farka_Touré has 6356 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Bruce_Springsteen has 6356 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Bruce_Springsteen has 6356 ratings
# http://dbpedia.org/resource/Dirty_Mind by http://dbpedia.org/resource/Prince has 6270 ratings
# http://dbpedia.org/resource/Nothing's_Shocking by http://dbpedia.org/resource/Jane's_Addiction has 5129 ratings
# http://dbpedia.org/resource/Los_Angeles by http://dbpedia.org/resource/Flying_Lotus has 5091 ratings
# http://dbpedia.org/resource/Los_Angeles by http://dbpedia.org/resource/X has 5091 ratings
# http://dbpedia.org/resource/Rum_Sodomy_&_the_Lash by http://dbpedia.org/resource/The_Pogues has 4526 ratings
# http://dbpedia.org/resource/Tracy_Chapman_(album) by http://dbpedia.org/resource/Tracy_Chapman has 3851 ratings
# http://dbpedia.org/resource/Heaven_Up_Here by http://dbpedia.org/resource/Echo_and_The_Bunnymen has 3770 ratings
# http://dbpedia.org/resource/Pretenders_(album) by http://dbpedia.org/resource/Pretenders_(band) has 3528 ratings
# http://dbpedia.org/resource/Imperial_Bedroom by http://dbpedia.org/resource/Elvis_Costello_&_The_Attractions has 3270 ratings
# http://dbpedia.org/resource/Desire by http://dbpedia.org/resource/Bob_Dylan has 2882 ratings
# http://dbpedia.org/resource/Desire by http://dbpedia.org/resource/Tuxedomoon has 2882 ratings
# http://dbpedia.org/resource/Strictly_Business by http://dbpedia.org/resource/EPMD has 2656 ratings
# http://dbpedia.org/resource/Rhythm_Nation_1814 by http://dbpedia.org/resource/Janet_Jackson has 2590 ratings
# http://dbpedia.org/resource/Wild_Gift by http://dbpedia.org/resource/X has 2093 ratings
# http://dbpedia.org/resource/Shoot_Out_the_Lights by http://dbpedia.org/resource/Richard_&_Linda_Thompson has 1881 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Ali_Farka_Touré has 527 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Ali_Farka_Touré has 527 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Bruce_Springsteen has 527 ratings
# http://dbpedia.org/resource/The_River by http://dbpedia.org/resource/Bruce_Springsteen has 527 ratings

# %% [markdown]
# I am a huge U2 fan! Let's see which other bands are from Ireland as well.

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?band ?origin 
    WHERE {
        # ?band a ns3:Band ;
            ns3:origin ?origin .
        <http://dbpedia.org/resource/U2> ns3:origin ?origin .
        
            
    }
    """)

for row in qres:
    print("%s is from %s like U2" % row)
# Out:
# http://dbpedia.org/resource/Altar_of_Plagues is from http://dbpedia.org/resource/Republic_of_Ireland like U2
# http://dbpedia.org/resource/My_Bloody_Valentine_(band) is from http://dbpedia.org/resource/Republic_of_Ireland like U2
# http://dbpedia.org/resource/Primordial_(band) is from http://dbpedia.org/resource/Republic_of_Ireland like U2
# http://dbpedia.org/resource/U2 is from http://dbpedia.org/resource/Republic_of_Ireland like U2
# http://dbpedia.org/resource/Thin_Lizzy is from http://dbpedia.org/resource/Republic_of_Ireland like U2

# %% [markdown]
# Are there any artists that played both in Black Metal bands and Pop bands?

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns2: <http://dbpedia.org/resource/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?artist ?band1 ?band2 
    WHERE {
        # ?artist a ns3:BandMember .
        # ?band1 a ns3:Band ;
               ns1:bandGenres <http://dbpedia.org/resource/Black_Metal> .
        OPTIONAL { ?band1 ns3:bandMember ?artist }
        OPTIONAL { ?band1 ns3:formerBandMember ?artist }
        # ?band2 a ns3:Band ;
               ns1:bandGenres <http://dbpedia.org/resource/Pop_music> .
        OPTIONAL { ?band2 ns3:bandMember ?artist }
        OPTIONAL { ?band2 ns3:formerBandMember ?artist }
    } LIMIT 300
    """)
for row in qres:
    print("%s played in both bands: %s and %s" % row)
# Out:
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/ABBA
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/ABC_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Almendra_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Alvvays
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Antony_and_the_Johnsons
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Bjork
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Blondie_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Buffalo_Springfield
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Carly_Rae_Jepsen
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Chicago_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Coheed_and_Cambria
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Coldplay
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Crowded_House
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Death_Cab_for_Cutie
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Dolly_Mixture_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Dusty_Springfield
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Edan
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/El_Último_de_la_Fila
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Elvis_Costello_and_The_Attractions
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Eurythmics
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Everything_Everything
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/FKA_twigs
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Fever_Ray
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Flamin'_Groovies
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Flotation_Toy_Warning
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Frightened_Rabbit
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Fugees
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Goldfrapp
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Grandaddy
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Hoodoo_Gurus
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/James_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Japanese_Breakfast
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Joe_Cocker
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kero_Kero_Bonito
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kleenex_Girl_Wonder
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kylie_Minogue
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lady_Pank
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lamp_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Leevi_and_the_Leavings
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lemon_Demon
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lenny_Valentino
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lil_Wayne
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lily_Chou-Chou
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Luna_Sea
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Magdalena_Bay_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Mazzy_Star
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Mink_DeVille
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Myslovitz
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Origami_Angel
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Os_Paralamas_do_Sucesso
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/PMMP
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Polaris_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Pretty_Things
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Propaganda_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Rilo_Kiley
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Robyn_Hitchcock_and_The_Egyptians
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Secos_&_Molhados
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Simple_Minds
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Sixpence_None_the_Richer
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Small_Faces
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Soft_Cell
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Spanish_Love_Songs
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Spiritualized
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Steve_Miller_Band
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Super_Furry_Animals
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Suzanne_Vega
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Swirlies
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Cars
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Crickets
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Doobie_Brothers
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Dukes_of_Stratosphear
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Durutti_Column
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Exploding_Hearts
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Innocence_Mission
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Knife
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Left_Banke
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Loud_Family
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Mamas_and_the_Papas
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Millennium_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Notwist
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Only_Ones
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Posies
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Postal_Service
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Pretenders
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Radio_Dept.
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Rutles
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Shins
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Soft_Boys
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Sundays
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Supremes
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_The
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Undertones
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Unicorns
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Verve
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Wonder_Years_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Zombies
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Tom_Petty_and_The_Heartbreakers
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Tom_Petty_and_the_Heartbreakers
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Traveling_Wilburys
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Tubeway_Army
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Whitney_Houston
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Young_Marble_Giants
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Badfinger
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Belle_&_Sebastian
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Belle_and_Sebastian
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Blur_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Candy_Claws
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Cockney_Rebel
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Eels_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Fishmans
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Galaxie_500
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Gorillaz
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Green_Day
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Japan_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Jellyfish_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Josh_Rouse
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kent_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Los_Prisioneros
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Love_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/M.I.A._(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/MGMT
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Manic_Street_Preachers
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Mansun
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Mercury_Rev
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Mew_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/My_Chemical_Romance
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Oasis_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Puressence
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Simon_and_Garfunkel
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Slapp_Happy
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Squeeze_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Sui_Generis
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Suicide
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Supergrass
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Tame_Impala
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Tears_for_Fears
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Blue_Nile
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Church_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Decemberists
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Jesus_and_Mary_Chain
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Magnetic_Fields
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_New_Pornographers
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Olivia_Tremor_Control
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Ronettes
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Wildhearts
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Yardbirds
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Vampire_Weekend
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Various
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Yellow_Magic_Orchestra
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Arcade_Fire
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Beach_House
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Broadcast_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Destroyer_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Einstürzende_Neubauten
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Electric_Light_Orchestra
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Janet_Jackson
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/My_Bloody_Valentine_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Prefab_Sprout
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Pulp_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Queen_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Ray_Charles
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Sade_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Sparklehorse
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Suede_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Supertramp
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Sweet_Trip
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Talk_Talk
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Teenage_Fanclub
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Divine_Comedy_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Jam
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Jayhawks
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Moody_Blues
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Replacements_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Residents
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Waterboys
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Tindersticks
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/ZZ_Top
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Animal_Collective
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Beastie_Boys
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Big_Star
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Brockhampton_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Buzzcocks
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Cheap_Trick
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Dire_Straits
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Elvis_Presley
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Fleetwood_Mac
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kraftwerk
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Simon_&_Garfunkel
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Slowdive
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Soda_Stereo
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Go-Betweens
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Police
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/They_Might_Be_Giants
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Ulver
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Weezer
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Wilco
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Yo_La_Tengo
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Cocteau_Twins
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Low_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/New_Order
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Pet_Shop_Boys
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Sparks_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Beach_Boys
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Byrds
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Flaming_Lips
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Velvet_Underground
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/U2
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/XTC
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Boris_(band)
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Depeche_Mode
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/R.E.M.
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Roxy_Music
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Smiths
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Ween
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Frank_Sinatra
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Radiohead
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Steely_Dan
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Stereolab
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Cure
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Who
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Pink_Floyd
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Kinks
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Rolling_Stones
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Beatles
# http://dbpedia.org/resource/%22Sneaky%22_Pete_Kleinow played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Various_Artists
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/ABBA
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/ABC_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Almendra_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Alvvays
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Antony_and_the_Johnsons
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Bjork
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Blondie_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Buffalo_Springfield
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Carly_Rae_Jepsen
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Chicago_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Coheed_and_Cambria
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Coldplay
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Crowded_House
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Death_Cab_for_Cutie
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Dolly_Mixture_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Dusty_Springfield
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Edan
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/El_Último_de_la_Fila
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Elvis_Costello_and_The_Attractions
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Eurythmics
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Everything_Everything
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/FKA_twigs
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Fever_Ray
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Flamin'_Groovies
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Flotation_Toy_Warning
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Frightened_Rabbit
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Fugees
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Goldfrapp
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Grandaddy
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Hoodoo_Gurus
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/James_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Japanese_Breakfast
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Joe_Cocker
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kero_Kero_Bonito
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kleenex_Girl_Wonder
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Kylie_Minogue
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lady_Pank
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lamp_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Leevi_and_the_Leavings
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lemon_Demon
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lenny_Valentino
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lil_Wayne
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Lily_Chou-Chou
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Luna_Sea
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Magdalena_Bay_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Mazzy_Star
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Mink_DeVille
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Myslovitz
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Origami_Angel
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Os_Paralamas_do_Sucesso
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/PMMP
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Polaris_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Pretty_Things
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Propaganda_(band)
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Rilo_Kiley
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Robyn_Hitchcock_and_The_Egyptians
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Secos_&_Molhados
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Simple_Minds
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Sixpence_None_the_Richer
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Small_Faces
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Soft_Cell
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Spanish_Love_Songs
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Spiritualized
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Steve_Miller_Band
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Super_Furry_Animals
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Suzanne_Vega
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/Swirlies
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Cars
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Crickets
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Doobie_Brothers
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Dukes_of_Stratosphear
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Durutti_Column
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Exploding_Hearts
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Innocence_Mission
# http://dbpedia.org/resource/2-D_(character) played in both bands: http://dbpedia.org/resource/Behemoth_(band) and http://dbpedia.org/resource/The_Knife

# %% [markdown]
# Which bands have active members from Ireland and United Kindom?

# %%
qres = g.query(
    """
    PREFIX ns1: <http://dbpedia.org/property/>
    PREFIX ns3: <http://dbpedia.org/ontology/>
    SELECT ?artist1 ?artist2 ?band 
    WHERE {
        # ?artist1 a ns3:BandMember ;
                ns3:country <http://dbpedia.org/resource/Republic_of_Ireland> .
        # ?artist2 a ns3:BandMember ;
                ns3:country <http://dbpedia.org/resource/United_Kingdom> .
        # ?band a ns3:Band ;
              ns3:bandMember ?artist1 ;
              ns3:bandMember ?artist2 .
    }
    """)

for row in qres:
    print("%s from Ireland and %s from United Kingdom play for: %s" % row)
# Out:
# http://dbpedia.org/resource/Bono from Ireland and http://dbpedia.org/resource/Adam_Clayton from United Kingdom play for: http://dbpedia.org/resource/U2
# http://dbpedia.org/resource/Bono from Ireland and http://dbpedia.org/resource/The_Edge from United Kingdom play for: http://dbpedia.org/resource/U2
# http://dbpedia.org/resource/John_Mitchell_(musician) from Ireland and http://dbpedia.org/resource/Mick_Pointer from United Kingdom play for: http://dbpedia.org/resource/Arena_(band)
# http://dbpedia.org/resource/Larry_Mullen_Jr. from Ireland and http://dbpedia.org/resource/Adam_Clayton from United Kingdom play for: http://dbpedia.org/resource/U2
# http://dbpedia.org/resource/Larry_Mullen_Jr. from Ireland and http://dbpedia.org/resource/The_Edge from United Kingdom play for: http://dbpedia.org/resource/U2
# http://dbpedia.org/resource/Mark_Kelly_(keyboardist) from Ireland and http://dbpedia.org/resource/Ian_Mosley from United Kingdom play for: http://dbpedia.org/resource/Marillion
# http://dbpedia.org/resource/Mark_Kelly_(keyboardist) from Ireland and http://dbpedia.org/resource/Steve_Hogarth from United Kingdom play for: http://dbpedia.org/resource/Marillion
# http://dbpedia.org/resource/Mark_Kelly_(keyboardist) from Ireland and http://dbpedia.org/resource/Steve_Rothery from United Kingdom play for: http://dbpedia.org/resource/Marillion
# http://dbpedia.org/resource/Mark_Kelly_(keyboardist) from Ireland and http://dbpedia.org/resource/Pete_Trewavas from United Kingdom play for: http://dbpedia.org/resource/Marillion
# http://dbpedia.org/resource/Scott_Gorham from Ireland and http://dbpedia.org/resource/Darren_Wharton from United Kingdom play for: http://dbpedia.org/resource/Thin_Lizzy
# http://dbpedia.org/resource/Scott_Gorham from Ireland and http://dbpedia.org/resource/Ricky_Warwick from United Kingdom play for: http://dbpedia.org/resource/Thin_Lizzy
# http://dbpedia.org/resource/Troy_Sanders from Ireland and http://dbpedia.org/resource/Darren_Wharton from United Kingdom play for: http://dbpedia.org/resource/Thin_Lizzy
# http://dbpedia.org/resource/Troy_Sanders from Ireland and http://dbpedia.org/resource/Ricky_Warwick from United Kingdom play for: http://dbpedia.org/resource/Thin_Lizzy
# http://dbpedia.org/resource/Scott_Travis from Ireland and http://dbpedia.org/resource/Darren_Wharton from United Kingdom play for: http://dbpedia.org/resource/Thin_Lizzy
# http://dbpedia.org/resource/Scott_Travis from Ireland and http://dbpedia.org/resource/Glenn_Tipton from United Kingdom play for: http://dbpedia.org/resource/Judas_Priest
# http://dbpedia.org/resource/Scott_Travis from Ireland and http://dbpedia.org/resource/Ian_Hill from United Kingdom play for: http://dbpedia.org/resource/Judas_Priest
# http://dbpedia.org/resource/Scott_Travis from Ireland and http://dbpedia.org/resource/Richie_Faulkner from United Kingdom play for: http://dbpedia.org/resource/Judas_Priest
# http://dbpedia.org/resource/Scott_Travis from Ireland and http://dbpedia.org/resource/Ricky_Warwick from United Kingdom play for: http://dbpedia.org/resource/Thin_Lizzy
# http://dbpedia.org/resource/Scott_Travis from Ireland and http://dbpedia.org/resource/Rob_Halford from United Kingdom play for: http://dbpedia.org/resource/Judas_Priest

# %% [markdown]
# ### **`Notes`**
# - attempts to enrich the data (e.g., using Wikipedia articles, other KGs and data sources) will be positively evaluated, but only if enrichment in steps 2 and 3 has been sufficiently explored
# - sometimes matching local entities with DBpedia entities is difficult: do not worry too much about that, we will give more importance to the choices and motivations rather than the end result of the matching
# - as you can see, the instructions leave enough freedom, however in case of non-obvious clarifications or technical issues contact me at renzo.alvaprincipe@unimib.it or use the course forum. Questions about how to do the exercise will be ignored
# - plagiarism will be **<ins>severely</ins>** punished for both parties
